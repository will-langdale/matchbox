# %% [markdown]
# # Hierarchical algorithm optimisation

# %% [markdown]
# ## Data generation

# %%
import rustworkx as rx
from collections import Counter

def verify_components(table) -> dict:
    """
    Fast verification of connected components using rustworkx.
    
    Args:
        table: PyArrow table with 'left', 'right' columns
    
    Returns:
        dictionary containing basic component statistics
    """
    # Create graph directly from arrays
    graph = rx.PyDiGraph()
    
    # Add all unique nodes at once
    unique_nodes = set(table['left'].to_numpy()) | set(table['right'].to_numpy())
    graph.add_nodes_from(range(len(unique_nodes)))
    
    # Create node mapping and edges in one pass
    node_to_idx = {node: idx for idx, node in enumerate(unique_nodes)}
    edges = [(node_to_idx[left], node_to_idx[right], prob) 
            for left, right, prob in zip(table['left'].to_numpy(), 
                                       table['right'].to_numpy(),
                                       table['probability'].to_numpy())]
    
    # Add all edges at once
    graph.add_edges_from(edges)
    
    # Get components and their sizes
    components = rx.weakly_connected_components(graph)
    component_sizes = Counter(len(component) for component in components)
    
    return {
        'num_components': len(components),
        'total_nodes': len(unique_nodes),
        'total_edges': len(edges),
        'component_sizes': component_sizes,
        'min_component_size': min(component_sizes.keys()),
        'max_component_size': max(component_sizes.keys())
    }

# %%
def calculate_max_possible_edges(n_nodes: int, num_components: int) -> int:
    """
    Calculate the maximum possible number of edges given n nodes split into k components.
    
    Args:
        n_nodes: Total number of nodes
        num_components: Number of components to split into
        
    Returns:
        Maximum possible number of edges
    """
    nodes_per_component = n_nodes // num_components
    max_edges_per_component = nodes_per_component * nodes_per_component  # Complete bipartite graph
    return max_edges_per_component * num_components

# %%
import numpy as np
import pyarrow as pa
import rustworkx as rx
from typing import List, Tuple
from decimal import Decimal

def split_values_into_components(values: List[int], num_components: int) -> List[np.ndarray]:
    """
    Split values into non-overlapping groups for each component.
    
    Args:
        values: List of values to split
        num_components: Number of components to create
        
    Returns:
        List of arrays, one for each component
    """
    values = np.array(values)
    np.random.shuffle(values)
    return np.array_split(values, num_components)


def generate_arrow_data(
    left_values: List[int],
    right_values: List[int],
    prob_range: Tuple[float, float],
    num_components: int,
    total_rows: int
) -> pa.Table:
    """
    Generate dummy arrow data with guaranteed isolated components.
    
    Args:
        left_values: List of integers to use for left column
        right_values: List of integers to use for right column
        prob_range: Tuple of (min_prob, max_prob) to constrain probabilities
        num_components: Number of distinct connected components to generate
        total_rows: Total number of rows to generate
    
    Returns:
        PyArrow Table with 'left', 'right', and 'probability' columns
    """
    if len(left_values) < 2 or len(right_values) < 2:
        raise ValueError("Need at least 2 possible values for both left and right")
    if num_components > min(len(left_values), len(right_values)):
        raise ValueError("Cannot have more components than minimum of left/right values")
    
    # Calculate maximum possible edges
    min_nodes = min(len(left_values), len(right_values))
    max_possible_edges = calculate_max_possible_edges(min_nodes, num_components)
    
    if total_rows > max_possible_edges:
        raise ValueError(
            f"Cannot generate {total_rows:,} edges with {num_components:,} components. "
            f"Maximum possible edges is {max_possible_edges:,} given {min_nodes:,} nodes. "
            "Either increase the number of nodes, decrease the number of components, "
            "or decrease the total edges requested."
        )
    
    # Convert probability range to integers (60-80 for 0.60-0.80)
    prob_min = int(prob_range[0] * 100)
    prob_max = int(prob_range[1] * 100)
    
    # Split values into completely separate groups for each component
    left_components = split_values_into_components(left_values, num_components)
    right_components = split_values_into_components(right_values, num_components)
    
    # Calculate base number of edges per component
    base_edges_per_component = total_rows // num_components
    remaining_edges = total_rows % num_components
    
    all_edges = []
    
    # Generate edges for each component
    for comp_idx in range(num_components):
        comp_left_values = left_components[comp_idx]
        comp_right_values = right_components[comp_idx]
        
        # Calculate edges for this component
        edges_in_component = base_edges_per_component
        if comp_idx < remaining_edges:  # Distribute remaining edges
            edges_in_component += 1
            
        # Ensure basic connectivity within the component
        base_edges = []
        
        # Create a spanning tree-like structure
        for i in range(len(comp_left_values)):
            base_edges.append((
                comp_left_values[i],
                comp_right_values[i % len(comp_right_values)],
                np.random.randint(prob_min, prob_max + 1)
            ))
        
        # Generate remaining random edges strictly within this component
        remaining_edges = edges_in_component - len(base_edges)
        if remaining_edges > 0:
            random_lefts = np.random.choice(comp_left_values, size=remaining_edges)
            random_rights = np.random.choice(comp_right_values, size=remaining_edges)
            random_probs = np.random.randint(prob_min, prob_max + 1, size=remaining_edges)
            
            component_edges = base_edges + list(zip(random_lefts, random_rights, random_probs))
        else:
            component_edges = base_edges
            
        all_edges.extend(component_edges)
    
    # Convert to arrays
    lefts, rights, probs = zip(*all_edges)
    
    # Create PyArrow arrays
    left_array = pa.array(lefts, type=pa.int64())
    right_array = pa.array(rights, type=pa.int64())
    decimal_probs = [Decimal(str(p/100)) for p in probs]
    prob_array = pa.array(decimal_probs, type=pa.decimal128(precision=3, scale=2))
    
    return pa.table([left_array, right_array, prob_array],
                   names=['left', 'right', 'probability'])

# %%
left_values = list(range(10_000))
right_values = list(range(10_000, 20_000))
prob_range = (0.6, 0.8)
num_components = 10
total_rows = 1_000_000

table = generate_arrow_data(
    left_values=left_values,
    right_values=right_values,
    prob_range=prob_range,
    num_components=num_components,
    total_rows=total_rows
)

results = verify_components(table)
print(f"Number of components found: {results['num_components']}")
print(f"Total nodes: {results['total_nodes']}")
print(f"Total edges: {results['total_edges']}")
print("\nComponent sizes:")
for size, count in sorted(results['component_sizes'].items()):
    print(f"Size {size}: {count} components")
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x10d274c90>>
# Traceback (most recent call last):
#   File "/Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# Number of components found: 10
# Total nodes: 20000
# Total edges: 1000009
#
# Component sizes:
# Size 2000: 10 components

# %%
left_values = list(range(int(2e7)))
right_values = list(range(int(2e7), int(4e7)))
prob_range = (0.7, 1.0)
num_components = 200_000
total_rows = int(1e8)

table = generate_arrow_data(
    left_values=left_values,
    right_values=right_values,
    prob_range=prob_range,
    num_components=num_components,
    total_rows=total_rows
)

# %%
results = verify_components(table)
print(f"Number of components found: {results['num_components']}")
print(f"Total nodes: {results['total_nodes']}")
print(f"Total edges: {results['total_edges']}")
print("\nComponent sizes:")
for size, count in sorted(results['component_sizes'].items()):
    print(f"Size {size}: {count} components")
# Out:
# Number of components found: 206763
# Total nodes: 40000000
# Total edges: 100000400
#
# Component sizes:
# Size 2: 6755 components
# Size 4: 8 components
# Size 194: 1 components
# Size 196: 124 components
# Size 198: 6520 components
# Size 200: 193355 components

# %% [markdown]
# Number of components found: 206763
# * Total nodes: 40000000
# * Total edges: 100000400
#
# Component sizes:
# * Size 2: 6755 components
# * Size 4: 8 components
# * Size 194: 1 components
# * Size 196: 124 components
# * Size 198: 6520 components
# * Size 200: 193355 components

# %%
from pathlib import Path
import pyarrow.parquet as pq

pq.write_table(table, Path.cwd() / 'hierarchical_cc200k.parquet')

# %%
left_values = list(range(int(2e5)))
right_values = list(range(int(2e5), int(4e5)))
prob_range = (0.7, 1.0)
num_components = 2_000
total_rows = int(1e6)

table2 = generate_arrow_data(
    left_values=left_values,
    right_values=right_values,
    prob_range=prob_range,
    num_components=num_components,
    total_rows=total_rows
)

# %%
results2 = verify_components(table2)
print(f"Number of components found: {results2['num_components']:,}")
print(f"Total nodes: {results2['total_nodes']:,}")
print(f"Total edges: {results2['total_edges']:,}")
print("\nComponent sizes:")
for size, count in sorted(results2['component_sizes'].items()):
    print(f"Size {size:,}: {count:,} components")
# Out:
# Number of components found: 2,080
# Total nodes: 400,000
# Total edges: 1,000,400
#
# Component sizes:
# Size 2: 80 components
# Size 196: 1 components
# Size 198: 78 components
# Size 200: 1,921 components

# %% [markdown]
# Number of components found: 2,080
# * Total nodes: 400,000
# * Total edges: 1,000,400
#
# Component sizes:
# * Size 2: 80 components
# * Size 196: 1 components
# * Size 198: 78 components
# * Size 200: 1,921 components

# %%
from pathlib import Path
import pyarrow.parquet as pq

pq.write_table(table2, Path.cwd() / 'hierarchical_cc2k.parquet')

# %% [markdown]
# ## Algorithm

# %%
import pyarrow.parquet as pq

h2 = pq.read_table('hierarchical_cc2k.parquet')

# %%
h2.schema
# Out:
# left: int64
# right: int64
# probability: decimal128(3, 2)

# %% [markdown]
# The plan.
#
# * Find components and their sizes at lowest threshold (rustworkx)
# * Use this to dask.groupby the data for parallel per-component processing
# * Ensure we implement early stopping!

# %% [markdown]
# ### Find components

# %%
import pyarrow as pa
import pyarrow.compute as pc
import rustworkx as rx
import numpy as np

def attach_independent_components(table: pa.Table) -> pa.Table:
    """
    Returns the original table with an additional 'component' column indicating
    which connected component each edge belongs to.
    """
    # Create dictionary array from sorted unique values
    unique = pc.unique(
        pa.concat_arrays([
            table['left'].combine_chunks(),
            table['right'].combine_chunks()
        ])
    )
    
    # Get indices into unique array for graph construction
    left_indices = pc.index_in(table['left'], unique)
    right_indices = pc.index_in(table['right'], unique)
    
    # Create and process graph
    n_nodes = len(unique)
    n_edges = len(table)
    
    graph = rx.PyGraph(
        node_count_hint=n_nodes,
        edge_count_hint=n_edges
    )
    graph.add_nodes_from(range(n_nodes))

    edges = tuple(zip(left_indices.to_numpy(), right_indices.to_numpy()))
    graph.add_edges_from_no_data(edges)
    
    # Get components and create mapping array
    components = rx.connected_components(graph)
    
    # Convert components to numpy arrays
    component_indices = np.concatenate([np.array(list(c)) for c in components])
    component_labels = np.repeat(np.arange(len(components)), [len(c) for c in components])
    
    # Create mapping array and fill with component labels
    node_to_component = np.zeros(len(unique), dtype=np.int64)
    node_to_component[component_indices] = component_labels
    
    # Use the indices we already have to map back to components  
    edge_components = pa.array(node_to_component[left_indices.to_numpy()])
    
    return table.append_column('component', edge_components).sort_by(
        [('component', 'ascending'), ('probability', 'descending')]
    )

cc2 = attach_independent_components(h2)
len(pc.unique(cc2.column('component'))), cc2
# Out:
# (2080,
#  pyarrow.Table
#  left: int64
#  right: int64
#  probability: decimal128(3, 2)
#  component: int64
#  ----
#  left: [[197413,116407,114551,160857,6412,...,39429,156175,197197,48177,121674]]
#  right: [[326505,384163,344025,248700,258884,...,311452,278755,204144,357956,378111]]
#  probability: [[1.00,1.00,1.00,1.00,1.00,...,0.70,0.70,0.70,0.70,0.70]]
#  component: [[0,0,0,0,0,...,2079,2079,2079,2079,2079]])

# %%
import cProfile
import pstats
from pstats import SortKey

# Profile the function
pr = cProfile.Profile()
pr.enable()
components = attach_independent_components(table2)
pr.disable()

# Print stats sorted by cumulative time
ps = pstats.Stats(pr).sort_stats(SortKey.CUMULATIVE)
ps.print_stats(20)  # Show top 20 lines
# Out:
#          34170 function calls in 1.108 seconds
#
#    Ordered by: cumulative time
#    List reduced from 49 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    1.108    0.554 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3541(run_code)
#         2    0.000    0.000    1.108    0.554 {built-in method builtins.exec}
#         1    0.058    0.058    1.108    1.108 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_25768/655470289.py:1(<module>)
#         1    0.397    0.397    1.050    1.050 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_25768/2783446239.py:5(attach_independent_components)
#         3    0.296    0.099    0.296    0.099 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pyarrow/compute.py:249(wrapper)
#         1    0.118    0.118    0.118    0.118 {connected_components}
#         1    0.088    0.088    0.088    0.088 {method 'add_edges_from_no_data' of 'rustworkx.PyGraph' objects}
#         1    0.066    0.066    0.066    0.066 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pyarrow/compute.py:239(wrapper)
#         1    0.007    0.007    0.033    0.033 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_25768/2783446239.py:39(<listcomp>)
#      2080    0.026    0.000    0.026    0.000 {built-in method numpy.array}
#      2850    0.008    0.000    0.021    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py:775(_clean_thread_parent_frames)
#         1    0.017    0.017    0.017    0.017 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pyarrow/compute.py:446(take)
#         1    0.013    0.013    0.013    0.013 {method 'add_nodes_from' of 'rustworkx.PyGraph' objects}
#      1425    0.005    0.000    0.008    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py:790(<setcomp>)
#      1425    0.004    0.000    0.005    0.000 /Users/willlangdale/.pyenv/versions/3.11.8/lib/python3.11/threading.py:1501(enumerate)
#     11400    0.003    0.000    0.003    0.000 /Users/willlangdale/.pyenv/versions/3.11.8/lib/python3.11/threading.py:1168(ident)
#      5700    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.001    0.001 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_25768/2783446239.py:40(<listcomp>)
#         1    0.000    0.000    0.000    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:467(repeat)
#         1    0.000    0.000    0.000    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:51(_wrapfunc)

# %%
import cProfile
import pstats
from pstats import SortKey

# Profile the function
pr = cProfile.Profile()
pr.enable()
_ = attach_independent_components(table)
pr.disable()

# Print stats sorted by cumulative time
ps = pstats.Stats(pr).sort_stats(SortKey.CUMULATIVE)
ps.print_stats(20)  # Show top 20 lines
# Out:
#          3411228 function calls in 121.198 seconds
#
#    Ordered by: cumulative time
#    List reduced from 48 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000  139.163   69.581 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3541(run_code)
#         2    0.001    0.000  139.162   69.581 {built-in method builtins.exec}
#         1   47.532   47.532  121.195  121.195 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_25768/2801194547.py:1(find_independent_components)
#         1   24.123   24.123   24.123   24.123 {method 'add_edges_from_no_data' of 'rustworkx.PyGraph' objects}
#         1   18.713   18.713   18.731   18.731 {connected_components}
#         2   14.375    7.187   14.375    7.187 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pyarrow/compute.py:249(wrapper)
#         1    7.661    7.661    7.661    7.661 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pyarrow/compute.py:239(wrapper)
#         1    1.303    1.303    4.041    4.041 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_25768/2801194547.py:35(<listcomp>)
#    206763    2.738    0.000    2.738    0.000 {built-in method numpy.array}
#    285488    0.966    0.000    2.629    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py:775(_clean_thread_parent_frames)
#         1    1.879    1.879    1.879    1.879 {method 'add_nodes_from' of 'rustworkx.PyGraph' objects}
#    142744    0.579    0.000    0.912    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py:790(<setcomp>)
#    142744    0.527    0.000    0.629    0.000 /Users/willlangdale/.pyenv/versions/3.11.8/lib/python3.11/threading.py:1501(enumerate)
#   1141952    0.333    0.000    0.333    0.000 /Users/willlangdale/.pyenv/versions/3.11.8/lib/python3.11/threading.py:1168(ident)
#         1    0.001    0.001    0.167    0.167 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:467(repeat)
#         1    0.000    0.000    0.166    0.166 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:51(_wrapfunc)
#         1    0.166    0.166    0.166    0.166 {method 'repeat' of 'numpy.ndarray' objects}
#    570976    0.082    0.000    0.082    0.000 {method 'keys' of 'dict' objects}
#         1    0.053    0.053    0.073    0.073 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_25768/2801194547.py:36(<listcomp>)
#    285488    0.053    0.000    0.053    0.000 {method 'values' of 'dict' objects}

# %% [markdown]
# ### Process a single component

# %%
from functools import lru_cache

@lru_cache(maxsize=None)
def combine_integers(*n: int) -> int:
    """
    Combine n integers into a single negative integer.

    Used to create a symmetric deterministic hash of two integers that populates the
    range of integers efficiently and reduces the likelihood of collisions.

    Aims to vectorise amazingly when used in Arrow.

    Does this by:

    * Using a Mersenne prime as a modulus
    * Making negative integers positive with modulo, sped up with bitwise operations
    * Combining using symmetric operations with coprime multipliers

    Args:
        *args: Variable number of integers to combine

    Returns:
        A negative integer
    """
    P = 2147483647

    total = 0
    product = 1

    for x in sorted(n):
        x_pos = (x ^ (x >> 31)) - (x >> 31)
        total = (total + x_pos) % P
        product = (product * x_pos) % P

    result = (31 * total + 37 * product) % P

    return -result

# %%
import numpy as np
from functools import lru_cache

@lru_cache(maxsize=None)
def combine_integers(*n: int) -> int:
    """Original function for single tuple of integers"""
    P = 2147483647

    total = 0
    product = 1

    for x in sorted(n):
        x_pos = (x ^ (x >> 31)) - (x >> 31)
        total = (total + x_pos) % P
        product = (product * x_pos) % P

    result = (31 * total + 37 * product) % P

    return -result

def vectorized_combine_integers(arrays: list[list[int]] | np.ndarray) -> np.ndarray:
    """
    Vectorized version of combine_integers that works on arrays of integer arrays.
    
    Args:
        arrays: List of integer arrays or 2D numpy array where each row is a set of integers
               to be combined
               
    Returns:
        1D numpy array of combined negative integers, one for each input array
    """
    P = 2147483647
    arrays = np.asarray(arrays)
    arrays = np.sort(arrays, axis=1)
    
    signs = arrays >> 31
    x_pos = (arrays ^ signs) - signs
    
    totals = np.sum(x_pos, axis=1) % P
    products = np.prod(x_pos, axis=1) % P
    
    results = (31 * totals + 37 * products) % P
    
    return -results

test_arrays = [
    # [1, 2, 3],
    # [-1, -2, -3],
    # [10, 20, 0],
    [10, 20, 0]
]

vectorized_results = vectorized_combine_integers(test_arrays)
original_results = np.array([combine_integers(*arr) for arr in test_arrays])

print("Vectorized results:", vectorized_results)
print("Original results:", original_results)
print("Match:", np.array_equal(vectorized_results, original_results))
# Out:
# Vectorized results: [-930]
# Original results: [-930]
# Match: True

# %%
import numpy as np
import time
from typing import List, Tuple
import random

def generate_test_data(num_arrays: int, array_size: int) -> List[List[int]]:
    """Generate random test arrays"""
    return [
        [random.randint(-1000000, 1000000) for _ in range(array_size)]
        for _ in range(num_arrays)
    ]

def run_benchmark(arrays: List[List[int]]) -> Tuple[float, float]:
    """
    Run speed comparison between original and vectorized versions
    
    Returns:
        Tuple of (original_time, vectorized_time) in seconds
    """
    # Time original version
    start = time.time()
    original_results = [combine_integers(*arr) for arr in arrays]
    original_time = time.time() - start
    
    # Time vectorized version
    start = time.time()
    vectorized_results = vectorized_combine_integers(arrays)
    vectorized_time = time.time() - start
    
    # Verify results match
    assert np.array_equal(original_results, vectorized_results), "Results don't match!"
    
    return original_time, vectorized_time

# Run benchmarks with different sizes
test_sizes = [
    (100, 3),     # 100 arrays of size 3
    (1000, 3),    # 1000 arrays of size 3
    (10000, 3),   # 10000 arrays of size 3
    (100000, 3),  # 100000 arrays of size 3
]

print("Benchmark Results:")
print("-" * 60)
print(f"{'Size':>12} | {'Original (s)':>12} | {'Vectorized (s)':>12} | {'Speedup':>8}")
print("-" * 60)

for num_arrays, array_size in test_sizes:
    # Generate test data
    arrays = generate_test_data(num_arrays, array_size)
    
    # Run benchmark
    orig_time, vec_time = run_benchmark(arrays)
    speedup = orig_time / vec_time
    
    print(f"{num_arrays:>7}x{array_size:<4} | {orig_time:>12.4f} | {vec_time:>12.4f} | {speedup:>8.2f}x")
# Out:
# Benchmark Results:
# ------------------------------------------------------------
#         Size | Original (s) | Vectorized (s) |  Speedup
# ------------------------------------------------------------
#     100x3    |       0.0002 |       0.0003 |     0.75x
#    1000x3    |       0.0024 |       0.0016 |     1.46x
#   10000x3    |       0.0218 |       0.0057 |     3.81x
#  100000x3    |       0.2714 |       0.0585 |     4.64x

# %%
from itertools import chain
from functools import lru_cache

@lru_cache(maxsize=None)
def combine_strings(*n: str) -> str:
    """
    Combine n strings into a single string.

    Args:
        *args: Variable number of strings to combine
        
    Returns:
        A single string
    """
    letters = set(chain.from_iterable(n))
    return "".join(sorted(letters))


def vectorized_combine_strings(arrays: list[list[str]] | np.ndarray) -> np.ndarray:
    """
    Vectorized version of combine_strings that works on arrays of string arrays.
    
    Args:
        arrays: List of string arrays or 2D numpy array where each row is a set of 
               strings to be combined
               
    Returns:
        1D numpy array of combined strings, one for each input array
    """
    arrays = np.asarray(arrays, dtype=object)
    
    def process_row(row):
        return combine_strings(*row)
    
    vfunc = np.vectorize(process_row, signature='(n)->()', otypes=[object])
    return vfunc(arrays)

test_arrays = [
    ["abc", "def", "abd"],
    ["xyz", "xyy", "xzz"],
    ["hello", "world", "hello"]
]

vectorized_results = vectorized_combine_strings(test_arrays)
original_results = np.array([combine_strings(*arr) for arr in test_arrays])

print("Vectorized results:", vectorized_results)
print("Original results:", original_results)
print("Match:", np.array_equal(vectorized_results, original_results))
# Out:
# Vectorized results: ['abcdef' 'xyz' 'dehlorw']
# Original results: ['abcdef' 'xyz' 'dehlorw']
# Match: True

# %%
from collections import defaultdict
from typing import TypeVar, Generic, Hashable, Iterator
import pandas as pd

T = TypeVar('T', bound=Hashable)

class UnionFindWithDiff(Generic[T]):
    def __init__(self):
        self.parent: dict[T, T] = {}
        self.rank: dict[T, int] = {}
        self._shadow_parent: dict[T, T] = {}
        self._shadow_rank: dict[T, int] = {}
        self._pending_pairs: list[tuple[T, T]] = []
        
    def make_set(self, x: T) -> None:
        if x not in self.parent:
            self.parent[x] = x
            self.rank[x] = 0
    
    def find(self, x: T, parent_dict: dict[T, T] | None = None) -> T:
        if parent_dict is None:
            parent_dict = self.parent
            
        if x not in parent_dict:
            self.make_set(x)
            if parent_dict is self._shadow_parent:
                self._shadow_parent[x] = x
                self._shadow_rank[x] = 0
        
        while parent_dict[x] != x:
            parent_dict[x] = parent_dict[parent_dict[x]]
            x = parent_dict[x]
        return x
    
    def union(self, x: T, y: T) -> None:
        root_x = self.find(x)
        root_y = self.find(y)
        
        if root_x != root_y:
            self._pending_pairs.append((x, y))
            
            if self.rank[root_x] < self.rank[root_y]:
                root_x, root_y = root_y, root_x
            self.parent[root_y] = root_x
            if self.rank[root_x] == self.rank[root_y]:
                self.rank[root_x] += 1
    
    def get_component(self, x: T, parent_dict: dict[T, T] | None = None) -> set[T]:
        if parent_dict is None:
            parent_dict = self.parent
        
        root = self.find(x, parent_dict)
        return {y for y in parent_dict if self.find(y, parent_dict) == root}
    
    def get_components(self, parent_dict: dict[T, T] | None = None) -> list[set[T]]:
        if parent_dict is None:
            parent_dict = self.parent
            
        components = defaultdict(set)
        for x in parent_dict:
            root = self.find(x, parent_dict)
            components[root].add(x)
        return list(components.values())
    
    def diff(self) -> Iterator[tuple[set[T], set[T]]]:
        """
        Returns differences including all pairwise merges that occurred since last diff,
        excluding cases where old_comp == new_comp.
        """
        # Get current state before processing pairs
        current_components = self.get_components()
        reported_pairs = set()
        
        # Process pending pairs
        for x, y in self._pending_pairs:
            # Find the final component containing the pair
            final_component = next(comp for comp in current_components 
                                 if x in comp and y in comp)
            
            # Only report if the pair forms a proper subset of the final component
            pair_component = {x, y}
            if (pair_component != final_component and 
                frozenset((frozenset(pair_component), frozenset(final_component))) not in reported_pairs):
                reported_pairs.add(frozenset((frozenset(pair_component), frozenset(final_component))))
                yield (pair_component, final_component)
        
        self._pending_pairs.clear()
        
        # Handle initial state
        if not self._shadow_parent:
            self._shadow_parent = self.parent.copy()
            self._shadow_rank = self.rank.copy()
            return
        
        # Get old components
        old_components = self.get_components(self._shadow_parent)
        
        # Report changes between old and new states
        for old_comp in old_components:
            if len(old_comp) > 1:  # Only consider non-singleton old components
                sample_elem = next(iter(old_comp))
                new_comp = next(comp for comp in current_components if sample_elem in comp)
                
                # Only yield if the components are different and this pair hasn't been reported
                if (old_comp != new_comp and 
                    frozenset((frozenset(old_comp), frozenset(new_comp))) not in reported_pairs):
                    reported_pairs.add(frozenset((frozenset(old_comp), frozenset(new_comp))))
                    yield (old_comp, new_comp)
        
        # Update shadow copy
        self._shadow_parent = self.parent.copy()
        self._shadow_rank = self.rank.copy()


def component_to_hierarchy(key: str | int | tuple, df: pd.DataFrame) -> pd.DataFrame:
    """
    Convert pairwise probabilities into a hierarchical representation.
    Assumes data is pre-sorted by probability descending.
    
    Args:
        key: Group key (ignored in this implementation)
        df: DataFrame with columns ['left', 'right', 'probability']
    
    Returns:
        DataFrame with columns ['parent', 'child', 'probability'] representing hierarchical merges
    """
    hierarchy: list[tuple[int, int, float]] = []
    uf = UnionFindWithDiff[int]()

    for threshold in df["probability"].unique():
        current_probs = df[df["probability"] == threshold]

        for _, row in current_probs.iterrows():
            uf.union(row["left"], row["right"])
            parent = combine_integers(row["left"], row["right"])
            hierarchy.extend([
                (parent, row["left"], threshold),
                (parent, row["right"], threshold)
            ])

        for old_comp, new_comp in uf.diff():
            if len(old_comp) > 1:
                parent = combine_integers(*new_comp)
                child = combine_integers(*old_comp)
                hierarchy.extend([
                    (parent, child, threshold)
                ])
            else:
                parent = combine_integers(*new_comp)
                hierarchy.extend([
                    (parent, old_comp.pop(), threshold)
                ])

    return pd.DataFrame(hierarchy, columns=['parent', 'child', 'probability'])

# %%
df = cc2.to_pandas()
cc_15_pd = df[df['component'] == 15]

# %%
import cProfile
import pstats
from pstats import SortKey

# Profile the function
pr = cProfile.Profile()
pr.enable()
_ = component_to_hierarchy(15, cc_15_pd)
pr.disable()

# Print stats sorted by cumulative time
ps = pstats.Stats(pr).sort_stats(SortKey.CUMULATIVE)
ps.print_stats(20)  # Show top 20 lines
# Out:
#          142304 function calls (139675 primitive calls) in 0.136 seconds
#
#    Ordered by: cumulative time
#    List reduced from 276 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.136    0.068 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3541(run_code)
#         2    0.000    0.000    0.136    0.068 {built-in method builtins.exec}
#         1    0.000    0.000    0.136    0.136 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_68435/3996032216.py:1(<module>)
#         1    0.007    0.007    0.136    0.136 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_68435/807932433.py:115(component_to_hierarchy)
#       532    0.002    0.000    0.059    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/frame.py:1505(iterrows)
#       532    0.007    0.000    0.054    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/series.py:389(__init__)
#      3006    0.007    0.000    0.027    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/series.py:1095(__getitem__)
#       536    0.004    0.000    0.018    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/construction.py:517(sanitize_array)
#       298    0.003    0.000    0.017    0.000 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_68435/807932433.py:65(diff)
#        63    0.000    0.000    0.014    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4062(__getitem__)
#        61    0.007    0.000    0.013    0.000 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_68435/807932433.py:55(get_components)
#        31    0.000    0.000    0.012    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4130(_getitem_bool_array)
#      3006    0.004    0.000    0.012    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/series.py:1220(_get_value)
# 32333/32271    0.006    0.000    0.008    0.000 {built-in method builtins.isinstance}
#       504    0.005    0.000    0.008    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/dtypes/cast.py:1156(maybe_infer_to_datetimelike)
#        31    0.000    0.000    0.008    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/ops/common.py:62(new_method)
#       594    0.002    0.000    0.007    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/generic.py:6301(__setattr__)
#        31    0.000    0.000    0.007    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/arraylike.py:38(__eq__)
#        31    0.000    0.000    0.007    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/generic.py:4142(_take_with_is_copy)
#        31    0.000    0.000    0.007    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/pandas/core/series.py:6110(_cmp_method)

# %%
import numpy as np
from typing import TypeVar, Generic, Hashable, Iterator, Optional, Dict
from collections import defaultdict

T = TypeVar('T', bound=Hashable)

class NumpyUnionFindWithDiff(Generic[T]):
    def __init__(self, max_size: int = 1000000):
        # Core numpy arrays for fast operations
        self.parent = np.arange(max_size, dtype=np.int32)
        self.rank = np.zeros(max_size, dtype=np.int32)
        self.size = 0
        
        # Mapping between external IDs and array indices
        self.id_to_idx: Dict[T, int] = {}
        self.idx_to_id: Dict[int, T] = {}
        
        # Shadow state
        self._shadow_parent = np.arange(max_size, dtype=np.int32)
        self._shadow_rank = np.zeros(max_size, dtype=np.int32)
        self._pending_x = np.array([], dtype=np.int32)
        self._pending_y = np.array([], dtype=np.int32)
        
    def _get_idx(self, x: T) -> int:
        if x not in self.id_to_idx:
            idx = self.size
            self.id_to_idx[x] = idx
            self.idx_to_id[idx] = x
            self.size += 1
        return self.id_to_idx[x]
    
    def find_vec(self, indices: np.ndarray, parent_array: Optional[np.ndarray] = None) -> np.ndarray:
        if parent_array is None:
            parent_array = self.parent
            
        paths = indices.reshape(-1, 1)
        positions = np.zeros(len(indices), dtype=np.int32)
        max_length = 32
        full_paths = np.zeros((len(indices), max_length), dtype=np.int32)
        full_paths[:, 0] = indices
        
        while True:
            next_parent = parent_array[paths[:, -1]]
            if np.all(next_parent == paths[:, -1]):
                break
            positions += 1
            full_paths[:, positions] = next_parent
            paths = np.hstack([paths, next_parent.reshape(-1, 1)])
            
        roots = paths[:, -1]
        mask = full_paths != 0
        parent_array[full_paths[mask]] = np.repeat(roots, mask.sum(axis=1))
        
        return roots
    
    def union_vectorized(self, x_vec: np.ndarray, y_vec: np.ndarray) -> None:
        x_idx = np.array([self._get_idx(x) for x in x_vec])
        y_idx = np.array([self._get_idx(y) for y in y_vec])
        
        for i in range(len(x_idx)):
            root_x = self.find_vec(np.array([x_idx[i]]))[0]
            root_y = self.find_vec(np.array([y_idx[i]]))[0]
            
            if root_x != root_y:
                self._pending_x = np.append(self._pending_x, x_idx[i])
                self._pending_y = np.append(self._pending_y, y_idx[i])
                
                if self.rank[root_x] < self.rank[root_y]:
                    root_x, root_y = root_y, root_x
                    
                self.parent[root_y] = root_x
                
                if self.rank[root_x] == self.rank[root_y]:
                    self.rank[root_x] += 1

    def get_components(self, parent_array: Optional[np.ndarray] = None) -> list[set[int]]:
        if parent_array is None:
            parent_array = self.parent
            
        all_indices = np.arange(self.size)
        roots = self.find_vec(all_indices, parent_array)
        unique_roots = np.unique(roots)
        
        components = []
        for root in unique_roots:
            comp_indices = all_indices[roots == root]
            if len(comp_indices) > 1:  # Only include non-singleton components
                components.append({self.idx_to_id[i] for i in comp_indices})
        return components

    def diff(self) -> tuple[np.ndarray, np.ndarray]:
        if len(self._pending_x) == 0:
            if not hasattr(self, '_initialized_shadow'):
                self._shadow_parent[:] = self.parent
                self._shadow_rank[:] = self.rank
                self._initialized_shadow = True
            return np.array([], dtype=object), np.array([], dtype=object)
        
        # Get current final state
        final_components = self.get_components()
        changes = set()
        
        # Process pending pairs
        all_indices = np.arange(self.size)
        current_roots = self.find_vec(all_indices)
        
        for x_idx, y_idx in zip(self._pending_x, self._pending_y):
            # Get the final component containing this pair
            final_root = self.find_vec(np.array([x_idx]))[0]
            final_comp = next(comp for comp in final_components 
                            if self.idx_to_id[x_idx] in comp)
            
            # Add the direct pair change
            pair_comp = frozenset({self.idx_to_id[x_idx], self.idx_to_id[y_idx]})
            if pair_comp != final_comp:
                changes.add((pair_comp, frozenset(final_comp)))

        # Process changes from old state
        if hasattr(self, '_initialized_shadow'):
            old_components = self.get_components(self._shadow_parent)
            
            # For each old component
            for old_comp in old_components:
                # Find which final component contains this old component
                sample_elem = next(iter(old_comp))
                sample_idx = self._get_idx(sample_elem)
                final_root = self.find_vec(np.array([sample_idx]))[0]
                final_comp = next(comp for comp in final_components 
                                if self.idx_to_id[sample_idx] in comp)
                
                if old_comp != final_comp:
                    changes.add((frozenset(old_comp), frozenset(final_comp)))
        
        # Update shadow state and clear pending
        self._shadow_parent[:] = self.parent
        self._shadow_rank[:] = self.rank
        self._initialized_shadow = True
        self._pending_x = np.array([], dtype=np.int32)
        self._pending_y = np.array([], dtype=np.int32)
        
        if not changes:
            return np.array([], dtype=object), np.array([], dtype=object)
        
        # Convert changes to numpy arrays
        changes_list = list(changes)
        old_comps = np.array([np.array(list(old_comp)) for old_comp, _ in changes_list], dtype=object)
        new_comps = np.array([np.array(list(new_comp)) for _, new_comp in changes_list], dtype=object)
        
        return old_comps, new_comps


def component_to_hierarchy_pa(table: pa.Table) -> pa.Table:
    """
    Convert pairwise probabilities into a hierarchical representation.
    Assumes data is pre-sorted by probability descending.
    
    Args:
        key: Group key (ignored in this implementation)
        table: Arrow Table with columns ['left', 'right', 'probability']
    
    Returns:
        Arrow Table with columns ['parent', 'child', 'probability'] representing hierarchical merges
    """
    hierarchy: list[tuple[int, int, float]] = []
    uf = NumpyUnionFindWithDiff[int]()

    # Get unique probabilities
    probs = pc.unique(table['probability'])

    for threshold in probs:
        # Get current probability rows
        mask = pc.equal(table['probability'], threshold)
        current_probs = table.filter(mask)
        threshold_float = float(threshold.as_py())
        
        # Process each row
        left = current_probs['left'].to_numpy()
        right = current_probs['right'].to_numpy()
        uf.union_vectorized(left, right)
        parent = vectorized_combine_integers([left, right])

        hierarchy.extend(
            list(zip(parent, left, [threshold_float] * len(parent))) +
            list(zip(parent, right, [threshold_float] * len(parent)))
        )
        
        # Process UnionFind diffs
        old_comps, new_comps = uf.diff()
        if len(old_comps) > 0:  # only if there are changes
            singles = np.array([len(comp) == 1 for comp in old_comps])
            multi_indices = ~singles
            single_indices = singles

            if multi_indices.any():
                parents = vectorized_combine_integers(new_comps[multi_indices])
                children = vectorized_combine_integers(old_comps[multi_indices])
                hierarchy.extend(list(zip(parents, children, [threshold_float] * len(parents))))

            if single_indices.any():
                parents = vectorized_combine_integers(new_comps[single_indices])
                children = old_comps[single_indices].ravel()  # automatically flattens single-element arrays
                hierarchy.extend(list(zip(parents, children, [threshold_float] * len(parents))))

    parents, children, probs = zip(*hierarchy)
    return pa.table({
        'parent': pa.array(parents, type=pa.int64()),
        'child': pa.array(children, type=pa.int64()),
        'probability': pa.array(probs, type=pa.float64())
    })

component_to_hierarchy_pa(cc_15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[128], line 211
#     204     parents, children, probs = zip(*hierarchy)
#     205     return pa.table({
#     206         'parent': pa.array(parents, type=pa.int64()),
#     207         'child': pa.array(children, type=pa.int64()),
#     208         'probability': pa.array(probs, type=pa.float64())
#     209     })
# --> 211 component_to_hierarchy_pa(cc_15)
#
# Cell In[128], line 168, in component_to_hierarchy_pa(table)
#     165 uf = NumpyUnionFindWithDiff[int]()
#     167 # Get unique probabilities
# --> 168 probs = pc.unique(table['probability'])
#     170 for threshold in probs:
#     171     # Get current probability rows
#     172     mask = pc.equal(table['probability'], threshold)
#
# File ~/DS/matchbox/.venv/lib/python3.11/site-packages/pyarrow/compute.py:247, in _make_generic_wrapper.<locals>.wrapper(memory_pool, *args)
#     245 if args and isinstance(args[0], Expression):
#     246     return Expression._call(func_name, list(args))
# --> 247 return func.call(args, None, memory_pool)
#
# File ~/DS/matchbox/.venv/lib/python3.11/site-packages/pyarrow/_compute.pyx:372, in pyarrow._compute.Function.call()
#
# File ~/DS/matchbox/.venv/lib/python3.11/site-packages/pyarrow/_compute.pyx:505, in pyarrow._compute._pack_compute_args()
#
# TypeError: Got unexpected argument type <class 'polars.series.series.Series'> for compute function

# %%
import numpy as np
from typing import Set, List, Tuple

# Helper function to convert numpy arrays to sets for comparison
def numpy_components_to_sets(old_comps: np.ndarray, new_comps: np.ndarray) -> List[Tuple[Set[int], Set[int]]]:
    if len(old_comps) == 0:
        return []
    return [(set(old.tolist()), set(new.tolist())) for old, new in zip(old_comps, new_comps)]

def test_implementations():
    # Initialize both implementations
    dict_uf = UnionFindWithDiff()
    numpy_uf = NumpyUnionFindWithDiff()
    
    # Test Case 1: Simple chain merge
    print("Test Case 1: Chain merge")
    # Dict version
    dict_uf = UnionFindWithDiff()
    dict_uf.union(1, 2)
    dict_uf.union(2, 3)
    dict_changes1 = list(dict_uf.diff())
    
    # Numpy version
    numpy_uf = NumpyUnionFindWithDiff()
    numpy_uf.union_vectorized(np.array([1, 2]), np.array([2, 3]))
    old_comps, new_comps = numpy_uf.diff()
    numpy_changes1 = numpy_components_to_sets(old_comps, new_comps)
    
    print("Dict version changes:", dict_changes1)
    print("Numpy version changes:", numpy_changes1)
    print("Match:", set(map(str, dict_changes1)) == set(map(str, numpy_changes1)))
    print()
    
    # Test Case 2: Star merge
    print("Test Case 2: Star merge")
    # Dict version
    dict_uf = UnionFindWithDiff()
    dict_uf.union(1, 2)
    dict_uf.union(1, 3)
    dict_uf.union(1, 4)
    dict_changes2 = list(dict_uf.diff())
    
    # Numpy version
    numpy_uf = NumpyUnionFindWithDiff()
    numpy_uf.union_vectorized(np.array([1, 1, 1]), np.array([2, 3, 4]))
    old_comps, new_comps = numpy_uf.diff()
    numpy_changes2 = numpy_components_to_sets(old_comps, new_comps)
    
    print("Dict version changes:", dict_changes2)
    print("Numpy version changes:", numpy_changes2)
    print("Match:", set(map(str, dict_changes2)) == set(map(str, numpy_changes2)))
    print()
    
    # Test Case 3: Merging existing components
    print("Test Case 3: Merging existing components")
    # Dict version
    dict_uf = UnionFindWithDiff()
    dict_uf.union(1, 2)
    dict_uf.union(3, 4)
    list(dict_uf.diff())  # Clear initial changes
    dict_uf.union(2, 3)
    dict_changes3 = list(dict_uf.diff())
    
    # Numpy version
    numpy_uf = NumpyUnionFindWithDiff()
    numpy_uf.union_vectorized(np.array([1, 3]), np.array([2, 4]))
    numpy_uf.diff()  # Clear initial changes
    numpy_uf.union_vectorized(np.array([2]), np.array([3]))
    old_comps, new_comps = numpy_uf.diff()
    numpy_changes3 = numpy_components_to_sets(old_comps, new_comps)
    
    print("Dict version changes:", dict_changes3)
    print("Numpy version changes:", numpy_changes3)
    print("Match:", set(map(str, dict_changes3)) == set(map(str, numpy_changes3)))

test_implementations()
# Out:
# Test Case 1: Chain merge
# Dict version changes: [({1, 2}, {1, 2, 3}), ({2, 3}, {1, 2, 3})]
# Numpy version changes: [({2, 3}, {1, 2, 3}), ({1, 2}, {1, 2, 3})]
# Match: True
#
# Test Case 2: Star merge
# Dict version changes: [({1, 2}, {1, 2, 3, 4}), ({1, 3}, {1, 2, 3, 4}), ({1, 4}, {1, 2, 3, 4})]
# Numpy version changes: [({1, 2}, {1, 2, 3, 4}), ({1, 4}, {1, 2, 3, 4}), ({1, 3}, {1, 2, 3, 4})]
# Match: True
#
# Test Case 3: Merging existing components
# Dict version changes: [({2, 3}, {1, 2, 3, 4}), ({1, 2}, {1, 2, 3, 4}), ({3, 4}, {1, 2, 3, 4})]
# Numpy version changes: [({1, 2}, {1, 2, 3, 4}), ({3, 4}, {1, 2, 3, 4}), ({2, 3}, {1, 2, 3, 4})]
# Match: True

# %%
import numpy as np
import time
from typing import Tuple, List
import pandas as pd
import matplotlib.pyplot as plt

def generate_random_pairs(size: int, num_pairs: int) -> Tuple[np.ndarray, np.ndarray]:
    """Generate random pairs of integers for testing"""
    x = np.random.randint(0, size, num_pairs)
    y = np.random.randint(0, size, num_pairs)
    return x, y

def benchmark_dict_version(x: np.ndarray, y: np.ndarray) -> float:
    """Benchmark dictionary-based implementation"""
    uf = UnionFindWithDiff()
    start = time.perf_counter()
    
    for xi, yi in zip(x, y):
        uf.union(int(xi), int(yi))
    list(uf.diff())  # Materialize the changes
    
    return time.perf_counter() - start

def benchmark_numpy_version(x: np.ndarray, y: np.ndarray) -> float:
    """Benchmark numpy-based implementation"""
    uf = NumpyUnionFindWithDiff()
    start = time.perf_counter()
    
    uf.union_vectorized(x, y)
    uf.diff()  # Get the changes
    
    return time.perf_counter() - start

def run_benchmarks() -> pd.DataFrame:
    """Run benchmarks with different input sizes"""
    # Test parameters
    sizes = [100, 1000, 10000]
    pairs_per_size = [10, 100, 1000]
    num_trials = 5
    
    results = []
    
    for size in sizes:
        for num_pairs in pairs_per_size:
            if num_pairs > size:
                continue
                
            dict_times = []
            numpy_times = []
            
            for _ in range(num_trials):
                # Generate random pairs
                x, y = generate_random_pairs(size, num_pairs)
                
                # Run benchmarks
                dict_time = benchmark_dict_version(x, y)
                numpy_time = benchmark_numpy_version(x, y)
                
                dict_times.append(dict_time)
                numpy_times.append(numpy_time)
            
            # Record average results
            results.append({
                'Size': size,
                'Num_Pairs': num_pairs,
                'Dict_Time': np.mean(dict_times),
                'Numpy_Time': np.mean(numpy_times),
                'Dict_Std': np.std(dict_times),
                'Numpy_Std': np.std(numpy_times),
                'Speedup': np.mean(dict_times) / np.mean(numpy_times)
            })
    
    return pd.DataFrame(results)

run_benchmarks()
# Out:
#     Size  Num_Pairs  Dict_Time  Numpy_Time  Dict_Std  Numpy_Std   Speedup
# 0    100         10   0.000074    0.002420  0.000010   0.000339  0.030523
# 1    100        100   0.000676    0.018620  0.000165   0.000740  0.036309
# 2   1000         10   0.000074    0.002496  0.000004   0.000256  0.029668
# 3   1000        100   0.000583    0.015933  0.000005   0.001204  0.036586
# 4   1000       1000   0.027857    0.232283  0.003230   0.016529  0.119926
# 5  10000         10   0.000072    0.002457  0.000007   0.000193  0.029138
# 6  10000        100   0.000600    0.014807  0.000026   0.000860  0.040527
# 7  10000       1000   0.018490    0.185388  0.001771   0.001559  0.099738

# %%
cc_15 = cc2.filter(pc.equal(cc2['component'], 15))

# %%
import cProfile
import pstats
from pstats import SortKey

# Profile the function
pr = cProfile.Profile()
pr.enable()
_ = component_to_hierarchy_pa(cc_15)
pr.disable()

# Print stats sorted by cumulative time
ps = pstats.Stats(pr).sort_stats(SortKey.CUMULATIVE)
ps.print_stats(20)  # Show top 20 lines
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[139], line 8
#       6 pr = cProfile.Profile()
#       7 pr.enable()
# ----> 8 _ = component_to_hierarchy_pa(cc_15)
#       9 pr.disable()
#      11 # Print stats sorted by cumulative time
#
# Cell In[128], line 195, in component_to_hierarchy_pa(table)
#     192 single_indices = singles
#     194 if multi_indices.any():
# --> 195     parents = vectorized_combine_integers(new_comps[multi_indices])
#     196     children = vectorized_combine_integers(old_comps[multi_indices])
#     197     hierarchy.extend(list(zip(parents, children, [threshold_float] * len(parents))))
#
# Cell In[104], line 34, in vectorized_combine_integers(arrays)
#      32 P = 2147483647
#      33 arrays = np.asarray(arrays)
# ---> 34 arrays = np.sort(arrays, axis=1)
#      36 signs = arrays >> 31
#      37 x_pos = (arrays ^ signs) - signs
#
# File ~/DS/matchbox/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:1136, in sort(a, axis, kind, order, stable)
#    1134 else:
#    1135     a = asanyarray(a).copy(order="K")
# -> 1136 a.sort(axis=axis, kind=kind, order=order, stable=stable)
#    1137 return a
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
P = 2147483647

cc_15.with_columns([
    pl.min_horizontal(['left', 'right']).abs().alias('smaller'),
    pl.max_horizontal(['left', 'right']).abs().alias('larger'),
]).with_columns([
    pl.col('smaller').add(pl.col('larger')).mod(P).alias('total2'),
    pl.col('smaller').mul(pl.col('larger')).mod(P).alias('prod2'),
]).with_columns([
    pl.col('total2').mul(31).add(pl.col('prod2').mul(37)).mod(P).neg().alias('parent')
]).select(["left", "right", "parent"])
# Out:
# shape: (501, 3)
# ┌────────┬────────┬─────────────┐
# │ left   ┆ right  ┆ parent      │
# │ ---    ┆ ---    ┆ ---         │
# │ i32    ┆ i32    ┆ i32         │
# ╞════════╪════════╪═════════════╡
# │ 81762  ┆ 389632 ┆ -1905962718 │
# │ 5063   ┆ 289249 ┆ -507336890  │
# │ 84647  ┆ 212390 ┆ -1629285124 │
# │ 175160 ┆ 262073 ┆ -1975619425 │
# │ 178519 ┆ 348267 ┆ -435576558  │
# │ …      ┆ …      ┆ …           │
# │ 12792  ┆ 227750 ┆ -428260364  │
# │ 71547  ┆ 331214 ┆ -641775315  │
# │ 66430  ┆ 329216 ┆ -1741711938 │
# │ 114817 ┆ 358133 ┆ -1027235085 │
# │ 88893  ┆ 202314 ┆ -1855621058 │
# └────────┴────────┴─────────────┘

# %%
cc_15.map_rows(lambda t: combine_integers(t[0], t[1]))
# Out:
# shape: (501, 1)
# ┌─────────────┐
# │ map         │
# │ ---         │
# │ i64         │
# ╞═════════════╡
# │ -1905963266 │
# │ -507336916  │
# │ -1629285434 │
# │ -1975620253 │
# │ -435577630  │
# │ …           │
# │ -428260452  │
# │ -641775761  │
# │ -1741712314 │
# │ -1027235831 │
# │ -1855621368 │
# └─────────────┘

# %%
import polars as pl

def component_to_hierarchy_pl(df: pl.DataFrame) -> pl.DataFrame:
    """
    Convert pairwise probabilities into a hierarchical representation using Polars.
    Assumes data is pre-sorted by probability descending.
    
    Args:
        key: Group key (ignored in this implementation)
        df: Polars DataFrame with columns ['left', 'right', 'probability']
    
    Returns:
        Polars DataFrame with columns ['parent', 'child', 'probability'] representing hierarchical merges
    """
    hierarchy: list[tuple[int, int, float]] = []
    uf = UnionFindWithDiff[int]()

    thresholds = df["probability"].unique(maintain_order=True)

    for threshold in thresholds:
        # Filter current probability rows and convert to Python objects for processing
        current_probs = df.filter(pl.col('probability') == threshold)
        
        # Process each row
        P = 2147483647

        current_probs = current_probs.with_columns([
            pl.min_horizontal(['left', 'right']).abs().alias('smaller'),
            pl.max_horizontal(['left', 'right']).abs().alias('larger'),
        ]).with_columns([
            pl.col('smaller').add(pl.col('larger')).mod(P).alias('total2'),
            pl.col('smaller').mul(pl.col('larger')).mod(P).alias('prod2'),
        ]).with_columns([
            pl.col('total2').mul(31).add(pl.col('prod2').mul(37)).mod(P).neg().alias('parent')
        ]).select(["left", "right", "parent"])

        for row in current_probs.iter_rows():
            uf.union(row[0], row[1])
            hierarchy.extend([
                (row[2], row[1], threshold),
                (row[2], row[0], threshold)
            ])

        # Process union-find differences
        for old_comp, new_comp in uf.diff():
            if len(old_comp) > 1:
                parent = combine_integers(*new_comp)
                child = combine_integers(*old_comp)
                hierarchy.extend([
                    (parent, child, threshold)
                ])
            else:
                parent = combine_integers(*new_comp)
                hierarchy.extend([
                    (parent, old_comp.pop(), threshold)
                ])

    # Convert the results to a Polars DataFrame
    return pl.DataFrame(
        hierarchy,
        schema={
            'parent': pl.Int32,
            'child': pl.Int32,
            'probability': pl.UInt8
        }
    )

# %%
import polars as pl

cc_15 = pl.from_arrow(cc2.filter(pc.equal(cc2['component'], 15)))
cc_15 = cc_15.with_columns(
    pl.col("probability").cast(pl.Float32).mul(100).cast(pl.UInt8).alias("probability"),
    pl.col("left").cast(pl.Int32),
    pl.col("right").cast(pl.Int32),
    pl.col("component").cast(pl.UInt32),
)
cc_15
# Out:
# shape: (501, 4)
# ┌────────┬────────┬─────────────┬───────────┐
# │ left   ┆ right  ┆ probability ┆ component │
# │ ---    ┆ ---    ┆ ---         ┆ ---       │
# │ i32    ┆ i32    ┆ u8          ┆ u32       │
# ╞════════╪════════╪═════════════╪═══════════╡
# │ 81762  ┆ 389632 ┆ 100         ┆ 15        │
# │ 5063   ┆ 289249 ┆ 100         ┆ 15        │
# │ 84647  ┆ 212390 ┆ 100         ┆ 15        │
# │ 175160 ┆ 262073 ┆ 100         ┆ 15        │
# │ 178519 ┆ 348267 ┆ 100         ┆ 15        │
# │ …      ┆ …      ┆ …           ┆ …         │
# │ 12792  ┆ 227750 ┆ 70          ┆ 15        │
# │ 71547  ┆ 331214 ┆ 70          ┆ 15        │
# │ 66430  ┆ 329216 ┆ 70          ┆ 15        │
# │ 114817 ┆ 358133 ┆ 70          ┆ 15        │
# │ 88893  ┆ 202314 ┆ 70          ┆ 15        │
# └────────┴────────┴─────────────┴───────────┘

# %%
import cProfile
import pstats
from pstats import SortKey

# Profile the function
pr = cProfile.Profile()
pr.enable()
_ = component_to_hierarchy_pl(cc_15)
pr.disable()

# Print stats sorted by cumulative time
ps = pstats.Stats(pr).sort_stats(SortKey.CUMULATIVE)
ps.print_stats(20)  # Show top 20 lines
# Out:
#          44754 function calls in 0.066 seconds
#
#    Ordered by: cumulative time
#    List reduced from 215 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.066    0.033 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3541(run_code)
#         2    0.000    0.000    0.066    0.033 {built-in method builtins.exec}
#         1    0.005    0.005    0.066    0.066 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_72030/1645101225.py:3(component_to_hierarchy_pl)
#       298    0.003    0.000    0.018    0.000 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_72030/807932433.py:65(diff)
#       156    0.001    0.000    0.017    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/lazyframe/frame.py:1824(collect)
#        93    0.001    0.000    0.016    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/dataframe/frame.py:9048(with_columns)
#       156    0.015    0.000    0.015    0.000 {method 'collect' of 'builtins.PyLazyFrame' objects}
#        61    0.007    0.000    0.014    0.000 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_72030/807932433.py:55(get_components)
#        31    0.000    0.000    0.008    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/dataframe/frame.py:4614(filter)
#       683    0.001    0.000    0.007    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/_utils/parse/expr.py:20(parse_into_expression)
#     11218    0.006    0.000    0.007    0.000 /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_72030/807932433.py:20(find)
#       218    0.000    0.000    0.005    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/_utils/parse/expr.py:78(parse_into_list_of_expressions)
#       218    0.001    0.000    0.005    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/_utils/parse/expr.py:108(_parse_positional_inputs)
#       186    0.002    0.000    0.003    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/functions/lit.py:23(lit)
#       435    0.001    0.000    0.003    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/functions/col.py:127(__call__)
#        93    0.001    0.000    0.003    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/lazyframe/frame.py:4710(with_columns)
#        31    0.000    0.000    0.003    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/dataframe/frame.py:8921(select)
#       218    0.001    0.000    0.003    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/_utils/parse/expr.py:114(<listcomp>)
#       435    0.001    0.000    0.003    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/functions/col.py:20(_create_col)
#        93    0.000    0.000    0.002    0.000 /Users/willlangdale/DS/matchbox/.venv/lib/python3.11/site-packages/polars/expr/expr.py:5469(mod)
# /var/folders/14/6nvsrw1n2ls1xncz_bvy2x8m0000gq/T/ipykernel_72030/1645101225.py:59: DataOrientationWarning: Row orientation inferred during DataFrame construction. Explicitly specify the orientation by passing `orient="row"` to silence this warning.
#   return pl.DataFrame(

# %%
from unittest.mock import patch

test_cases = [
    # Test case 1: Equal probabilities
    (
        {
            "left": ["a", "b", "c"],
            "right": ["b", "c", "d"],
            "probability": [1.0, 1.0, 1.0],
        },
        {
            ("ab", "a", 1.0),
            ("ab", "b", 1.0),
            ("bc", "b", 1.0),
            ("bc", "c", 1.0),
            ("cd", "c", 1.0),
            ("cd", "d", 1.0),
            ("abcd", "ab", 1.0),
            ("abcd", "bc", 1.0),
            ("abcd", "cd", 1.0),
        },
    ),
    # Test case 2: Asymmetric probabilities
    (
        {
            "left": ["w", "x", "y"],
            "right": ["x", "y", "z"],
            "probability": [0.9, 0.85, 0.8],
        },
        {
            ("wx", "w", 0.9),
            ("wx", "x", 0.9),
            ("xy", "x", 0.85),
            ("xy", "y", 0.85),
            ("wxy", "wx", 0.85),
            ("wxy", "xy", 0.85),
            ("yz", "y", 0.8),
            ("yz", "z", 0.8),
            ("wxyz", "wxy", 0.8),
            ("wxyz", "yz", 0.8),
        },
    ),
    # Test case 3: Single two-item component
    (
        {
            "left": ["x"],
            "right": ["y"],
            "probability": [0.9],
        },
        {
            ("xy", "x", 0.9),
            ("xy", "y", 0.9),
        },
    ),
]

for i, (prob_data, expected_relations) in enumerate(test_cases, 1):
    print(f"\nRunning test case {i}...")
    
    with patch('__main__.combine_integers', side_effect=combine_strings):
        # Pandas
        # probabilities = (
        #     pd.DataFrame.from_dict(prob_data)
        #     .assign(probability=lambda df: df['probability'].astype(float))
        #     .sort_values(by="probability", ascending=False)
        # )
        # hierarchy_true = (
        #         pd.DataFrame.from_records(
        #         list(expected_relations), 
        #         columns=["parent", "child", "probability"]
        #     )
        #     .sort_values(by=["probability", "parent", "child"], ascending=[False, True, True])
        #     .dropna(how='all')
        #     .reset_index(drop=True)
        # )

        # hierarchy = component_to_hierarchy(0, probabilities)

        # hierarchy = hierarchy.sort_values(
        #     by=["probability", "parent", "child"],
        #     ascending=[False, True, True]
        # ).reset_index(drop=True)

        # Arrow
        # probabilities = (
        #     pa.Table.from_pydict(prob_data)
        #     .cast(pa.schema([
        #         ('left', pa.string()),
        #         ('right', pa.string()),
        #         ('probability', pa.float64()),
        #     ]))
        #     .sort_by([('probability', 'descending')])
        # )

        # parents, children, probs = zip(*expected_relations)

        # hierarchy_true = (
        #     pa.table(
        #         [parents, children, probs], 
        #         names=['parent', 'child', 'probability']
        #     )
        #     .sort_by([
        #         ('probability', 'descending'),
        #         ('parent', 'ascending'),
        #         ('child', 'ascending')
        #     ])
        #     .filter(pc.is_valid(pc.field('parent')))
        # )

        # hierarchy = (
        #     component_to_hierarchy_pa(probabilities)
        #     .sort_by([
        #         ('probability', 'descending'),
        #         ('parent', 'ascending'),
        #         ('child', 'ascending')
        #     ])
        # )

        # Polars
        
        try:
            assert hierarchy.equals(hierarchy_true)
            print(f"✓ Test case {i} passed")
        except AssertionError:
            print(f"✗ Test case {i} failed")
            print("\nExpected DataFrame:")
            print(hierarchy_true)
            print("\nActual DataFrame:")
            print(hierarchy)
            print("\nDifferences:")
            if hierarchy.shape != hierarchy_true.shape:
                print(f"Shape mismatch: Expected {hierarchy_true.shape}, got {hierarchy.shape}")
            else:
                # Show where values differ
                differences = (hierarchy != hierarchy_true).any(axis=1)
                if differences.any():
                    print("\nMismatched rows:")
                    print("Expected:")
                    print(hierarchy_true[differences])
                    print("\nGot:")
                    print(hierarchy[differences])
            # Continue to next test case instead of raising
            continue
# Out:
# Running test case 1...
# ✓ Test case 1 passed
#
# Running test case 2...
# ✓ Test case 2 passed
#
# Running test case 3...
# ✓ Test case 3 passed

# %% [markdown]
# ### Process all components in parallel

# %%
import pyarrow.parquet as pq

h2 = pq.read_table('hierarchical_cc2k.parquet')
cc2 = attach_independent_components(h2)

h200 = pq.read_table('hierarchical_cc200k.parquet')
cc200 = attach_independent_components(h200)

# %%
import pyarrow as pa
import dask.dataframe as dd
import pandas as pd
from multiprocessing import cpu_count
from dask.distributed import Client, LocalCluster

def setup_client(port: int = 8787) -> Client:
    """
    Creates a Dask client optimized for local computation.
    Returns the client object.
    """
    try:
        client = Client(f'tcp://localhost:{port}')
    except Exception:
        n_workers = cpu_count()
        cluster = LocalCluster(
            dashboard_address=f':{port}',
            n_workers=n_workers,
            threads_per_worker=1,  # One thread per worker for CPU-bound tasks
            memory_limit='auto'    # Automatically determine memory limits
        )
        client = Client(cluster)
    return client

# %%
from cluster import component_to_hierarchy

def to_hierarchical_clusters(client: Client, table: pa.Table) -> pd.DataFrame:
    """
    Perform hierarchical clustering on an Arrow table of pairwise probabilities.
    """
    pdf = table.to_pandas()
    
    ddf = dd.from_pandas(
        pdf, 
        npartitions=len(client.cluster.worker_spec)
    )
    
    result_ddf = ddf.groupby('component').apply(
        component_to_hierarchy, 
        meta={
            'parent': int, 
            'child': int, 
            'probability': float
        }
    )
    
    return result_ddf.compute()

# %%
with setup_client(port=8787) as client:
    h_out = to_hierarchical_clusters(client, cc2)

h_out
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 with setup_client(port=8787) as client:
#       2     h_out = to_hierarchical_clusters(client, cc2)
#       4 h_out
#
# Cell In[15], line 13, in setup_client(port)
#       8 """
#       9 Creates a Dask client optimized for local computation.
#      10 Returns the client object.
#      11 """
#      12 try:
# ---> 13     client = Client(f'tcp://localhost:{port}')
#      14 except Exception:
#      15     n_workers = cpu_count()
#
# File ~/DS/matchbox/.venv/lib/python3.11/site-packages/distributed/client.py:1231, in Client.__init__(self, address, loop, timeout, set_as_default, scheduler_file, security, asynchronous, name, heartbeat_interval, serializers, deserializers, extensions, direct_to_workers, connection_limit, **kwargs)
#    1228 preload_argv = dask.config.get("distributed.client.preload-argv")
#    1229 self.preloads = preloading.process_preloads(self, preload, preload_argv)
# -> 1231 self.start(timeout=timeout)
#    1232 Client._instances.add(self)
#    1234 from distributed.recreate_tasks import ReplayTaskClient
#
# File ~/DS/matchbox/.venv/lib/python3.11/site-packages/distributed/client.py:1433, in Client.start(self, **kwargs)
#    1431     self._started = asyncio.ensure_future(self._start(**kwargs))
#    1432 else:
# -> 1433     sync(self.loop, self._start, **kwargs)
#
# File ~/DS/matchbox/.venv/lib/python3.11/site-packages/distributed/utils.py:436, in sync(loop, func, callback_timeout, *args, **kwargs)
#     434 else:
#     435     while not e.is_set():
# --> 436         wait(10)
#     438 if error is not None:
#     439     raise error
#
# File ~/DS/matchbox/.venv/lib/python3.11/site-packages/distributed/utils.py:425, in sync.<locals>.wait(timeout)
#     423 def wait(timeout: float | None) -> bool:
#     424     try:
# --> 425         return e.wait(timeout)
#     426     except KeyboardInterrupt:
#     427         loop.add_callback(cancel)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/threading.py:629, in Event.wait(self, timeout)
#     627 signaled = self._flag
#     628 if not signaled:
# --> 629     signaled = self._cond.wait(timeout)
#     630 return signaled
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
import pyarrow as pa
import pyarrow.compute as pc
from concurrent.futures import ProcessPoolExecutor
import multiprocessing
from cluster import component_to_hierarchy_pa
import logging
import time

def to_hierarchical_clusters_pa(table: pa.Table) -> pa.Table:
    """
    Parallel processing of components using Arrow.
    """
    logging.info(f"Starting processing with table size: {len(table)}")
    components = pc.unique(table['component'])
    logging.info(f"Found {len(components)} unique components")
    n_cores = multiprocessing.cpu_count() + 4
    results = []
    
    with ProcessPoolExecutor(max_workers=n_cores) as executor:
        futures = []
        for i, comp in enumerate(components):
            t_start = time.time()
            mask = pc.equal(table["component"], comp)
            component_table = table.filter(mask)
            logging.info(f"Component {i}: size {len(component_table)}")
            futures.append(executor.submit(component_to_hierarchy_pa, component_table))
            logging.info(f"Component {i}: submission took {time.time() - t_start:.2f}s")
            
        for i, future in enumerate(futures):
            t_start = time.time()
            results.append(future.result())
            logging.info(f"Component {i}: processing took {time.time() - t_start:.2f}s")

    return pa.concat_tables(results) if results else pa.table({
        'parent': pa.array([], type=pa.int64()),
        'child': pa.array([], type=pa.int64()),
        'probability': pa.array([], type=pa.float64())
    })

# %%
# Clear existing handlers
for handler in logging.root.handlers[:]:
    logging.root.removeHandler(handler)

# Setup logging
logging.basicConfig(level=logging.INFO)

# %%
h_out = to_hierarchical_clusters_pa(cc2)

h_out
# Out:
# INFO:root:Starting processing with table size: 1000400
# INFO:root:Found 2080 unique components
# INFO:root:Component 0: size 500
# INFO:root:Component 0: submission took 0.05s
# INFO:root:Component 1: size 500
# INFO:root:Component 1: submission took 0.05s
# INFO:root:Component 2: size 1
# INFO:root:Component 2: submission took 0.05s
# INFO:root:Component 3: size 501
# INFO:root:Component 3: submission took 0.05s
# INFO:root:Component 4: size 501
# INFO:root:Component 4: submission took 0.05s
# INFO:root:Component 5: size 501
# INFO:root:Component 5: submission took 0.06s
# INFO:root:Component 6: size 501
# INFO:root:Component 6: submission took 0.06s
# INFO:root:Component 7: size 501
# INFO:root:Component 7: submission took 0.06s
# INFO:root:Component 8: size 501
# INFO:root:Component 8: submission took 0.05s
# INFO:root:Component 9: size 501
# INFO:root:Component 9: submission took 0.05s
# INFO:root:Component 10: size 501
# INFO:root:Component 10: submission took 0.06s
# INFO:root:Component 11: size 501
# INFO:root:Component 11: submission took 0.06s
# INFO:root:Component 12: size 501
# INFO:root:Component 12: submission took 0.06s
# INFO:root:Component 13: size 501
# INFO:root:Component 13: submission took 0.06s
# INFO:root:Component 14: size 501
# INFO:root:Component 14: submission took 0.08s
# INFO:root:Component 15: size 501
# INFO:root:Component 15: submission took 0.07s
# INFO:root:Component 16: size 501
# INFO:root:Component 16: submission took 0.07s
# INFO:root:Component 17: size 501
# INFO:root:Component 17: submission took 0.07s
# INFO:root:Component 18: size 501
# INFO:root:Component 18: submission took 0.08s
# INFO:root:Component 19: size 501
# INFO:root:Component 19: submission took 0.11s
# INFO:root:Component 20: size 501
# INFO:root:Component 20: submission took 0.00s
# INFO:root:Component 21: size 501
# INFO:root:Component 21: submission took 0.00s
# INFO:root:Component 22: size 501
# INFO:root:Component 22: submission took 0.00s
# INFO:root:Component 23: size 501
# INFO:root:Component 23: submission took 0.00s
# INFO:root:Component 24: size 500
# INFO:root:Component 24: submission took 0.00s
# INFO:root:Component 25: size 1
# INFO:root:Component 25: submission took 0.00s
# INFO:root:Component 26: size 501
# INFO:root:Component 26: submission took 0.01s
# INFO:root:Component 27: size 501
# INFO:root:Component 27: submission took 0.00s
# INFO:root:Component 28: size 501
# INFO:root:Component 28: submission took 0.00s
# INFO:root:Component 29: size 501
# INFO:root:Component 29: submission took 0.00s
# INFO:root:Component 30: size 501
# INFO:root:Component 30: submission took 0.00s
# INFO:root:Component 31: size 501
# INFO:root:Component 31: submission took 0.01s
# INFO:root:Component 32: size 501
# INFO:root:Component 32: submission took 0.00s
# INFO:root:Component 33: size 501
# INFO:root:Component 33: submission took 0.00s
# INFO:root:Component 34: size 501
# INFO:root:Component 34: submission took 0.00s
# INFO:root:Component 35: size 501
# INFO:root:Component 35: submission took 0.00s
# INFO:root:Component 36: size 501
# INFO:root:Component 36: submission took 0.00s
# INFO:root:Component 37: size 501
# INFO:root:Component 37: submission took 0.00s
# INFO:root:Component 38: size 501
# INFO:root:Component 38: submission took 0.00s
# INFO:root:Component 39: size 501
# INFO:root:Component 39: submission took 0.00s
# INFO:root:Component 40: size 501
# INFO:root:Component 40: submission took 0.00s
# INFO:root:Component 41: size 501
# INFO:root:Component 41: submission took 0.00s
# INFO:root:Component 42: size 501
# INFO:root:Component 42: submission took 0.00s
# INFO:root:Component 43: size 500
# INFO:root:Component 43: submission took 0.00s
# INFO:root:Component 44: size 1
# INFO:root:Component 44: submission took 0.00s
# INFO:root:Component 45: size 501
# INFO:root:Component 45: submission took 0.00s
# INFO:root:Component 46: size 501
# INFO:root:Component 46: submission took 0.00s
# INFO:root:Component 47: size 501
# INFO:root:Component 47: submission took 0.00s
# INFO:root:Component 48: size 501
# INFO:root:Component 48: submission took 0.00s
# INFO:root:Component 49: size 501
# INFO:root:Component 49: submission took 0.00s
# INFO:root:Component 50: size 501
# INFO:root:Component 50: submission took 0.00s
# INFO:root:Component 51: size 501
# INFO:root:Component 51: submission took 0.00s
# INFO:root:Component 52: size 501
# INFO:root:Component 52: submission took 0.00s
# INFO:root:Component 53: size 501
# INFO:root:Component 53: submission took 0.00s
# INFO:root:Component 54: size 501
# INFO:root:Component 54: submission took 0.00s
# INFO:root:Component 55: size 501
# INFO:root:Component 55: submission took 0.00s
# INFO:root:Component 56: size 501
# INFO:root:Component 56: submission took 0.00s
# INFO:root:Component 57: size 501
# INFO:root:Component 57: submission took 0.00s
# INFO:root:Component 58: size 501
# INFO:root:Component 58: submission took 0.00s
# INFO:root:Component 59: size 501
# INFO:root:Component 59: submission took 0.00s
# INFO:root:Component 60: size 501
# INFO:root:Component 60: submission took 0.00s
# INFO:root:Component 61: size 501
# INFO:root:Component 61: submission took 0.00s
# INFO:root:Component 62: size 501
# INFO:root:Component 62: submission took 0.01s
# INFO:root:Component 63: size 501
# INFO:root:Component 63: submission took 0.00s
# INFO:root:Component 64: size 501
# INFO:root:Component 64: submission took 0.00s
# INFO:root:Component 65: size 501
# INFO:root:Component 65: submission took 0.00s
# INFO:root:Component 66: size 501
# INFO:root:Component 66: submission took 0.00s
# INFO:root:Component 67: size 501
# INFO:root:Component 67: submission took 0.00s
# INFO:root:Component 68: size 501
# INFO:root:Component 68: submission took 0.00s
# INFO:root:Component 69: size 501
# INFO:root:Component 69: submission took 0.00s
# INFO:root:Component 70: size 501
# INFO:root:Component 70: submission took 0.00s
# INFO:root:Component 71: size 501
# INFO:root:Component 71: submission took 0.00s
# INFO:root:Component 72: size 501
# INFO:root:Component 72: submission took 0.00s
# INFO:root:Component 73: size 501
# INFO:root:Component 73: submission took 0.01s
# INFO:root:Component 74: size 501
# INFO:root:Component 74: submission took 0.01s
# INFO:root:Component 75: size 501
# INFO:root:Component 75: submission took 0.01s
# INFO:root:Component 76: size 501
# INFO:root:Component 76: submission took 0.00s
# INFO:root:Component 77: size 501
# INFO:root:Component 77: submission took 0.00s
# INFO:root:Component 78: size 501
# INFO:root:Component 78: submission took 0.00s
# INFO:root:Component 79: size 501
# INFO:root:Component 79: submission took 0.00s
# INFO:root:Component 80: size 501
# INFO:root:Component 80: submission took 0.00s
# INFO:root:Component 81: size 501
# INFO:root:Component 81: submission took 0.00s
# INFO:root:Component 82: size 501
# INFO:root:Component 82: submission took 0.00s
# INFO:root:Component 83: size 501
# INFO:root:Component 83: submission took 0.00s
# INFO:root:Component 84: size 501
# INFO:root:Component 84: submission took 0.00s
# INFO:root:Component 85: size 501
# INFO:root:Component 85: submission took 0.00s
# INFO:root:Component 86: size 501
# INFO:root:Component 86: submission took 0.00s
# INFO:root:Component 87: size 501
# INFO:root:Component 87: submission took 0.01s
# INFO:root:Component 88: size 501
# INFO:root:Component 88: submission took 0.00s
# INFO:root:Component 89: size 501
# INFO:root:Component 89: submission took 0.00s
# INFO:root:Component 90: size 501
# INFO:root:Component 90: submission took 0.00s
# INFO:root:Component 91: size 501
# INFO:root:Component 91: submission took 0.00s
# INFO:root:Component 92: size 501
# INFO:root:Component 92: submission took 0.00s
# INFO:root:Component 93: size 501
# INFO:root:Component 93: submission took 0.00s
# INFO:root:Component 94: size 501
# INFO:root:Component 94: submission took 0.00s
# INFO:root:Component 95: size 501
# INFO:root:Component 95: submission took 0.00s
# INFO:root:Component 96: size 501
# INFO:root:Component 96: submission took 0.00s
# INFO:root:Component 97: size 501
# INFO:root:Component 97: submission took 0.00s
# INFO:root:Component 98: size 501
# INFO:root:Component 98: submission took 0.00s
# INFO:root:Component 99: size 501
# INFO:root:Component 99: submission took 0.00s
# INFO:root:Component 100: size 501
# INFO:root:Component 100: submission took 0.01s
# INFO:root:Component 101: size 501
# INFO:root:Component 101: submission took 0.00s
# INFO:root:Component 102: size 501
# INFO:root:Component 102: submission took 0.00s
# INFO:root:Component 103: size 501
# INFO:root:Component 103: submission took 0.00s
# INFO:root:Component 104: size 501
# INFO:root:Component 104: submission took 0.01s
# INFO:root:Component 105: size 501
# INFO:root:Component 105: submission took 0.00s
# INFO:root:Component 106: size 501
# INFO:root:Component 106: submission took 0.00s
# INFO:root:Component 107: size 501
# INFO:root:Component 107: submission took 0.01s
# INFO:root:Component 108: size 501
# INFO:root:Component 108: submission took 0.00s
# INFO:root:Component 109: size 501
# INFO:root:Component 109: submission took 0.00s
# INFO:root:Component 110: size 501
# INFO:root:Component 110: submission took 0.01s
# INFO:root:Component 111: size 501
# INFO:root:Component 111: submission took 0.00s
# INFO:root:Component 112: size 501
# INFO:root:Component 112: submission took 0.00s
# INFO:root:Component 113: size 501
# INFO:root:Component 113: submission took 0.00s
# INFO:root:Component 114: size 501
# INFO:root:Component 114: submission took 0.00s
# INFO:root:Component 115: size 501
# INFO:root:Component 115: submission took 0.00s
# INFO:root:Component 116: size 501
# INFO:root:Component 116: submission took 0.00s
# INFO:root:Component 117: size 501
# INFO:root:Component 117: submission took 0.00s
# INFO:root:Component 118: size 501
# INFO:root:Component 118: submission took 0.00s
# INFO:root:Component 119: size 501
# INFO:root:Component 119: submission took 0.00s
# INFO:root:Component 120: size 501
# INFO:root:Component 120: submission took 0.00s
# INFO:root:Component 121: size 501
# INFO:root:Component 121: submission took 0.00s
# INFO:root:Component 122: size 501
# INFO:root:Component 122: submission took 0.01s
# INFO:root:Component 123: size 501
# INFO:root:Component 123: submission took 0.00s
# INFO:root:Component 124: size 501
# INFO:root:Component 124: submission took 0.00s
# INFO:root:Component 125: size 501
# INFO:root:Component 125: submission took 0.00s
# INFO:root:Component 126: size 501
# INFO:root:Component 126: submission took 0.00s
# INFO:root:Component 127: size 501
# INFO:root:Component 127: submission took 0.01s
# INFO:root:Component 128: size 501
# INFO:root:Component 128: submission took 0.00s
# INFO:root:Component 129: size 501
# INFO:root:Component 129: submission took 0.00s
# INFO:root:Component 130: size 501
# INFO:root:Component 130: submission took 0.00s
# INFO:root:Component 131: size 501
# INFO:root:Component 131: submission took 0.00s
# INFO:root:Component 132: size 501
# INFO:root:Component 132: submission took 0.00s
# INFO:root:Component 133: size 501
# INFO:root:Component 133: submission took 0.01s
# INFO:root:Component 134: size 501
# INFO:root:Component 134: submission took 0.00s
# INFO:root:Component 135: size 501
# INFO:root:Component 135: submission took 0.01s
# INFO:root:Component 136: size 501
# INFO:root:Component 136: submission took 0.00s
# INFO:root:Component 137: size 501
# INFO:root:Component 137: submission took 0.00s
# INFO:root:Component 138: size 501
# INFO:root:Component 138: submission took 0.00s
# INFO:root:Component 139: size 501
# INFO:root:Component 139: submission took 0.01s
# INFO:root:Component 140: size 501
# INFO:root:Component 140: submission took 0.00s
# INFO:root:Component 141: size 501
# INFO:root:Component 141: submission took 0.00s
# INFO:root:Component 142: size 500
# INFO:root:Component 142: submission took 0.01s
# INFO:root:Component 143: size 1
# INFO:root:Component 143: submission took 0.00s
# INFO:root:Component 144: size 501
# INFO:root:Component 144: submission took 0.00s
# INFO:root:Component 145: size 501
# INFO:root:Component 145: submission took 0.00s
# INFO:root:Component 146: size 501
# INFO:root:Component 146: submission took 0.00s
# INFO:root:Component 147: size 501
# INFO:root:Component 147: submission took 0.00s
# INFO:root:Component 148: size 501
# INFO:root:Component 148: submission took 0.00s
# INFO:root:Component 149: size 501
# INFO:root:Component 149: submission took 0.01s
# INFO:root:Component 150: size 500
# INFO:root:Component 150: submission took 0.00s
# INFO:root:Component 151: size 1
# INFO:root:Component 151: submission took 0.00s
# INFO:root:Component 152: size 501
# INFO:root:Component 152: submission took 0.00s
# INFO:root:Component 153: size 501
# INFO:root:Component 153: submission took 0.00s
# INFO:root:Component 154: size 501
# INFO:root:Component 154: submission took 0.00s
# INFO:root:Component 155: size 501
# INFO:root:Component 155: submission took 0.00s
# INFO:root:Component 156: size 501
# INFO:root:Component 156: submission took 0.01s
# INFO:root:Component 157: size 501
# INFO:root:Component 157: submission took 0.01s
# INFO:root:Component 158: size 501
# INFO:root:Component 158: submission took 0.00s
# INFO:root:Component 159: size 501
# INFO:root:Component 159: submission took 0.00s
# INFO:root:Component 160: size 501
# INFO:root:Component 160: submission took 0.00s
# INFO:root:Component 161: size 501
# INFO:root:Component 161: submission took 0.00s
# INFO:root:Component 162: size 501
# INFO:root:Component 162: submission took 0.00s
# INFO:root:Component 163: size 501
# INFO:root:Component 163: submission took 0.01s
# INFO:root:Component 164: size 501
# INFO:root:Component 164: submission took 0.01s
# INFO:root:Component 165: size 501
# INFO:root:Component 165: submission took 0.00s
# INFO:root:Component 166: size 501
# INFO:root:Component 166: submission took 0.00s
# INFO:root:Component 167: size 501
# INFO:root:Component 167: submission took 0.00s
# INFO:root:Component 168: size 501
# INFO:root:Component 168: submission took 0.00s
# INFO:root:Component 169: size 501
# INFO:root:Component 169: submission took 0.00s
# INFO:root:Component 170: size 501
# INFO:root:Component 170: submission took 0.00s
# INFO:root:Component 171: size 501
# INFO:root:Component 171: submission took 0.00s
# INFO:root:Component 172: size 501
# INFO:root:Component 172: submission took 0.00s
# INFO:root:Component 173: size 501
# INFO:root:Component 173: submission took 0.01s
# INFO:root:Component 174: size 501
# INFO:root:Component 174: submission took 0.01s
# INFO:root:Component 175: size 501
# INFO:root:Component 175: submission took 0.00s
# INFO:root:Component 176: size 501
# INFO:root:Component 176: submission took 0.02s
# INFO:root:Component 177: size 501
# INFO:root:Component 177: submission took 0.00s
# INFO:root:Component 178: size 501
# INFO:root:Component 178: submission took 0.01s
# INFO:root:Component 179: size 501
# INFO:root:Component 179: submission took 0.00s
# INFO:root:Component 180: size 501
# INFO:root:Component 180: submission took 0.00s
# INFO:root:Component 181: size 501
# INFO:root:Component 181: submission took 0.00s
# INFO:root:Component 182: size 501
# INFO:root:Component 182: submission took 0.01s
# INFO:root:Component 183: size 501
# INFO:root:Component 183: submission took 0.01s
# INFO:root:Component 184: size 501
# INFO:root:Component 184: submission took 0.00s
# INFO:root:Component 185: size 501
# INFO:root:Component 185: submission took 0.00s
# INFO:root:Component 186: size 501
# INFO:root:Component 186: submission took 0.00s
# INFO:root:Component 187: size 500
# INFO:root:Component 187: submission took 0.00s
# INFO:root:Component 188: size 1
# INFO:root:Component 188: submission took 0.01s
# INFO:root:Component 189: size 501
# INFO:root:Component 189: submission took 0.00s
# INFO:root:Component 190: size 501
# INFO:root:Component 190: submission took 0.00s
# INFO:root:Component 191: size 501
# INFO:root:Component 191: submission took 0.00s
# INFO:root:Component 192: size 501
# INFO:root:Component 192: submission took 0.00s
# INFO:root:Component 193: size 501
# INFO:root:Component 193: submission took 0.01s
# INFO:root:Component 194: size 501
# INFO:root:Component 194: submission took 0.00s
# INFO:root:Component 195: size 501
# INFO:root:Component 195: submission took 0.01s
# INFO:root:Component 196: size 501
# INFO:root:Component 196: submission took 0.01s
# INFO:root:Component 197: size 501
# INFO:root:Component 197: submission took 0.01s
# INFO:root:Component 198: size 501
# INFO:root:Component 198: submission took 0.00s
# INFO:root:Component 199: size 501
# INFO:root:Component 199: submission took 0.00s
# INFO:root:Component 200: size 501
# INFO:root:Component 200: submission took 0.01s
# INFO:root:Component 201: size 501
# INFO:root:Component 201: submission took 0.00s
# INFO:root:Component 202: size 501
# INFO:root:Component 202: submission took 0.00s
# INFO:root:Component 203: size 501
# INFO:root:Component 203: submission took 0.00s
# INFO:root:Component 204: size 501
# INFO:root:Component 204: submission took 0.00s
# INFO:root:Component 205: size 501
# INFO:root:Component 205: submission took 0.00s
# INFO:root:Component 206: size 501
# INFO:root:Component 206: submission took 0.01s
# INFO:root:Component 207: size 501
# INFO:root:Component 207: submission took 0.01s
# INFO:root:Component 208: size 501
# INFO:root:Component 208: submission took 0.00s
# INFO:root:Component 209: size 501
# INFO:root:Component 209: submission took 0.00s
# INFO:root:Component 210: size 501
# INFO:root:Component 210: submission took 0.01s
# INFO:root:Component 211: size 501
# INFO:root:Component 211: submission took 0.01s
# INFO:root:Component 212: size 501
# INFO:root:Component 212: submission took 0.01s
# INFO:root:Component 213: size 501
# INFO:root:Component 213: submission took 0.00s
# INFO:root:Component 214: size 501
# INFO:root:Component 214: submission took 0.01s
# INFO:root:Component 215: size 501
# INFO:root:Component 215: submission took 0.01s
# INFO:root:Component 216: size 501
# INFO:root:Component 216: submission took 0.00s
# INFO:root:Component 217: size 501
# INFO:root:Component 217: submission took 0.00s
# INFO:root:Component 218: size 501
# INFO:root:Component 218: submission took 0.01s
# INFO:root:Component 219: size 501
# INFO:root:Component 219: submission took 0.01s
# INFO:root:Component 220: size 501
# INFO:root:Component 220: submission took 0.00s
# INFO:root:Component 221: size 501
# INFO:root:Component 221: submission took 0.00s
# INFO:root:Component 222: size 501
# INFO:root:Component 222: submission took 0.01s
# INFO:root:Component 223: size 501
# INFO:root:Component 223: submission took 0.00s
# INFO:root:Component 224: size 501
# INFO:root:Component 224: submission took 0.00s
# INFO:root:Component 225: size 501
# INFO:root:Component 225: submission took 0.00s
# INFO:root:Component 226: size 501
# INFO:root:Component 226: submission took 0.00s
# INFO:root:Component 227: size 501
# INFO:root:Component 227: submission took 0.00s
# INFO:root:Component 228: size 501
# INFO:root:Component 228: submission took 0.00s
# INFO:root:Component 229: size 501
# INFO:root:Component 229: submission took 0.00s
# INFO:root:Component 230: size 501
# INFO:root:Component 230: submission took 0.00s
# INFO:root:Component 231: size 501
# INFO:root:Component 231: submission took 0.00s
# INFO:root:Component 232: size 501
# INFO:root:Component 232: submission took 0.00s
# INFO:root:Component 233: size 501
# INFO:root:Component 233: submission took 0.00s
# INFO:root:Component 234: size 501
# INFO:root:Component 234: submission took 0.01s
# INFO:root:Component 235: size 500
# INFO:root:Component 235: submission took 0.00s
# INFO:root:Component 236: size 1
# INFO:root:Component 236: submission took 0.01s
# INFO:root:Component 237: size 501
# INFO:root:Component 237: submission took 0.00s
# INFO:root:Component 238: size 501
# INFO:root:Component 238: submission took 0.01s
# INFO:root:Component 239: size 501
# INFO:root:Component 239: submission took 0.00s
# INFO:root:Component 240: size 501
# INFO:root:Component 240: submission took 0.00s
# INFO:root:Component 241: size 501
# INFO:root:Component 241: submission took 0.01s
# INFO:root:Component 242: size 501
# INFO:root:Component 242: submission took 0.00s
# INFO:root:Component 243: size 501
# INFO:root:Component 243: submission took 0.00s
# INFO:root:Component 244: size 501
# INFO:root:Component 244: submission took 0.00s
# INFO:root:Component 245: size 501
# INFO:root:Component 245: submission took 0.01s
# INFO:root:Component 246: size 501
# INFO:root:Component 246: submission took 0.01s
# INFO:root:Component 247: size 501
# INFO:root:Component 247: submission took 0.00s
# INFO:root:Component 248: size 501
# INFO:root:Component 248: submission took 0.00s
# INFO:root:Component 249: size 501
# INFO:root:Component 249: submission took 0.01s
# INFO:root:Component 250: size 501
# INFO:root:Component 250: submission took 0.00s
# INFO:root:Component 251: size 501
# INFO:root:Component 251: submission took 0.00s
# INFO:root:Component 252: size 501
# INFO:root:Component 252: submission took 0.00s
# INFO:root:Component 253: size 501
# INFO:root:Component 253: submission took 0.00s
# INFO:root:Component 254: size 501
# INFO:root:Component 254: submission took 0.00s
# INFO:root:Component 255: size 501
# INFO:root:Component 255: submission took 0.00s
# INFO:root:Component 256: size 501
# INFO:root:Component 256: submission took 0.00s
# INFO:root:Component 257: size 501
# INFO:root:Component 257: submission took 0.00s
# INFO:root:Component 258: size 501
# INFO:root:Component 258: submission took 0.00s
# INFO:root:Component 259: size 501
# INFO:root:Component 259: submission took 0.01s
# INFO:root:Component 260: size 501
# INFO:root:Component 260: submission took 0.01s
# INFO:root:Component 261: size 501
# INFO:root:Component 261: submission took 0.00s
# INFO:root:Component 262: size 501
# INFO:root:Component 262: submission took 0.00s
# INFO:root:Component 263: size 501
# INFO:root:Component 263: submission took 0.00s
# INFO:root:Component 264: size 501
# INFO:root:Component 264: submission took 0.00s
# INFO:root:Component 265: size 501
# INFO:root:Component 265: submission took 0.00s
# INFO:root:Component 266: size 501
# INFO:root:Component 266: submission took 0.00s
# INFO:root:Component 267: size 501
# INFO:root:Component 267: submission took 0.00s
# INFO:root:Component 268: size 501
# INFO:root:Component 268: submission took 0.01s
# INFO:root:Component 269: size 501
# INFO:root:Component 269: submission took 0.00s
# INFO:root:Component 270: size 501
# INFO:root:Component 270: submission took 0.00s
# INFO:root:Component 271: size 501
# INFO:root:Component 271: submission took 0.00s
# INFO:root:Component 272: size 501
# INFO:root:Component 272: submission took 0.01s
# INFO:root:Component 273: size 501
# INFO:root:Component 273: submission took 0.00s
# INFO:root:Component 274: size 501
# INFO:root:Component 274: submission took 0.01s
# INFO:root:Component 275: size 501
# INFO:root:Component 275: submission took 0.00s
# INFO:root:Component 276: size 501
# INFO:root:Component 276: submission took 0.00s
# INFO:root:Component 277: size 501
# INFO:root:Component 277: submission took 0.00s
# INFO:root:Component 278: size 501
# INFO:root:Component 278: submission took 0.00s
# INFO:root:Component 279: size 501
# INFO:root:Component 279: submission took 0.00s
# INFO:root:Component 280: size 501
# INFO:root:Component 280: submission took 0.01s
# INFO:root:Component 281: size 501
# INFO:root:Component 281: submission took 0.01s
# INFO:root:Component 282: size 501
# INFO:root:Component 282: submission took 0.00s
# INFO:root:Component 283: size 501
# INFO:root:Component 283: submission took 0.00s
# INFO:root:Component 284: size 501
# INFO:root:Component 284: submission took 0.00s
# INFO:root:Component 285: size 501
# INFO:root:Component 285: submission took 0.00s
# INFO:root:Component 286: size 501
# INFO:root:Component 286: submission took 0.01s
# INFO:root:Component 287: size 501
# INFO:root:Component 287: submission took 0.01s
# INFO:root:Component 288: size 501
# INFO:root:Component 288: submission took 0.01s
# INFO:root:Component 289: size 501
# INFO:root:Component 289: submission took 0.00s
# INFO:root:Component 290: size 501
# INFO:root:Component 290: submission took 0.00s
# INFO:root:Component 291: size 500
# INFO:root:Component 291: submission took 0.00s
# INFO:root:Component 292: size 1
# INFO:root:Component 292: submission took 0.00s
# INFO:root:Component 293: size 501
# INFO:root:Component 293: submission took 0.01s
# INFO:root:Component 294: size 501
# INFO:root:Component 294: submission took 0.00s
# INFO:root:Component 295: size 501
# INFO:root:Component 295: submission took 0.01s
# INFO:root:Component 296: size 501
# INFO:root:Component 296: submission took 0.00s
# INFO:root:Component 297: size 501
# INFO:root:Component 297: submission took 0.01s
# INFO:root:Component 298: size 501
# INFO:root:Component 298: submission took 0.00s
# INFO:root:Component 299: size 501
# INFO:root:Component 299: submission took 0.00s
# INFO:root:Component 300: size 501
# INFO:root:Component 300: submission took 0.00s
# INFO:root:Component 301: size 501
# INFO:root:Component 301: submission took 0.00s
# INFO:root:Component 302: size 501
# INFO:root:Component 302: submission took 0.01s
# INFO:root:Component 303: size 501
# INFO:root:Component 303: submission took 0.00s
# INFO:root:Component 304: size 501
# INFO:root:Component 304: submission took 0.00s
# INFO:root:Component 305: size 501
# INFO:root:Component 305: submission took 0.01s
# INFO:root:Component 306: size 501
# INFO:root:Component 306: submission took 0.01s
# INFO:root:Component 307: size 501
# INFO:root:Component 307: submission took 0.00s
# INFO:root:Component 308: size 501
# INFO:root:Component 308: submission took 0.01s
# INFO:root:Component 309: size 501
# INFO:root:Component 309: submission took 0.00s
# INFO:root:Component 310: size 501
# INFO:root:Component 310: submission took 0.01s
# INFO:root:Component 311: size 501
# INFO:root:Component 311: submission took 0.01s
# INFO:root:Component 312: size 501
# INFO:root:Component 312: submission took 0.00s
# INFO:root:Component 313: size 500
# INFO:root:Component 313: submission took 0.01s
# INFO:root:Component 314: size 1
# INFO:root:Component 314: submission took 0.00s
# INFO:root:Component 315: size 501
# INFO:root:Component 315: submission took 0.00s
# INFO:root:Component 316: size 501
# INFO:root:Component 316: submission took 0.00s
# INFO:root:Component 317: size 501
# INFO:root:Component 317: submission took 0.02s
# INFO:root:Component 318: size 501
# INFO:root:Component 318: submission took 0.00s
# INFO:root:Component 319: size 501
# INFO:root:Component 319: submission took 0.00s
# INFO:root:Component 320: size 501
# INFO:root:Component 320: submission took 0.00s
# INFO:root:Component 321: size 501
# INFO:root:Component 321: submission took 0.01s
# INFO:root:Component 322: size 501
# INFO:root:Component 322: submission took 0.01s
# INFO:root:Component 323: size 501
# INFO:root:Component 323: submission took 0.00s
# INFO:root:Component 324: size 501
# INFO:root:Component 324: submission took 0.00s
# INFO:root:Component 325: size 501
# INFO:root:Component 325: submission took 0.01s
# INFO:root:Component 326: size 501
# INFO:root:Component 326: submission took 0.00s
# INFO:root:Component 327: size 501
# INFO:root:Component 327: submission took 0.01s
# INFO:root:Component 328: size 501
# INFO:root:Component 328: submission took 0.00s
# INFO:root:Component 329: size 501
# INFO:root:Component 329: submission took 0.01s
# INFO:root:Component 330: size 501
# INFO:root:Component 330: submission took 0.00s
# INFO:root:Component 331: size 501
# INFO:root:Component 331: submission took 0.00s
# INFO:root:Component 332: size 501
# INFO:root:Component 332: submission took 0.00s
# INFO:root:Component 333: size 501
# INFO:root:Component 333: submission took 0.00s
# INFO:root:Component 334: size 501
# INFO:root:Component 334: submission took 0.00s
# INFO:root:Component 335: size 501
# INFO:root:Component 335: submission took 0.00s
# INFO:root:Component 336: size 501
# INFO:root:Component 336: submission took 0.00s
# INFO:root:Component 337: size 501
# INFO:root:Component 337: submission took 0.00s
# INFO:root:Component 338: size 501
# INFO:root:Component 338: submission took 0.00s
# INFO:root:Component 339: size 501
# INFO:root:Component 339: submission took 0.00s
# INFO:root:Component 340: size 501
# INFO:root:Component 340: submission took 0.00s
# INFO:root:Component 341: size 501
# INFO:root:Component 341: submission took 0.00s
# INFO:root:Component 342: size 501
# INFO:root:Component 342: submission took 0.01s
# INFO:root:Component 343: size 501
# INFO:root:Component 343: submission took 0.00s
# INFO:root:Component 344: size 501
# INFO:root:Component 344: submission took 0.01s
# INFO:root:Component 345: size 501
# INFO:root:Component 345: submission took 0.00s
# INFO:root:Component 346: size 501
# INFO:root:Component 346: submission took 0.00s
# INFO:root:Component 347: size 501
# INFO:root:Component 347: submission took 0.00s
# INFO:root:Component 348: size 501
# INFO:root:Component 348: submission took 0.00s
# INFO:root:Component 349: size 501
# INFO:root:Component 349: submission took 0.00s
# INFO:root:Component 350: size 501
# INFO:root:Component 350: submission took 0.01s
# INFO:root:Component 351: size 501
# INFO:root:Component 351: submission took 0.00s
# INFO:root:Component 352: size 501
# INFO:root:Component 352: submission took 0.01s
# INFO:root:Component 353: size 501
# INFO:root:Component 353: submission took 0.00s
# INFO:root:Component 354: size 501
# INFO:root:Component 354: submission took 0.00s
# INFO:root:Component 355: size 501
# INFO:root:Component 355: submission took 0.00s
# INFO:root:Component 356: size 501
# INFO:root:Component 356: submission took 0.00s
# INFO:root:Component 357: size 501
# INFO:root:Component 357: submission took 0.00s
# INFO:root:Component 358: size 501
# INFO:root:Component 358: submission took 0.00s
# INFO:root:Component 359: size 501
# INFO:root:Component 359: submission took 0.00s
# INFO:root:Component 360: size 501
# INFO:root:Component 360: submission took 0.00s
# INFO:root:Component 361: size 501
# INFO:root:Component 361: submission took 0.00s
# INFO:root:Component 362: size 501
# INFO:root:Component 362: submission took 0.00s
# INFO:root:Component 363: size 501
# INFO:root:Component 363: submission took 0.01s
# INFO:root:Component 364: size 501
# INFO:root:Component 364: submission took 0.01s
# INFO:root:Component 365: size 501
# INFO:root:Component 365: submission took 0.01s
# INFO:root:Component 366: size 501
# INFO:root:Component 366: submission took 0.01s
# INFO:root:Component 367: size 501
# INFO:root:Component 367: submission took 0.01s
# INFO:root:Component 368: size 500
# INFO:root:Component 368: submission took 0.00s
# INFO:root:Component 369: size 1
# INFO:root:Component 369: submission took 0.00s
# INFO:root:Component 370: size 501
# INFO:root:Component 370: submission took 0.00s
# INFO:root:Component 371: size 501
# INFO:root:Component 371: submission took 0.00s
# INFO:root:Component 372: size 501
# INFO:root:Component 372: submission took 0.00s
# INFO:root:Component 373: size 500
# INFO:root:Component 373: submission took 0.00s
# INFO:root:Component 374: size 1
# INFO:root:Component 374: submission took 0.01s
# INFO:root:Component 375: size 501
# INFO:root:Component 375: submission took 0.01s
# INFO:root:Component 376: size 501
# INFO:root:Component 376: submission took 0.00s
# INFO:root:Component 377: size 501
# INFO:root:Component 377: submission took 0.00s
# INFO:root:Component 378: size 501
# INFO:root:Component 378: submission took 0.00s
# INFO:root:Component 379: size 501
# INFO:root:Component 379: submission took 0.01s
# INFO:root:Component 380: size 501
# INFO:root:Component 380: submission took 0.00s
# INFO:root:Component 381: size 501
# INFO:root:Component 381: submission took 0.01s
# INFO:root:Component 382: size 501
# INFO:root:Component 382: submission took 0.01s
# INFO:root:Component 383: size 501
# INFO:root:Component 383: submission took 0.00s
# INFO:root:Component 384: size 500
# INFO:root:Component 384: submission took 0.01s
# INFO:root:Component 385: size 1
# INFO:root:Component 385: submission took 0.00s
# INFO:root:Component 386: size 501
# INFO:root:Component 386: submission took 0.01s
# INFO:root:Component 387: size 501
# INFO:root:Component 387: submission took 0.01s
# INFO:root:Component 388: size 501
# INFO:root:Component 388: submission took 0.00s
# INFO:root:Component 389: size 501
# INFO:root:Component 389: submission took 0.00s
# INFO:root:Component 390: size 501
# INFO:root:Component 390: submission took 0.01s
# INFO:root:Component 391: size 501
# INFO:root:Component 391: submission took 0.00s
# INFO:root:Component 392: size 501
# INFO:root:Component 392: submission took 0.01s
# INFO:root:Component 393: size 500
# INFO:root:Component 393: submission took 0.00s
# INFO:root:Component 394: size 1
# INFO:root:Component 394: submission took 0.01s
# INFO:root:Component 395: size 501
# INFO:root:Component 395: submission took 0.00s
# INFO:root:Component 396: size 501
# INFO:root:Component 396: submission took 0.00s
# INFO:root:Component 397: size 501
# INFO:root:Component 397: submission took 0.00s
# INFO:root:Component 398: size 501
# INFO:root:Component 398: submission took 0.00s
# INFO:root:Component 399: size 501
# INFO:root:Component 399: submission took 0.00s
# INFO:root:Component 400: size 501
# INFO:root:Component 400: submission took 0.01s
# INFO:root:Component 401: size 501
# INFO:root:Component 401: submission took 0.01s
# INFO:root:Component 402: size 501
# INFO:root:Component 402: submission took 0.01s
# INFO:root:Component 403: size 501
# INFO:root:Component 403: submission took 0.00s
# INFO:root:Component 404: size 501
# INFO:root:Component 404: submission took 0.00s
# INFO:root:Component 405: size 501
# INFO:root:Component 405: submission took 0.00s
# INFO:root:Component 406: size 501
# INFO:root:Component 406: submission took 0.00s
# INFO:root:Component 407: size 501
# INFO:root:Component 407: submission took 0.00s
# INFO:root:Component 408: size 501
# INFO:root:Component 408: submission took 0.00s
# INFO:root:Component 409: size 501
# INFO:root:Component 409: submission took 0.00s
# INFO:root:Component 410: size 501
# INFO:root:Component 410: submission took 0.00s
# INFO:root:Component 411: size 501
# INFO:root:Component 411: submission took 0.00s
# INFO:root:Component 412: size 501
# INFO:root:Component 412: submission took 0.01s
# INFO:root:Component 413: size 501
# INFO:root:Component 413: submission took 0.00s
# INFO:root:Component 414: size 500
# INFO:root:Component 414: submission took 0.01s
# INFO:root:Component 415: size 500
# INFO:root:Component 415: submission took 0.00s
# INFO:root:Component 416: size 500
# INFO:root:Component 416: submission took 0.00s
# INFO:root:Component 417: size 500
# INFO:root:Component 417: submission took 0.00s
# INFO:root:Component 418: size 500
# INFO:root:Component 418: submission took 0.00s
# INFO:root:Component 419: size 500
# INFO:root:Component 419: submission took 0.00s
# INFO:root:Component 420: size 500
# INFO:root:Component 420: submission took 0.00s
# INFO:root:Component 421: size 500
# INFO:root:Component 421: submission took 0.01s
# INFO:root:Component 422: size 500
# INFO:root:Component 422: submission took 0.00s
# INFO:root:Component 423: size 500
# INFO:root:Component 423: submission took 0.00s
# INFO:root:Component 424: size 500
# INFO:root:Component 424: submission took 0.00s
# INFO:root:Component 425: size 500
# INFO:root:Component 425: submission took 0.00s
# INFO:root:Component 426: size 500
# INFO:root:Component 426: submission took 0.00s
# INFO:root:Component 427: size 500
# INFO:root:Component 427: submission took 0.00s
# INFO:root:Component 428: size 500
# INFO:root:Component 428: submission took 0.01s
# INFO:root:Component 429: size 500
# INFO:root:Component 429: submission took 0.00s
# INFO:root:Component 430: size 500
# INFO:root:Component 430: submission took 0.00s
# INFO:root:Component 431: size 500
# INFO:root:Component 431: submission took 0.01s
# INFO:root:Component 432: size 500
# INFO:root:Component 432: submission took 0.00s
# INFO:root:Component 433: size 500
# INFO:root:Component 433: submission took 0.00s
# INFO:root:Component 434: size 500
# INFO:root:Component 434: submission took 0.00s
# INFO:root:Component 435: size 500
# INFO:root:Component 435: submission took 0.01s
# INFO:root:Component 436: size 500
# INFO:root:Component 436: submission took 0.00s
# INFO:root:Component 437: size 500
# INFO:root:Component 437: submission took 0.01s
# INFO:root:Component 438: size 500
# INFO:root:Component 438: submission took 0.00s
# INFO:root:Component 439: size 500
# INFO:root:Component 439: submission took 0.00s
# INFO:root:Component 440: size 500
# INFO:root:Component 440: submission took 0.01s
# INFO:root:Component 441: size 500
# INFO:root:Component 441: submission took 0.00s
# INFO:root:Component 442: size 499
# INFO:root:Component 442: submission took 0.00s
# INFO:root:Component 443: size 1
# INFO:root:Component 443: submission took 0.00s
# INFO:root:Component 444: size 500
# INFO:root:Component 444: submission took 0.00s
# INFO:root:Component 445: size 500
# INFO:root:Component 445: submission took 0.00s
# INFO:root:Component 446: size 500
# INFO:root:Component 446: submission took 0.01s
# INFO:root:Component 447: size 500
# INFO:root:Component 447: submission took 0.01s
# INFO:root:Component 448: size 500
# INFO:root:Component 448: submission took 0.00s
# INFO:root:Component 449: size 500
# INFO:root:Component 449: submission took 0.01s
# INFO:root:Component 450: size 500
# INFO:root:Component 450: submission took 0.00s
# INFO:root:Component 451: size 500
# INFO:root:Component 451: submission took 0.00s
# INFO:root:Component 452: size 500
# INFO:root:Component 452: submission took 0.00s
# INFO:root:Component 453: size 500
# INFO:root:Component 453: submission took 0.00s
# INFO:root:Component 454: size 500
# INFO:root:Component 454: submission took 0.00s
# INFO:root:Component 455: size 500
# INFO:root:Component 455: submission took 0.01s
# INFO:root:Component 456: size 500
# INFO:root:Component 456: submission took 0.00s
# INFO:root:Component 457: size 500
# INFO:root:Component 457: submission took 0.01s
# INFO:root:Component 458: size 500
# INFO:root:Component 458: submission took 0.00s
# INFO:root:Component 459: size 500
# INFO:root:Component 459: submission took 0.01s
# INFO:root:Component 460: size 500
# INFO:root:Component 460: submission took 0.00s
# INFO:root:Component 461: size 500
# INFO:root:Component 461: submission took 0.01s
# INFO:root:Component 462: size 500
# INFO:root:Component 462: submission took 0.01s
# INFO:root:Component 463: size 500
# INFO:root:Component 463: submission took 0.00s
# INFO:root:Component 464: size 500
# INFO:root:Component 464: submission took 0.01s
# INFO:root:Component 465: size 500
# INFO:root:Component 465: submission took 0.00s
# INFO:root:Component 466: size 500
# INFO:root:Component 466: submission took 0.01s
# INFO:root:Component 467: size 500
# INFO:root:Component 467: submission took 0.00s
# INFO:root:Component 468: size 500
# INFO:root:Component 468: submission took 0.00s
# INFO:root:Component 469: size 500
# INFO:root:Component 469: submission took 0.00s
# INFO:root:Component 470: size 500
# INFO:root:Component 470: submission took 0.01s
# INFO:root:Component 471: size 500
# INFO:root:Component 471: submission took 0.02s
# INFO:root:Component 472: size 500
# INFO:root:Component 472: submission took 0.00s
# INFO:root:Component 473: size 500
# INFO:root:Component 473: submission took 0.01s
# INFO:root:Component 474: size 500
# INFO:root:Component 474: submission took 0.00s
# INFO:root:Component 475: size 500
# INFO:root:Component 475: submission took 0.00s
# INFO:root:Component 476: size 500
# INFO:root:Component 476: submission took 0.00s
# INFO:root:Component 477: size 500
# INFO:root:Component 477: submission took 0.00s
# INFO:root:Component 478: size 500
# INFO:root:Component 478: submission took 0.00s
# INFO:root:Component 479: size 500
# INFO:root:Component 479: submission took 0.01s
# INFO:root:Component 480: size 500
# INFO:root:Component 480: submission took 0.00s
# INFO:root:Component 481: size 500
# INFO:root:Component 481: submission took 0.01s
# INFO:root:Component 482: size 500
# INFO:root:Component 482: submission took 0.01s
# INFO:root:Component 483: size 500
# INFO:root:Component 483: submission took 0.00s
# INFO:root:Component 484: size 500
# INFO:root:Component 484: submission took 0.01s
# INFO:root:Component 485: size 500
# INFO:root:Component 485: submission took 0.00s
# INFO:root:Component 486: size 500
# INFO:root:Component 486: submission took 0.00s
# INFO:root:Component 487: size 499
# INFO:root:Component 487: submission took 0.00s
# INFO:root:Component 488: size 1
# INFO:root:Component 488: submission took 0.00s
# INFO:root:Component 489: size 500
# INFO:root:Component 489: submission took 0.01s
# INFO:root:Component 490: size 500
# INFO:root:Component 490: submission took 0.01s
# INFO:root:Component 491: size 500
# INFO:root:Component 491: submission took 0.01s
# INFO:root:Component 492: size 500
# INFO:root:Component 492: submission took 0.01s
# INFO:root:Component 493: size 500
# INFO:root:Component 493: submission took 0.00s
# INFO:root:Component 494: size 500
# INFO:root:Component 494: submission took 0.00s
# INFO:root:Component 495: size 500
# INFO:root:Component 495: submission took 0.00s
# INFO:root:Component 496: size 500
# INFO:root:Component 496: submission took 0.00s
# INFO:root:Component 497: size 500
# INFO:root:Component 497: submission took 0.00s
# INFO:root:Component 498: size 500
# INFO:root:Component 498: submission took 0.01s
# INFO:root:Component 499: size 500
# INFO:root:Component 499: submission took 0.01s
# INFO:root:Component 500: size 500
# INFO:root:Component 500: submission took 0.01s
# INFO:root:Component 501: size 500
# INFO:root:Component 501: submission took 0.00s
# INFO:root:Component 502: size 500
# INFO:root:Component 502: submission took 0.00s
# INFO:root:Component 503: size 500
# INFO:root:Component 503: submission took 0.00s
# INFO:root:Component 504: size 500
# INFO:root:Component 504: submission took 0.00s
# INFO:root:Component 505: size 500
# INFO:root:Component 505: submission took 0.00s
# INFO:root:Component 506: size 500
# INFO:root:Component 506: submission took 0.00s
# INFO:root:Component 507: size 500
# INFO:root:Component 507: submission took 0.01s
# INFO:root:Component 508: size 500
# INFO:root:Component 508: submission took 0.01s
# INFO:root:Component 509: size 500
# INFO:root:Component 509: submission took 0.00s
# INFO:root:Component 510: size 500
# INFO:root:Component 510: submission took 0.01s
# INFO:root:Component 511: size 500
# INFO:root:Component 511: submission took 0.00s
# INFO:root:Component 512: size 500
# INFO:root:Component 512: submission took 0.00s
# INFO:root:Component 513: size 500
# INFO:root:Component 513: submission took 0.01s
# INFO:root:Component 514: size 500
# INFO:root:Component 514: submission took 0.00s
# INFO:root:Component 515: size 500
# INFO:root:Component 515: submission took 0.01s
# INFO:root:Component 516: size 500
# INFO:root:Component 516: submission took 0.00s
# INFO:root:Component 517: size 500
# INFO:root:Component 517: submission took 0.00s
# INFO:root:Component 518: size 500
# INFO:root:Component 518: submission took 0.00s
# INFO:root:Component 519: size 500
# INFO:root:Component 519: submission took 0.01s
# INFO:root:Component 520: size 500
# INFO:root:Component 520: submission took 0.00s
# INFO:root:Component 521: size 500
# INFO:root:Component 521: submission took 0.00s
# INFO:root:Component 522: size 500
# INFO:root:Component 522: submission took 0.00s
# INFO:root:Component 523: size 500
# INFO:root:Component 523: submission took 0.00s
# INFO:root:Component 524: size 500
# INFO:root:Component 524: submission took 0.00s
# INFO:root:Component 525: size 500
# INFO:root:Component 525: submission took 0.00s
# INFO:root:Component 526: size 500
# INFO:root:Component 526: submission took 0.00s
# INFO:root:Component 527: size 500
# INFO:root:Component 527: submission took 0.00s
# INFO:root:Component 528: size 500
# INFO:root:Component 528: submission took 0.01s
# INFO:root:Component 529: size 500
# INFO:root:Component 529: submission took 0.00s
# INFO:root:Component 530: size 500
# INFO:root:Component 530: submission took 0.00s
# INFO:root:Component 531: size 500
# INFO:root:Component 531: submission took 0.00s
# INFO:root:Component 532: size 500
# INFO:root:Component 532: submission took 0.00s
# INFO:root:Component 533: size 500
# INFO:root:Component 533: submission took 0.00s
# INFO:root:Component 534: size 500
# INFO:root:Component 534: submission took 0.00s
# INFO:root:Component 535: size 500
# INFO:root:Component 535: submission took 0.00s
# INFO:root:Component 536: size 500
# INFO:root:Component 536: submission took 0.00s
# INFO:root:Component 537: size 500
# INFO:root:Component 537: submission took 0.00s
# INFO:root:Component 538: size 500
# INFO:root:Component 538: submission took 0.01s
# INFO:root:Component 539: size 500
# INFO:root:Component 539: submission took 0.00s
# INFO:root:Component 540: size 500
# INFO:root:Component 540: submission took 0.00s
# INFO:root:Component 541: size 500
# INFO:root:Component 541: submission took 0.00s
# INFO:root:Component 542: size 499
# INFO:root:Component 542: submission took 0.00s
# INFO:root:Component 543: size 1
# INFO:root:Component 543: submission took 0.00s
# INFO:root:Component 544: size 500
# INFO:root:Component 544: submission took 0.00s
# INFO:root:Component 545: size 500
# INFO:root:Component 545: submission took 0.00s
# INFO:root:Component 546: size 500
# INFO:root:Component 546: submission took 0.01s
# INFO:root:Component 547: size 500
# INFO:root:Component 547: submission took 0.00s
# INFO:root:Component 548: size 500
# INFO:root:Component 548: submission took 0.00s
# INFO:root:Component 549: size 500
# INFO:root:Component 549: submission took 0.00s
# INFO:root:Component 550: size 500
# INFO:root:Component 550: submission took 0.00s
# INFO:root:Component 551: size 500
# INFO:root:Component 551: submission took 0.00s
# INFO:root:Component 552: size 500
# INFO:root:Component 552: submission took 0.00s
# INFO:root:Component 553: size 500
# INFO:root:Component 553: submission took 0.00s
# INFO:root:Component 554: size 500
# INFO:root:Component 554: submission took 0.00s
# INFO:root:Component 555: size 500
# INFO:root:Component 555: submission took 0.00s
# INFO:root:Component 556: size 500
# INFO:root:Component 556: submission took 0.00s
# INFO:root:Component 557: size 500
# INFO:root:Component 557: submission took 0.00s
# INFO:root:Component 558: size 500
# INFO:root:Component 558: submission took 0.00s
# INFO:root:Component 559: size 500
# INFO:root:Component 559: submission took 0.00s
# INFO:root:Component 560: size 500
# INFO:root:Component 560: submission took 0.00s
# INFO:root:Component 561: size 500
# INFO:root:Component 561: submission took 0.01s
# INFO:root:Component 562: size 500
# INFO:root:Component 562: submission took 0.00s
# INFO:root:Component 563: size 500
# INFO:root:Component 563: submission took 0.00s
# INFO:root:Component 564: size 500
# INFO:root:Component 564: submission took 0.00s
# INFO:root:Component 565: size 500
# INFO:root:Component 565: submission took 0.00s
# INFO:root:Component 566: size 500
# INFO:root:Component 566: submission took 0.00s
# INFO:root:Component 567: size 500
# INFO:root:Component 567: submission took 0.00s
# INFO:root:Component 568: size 500
# INFO:root:Component 568: submission took 0.00s
# INFO:root:Component 569: size 499
# INFO:root:Component 569: submission took 0.00s
# INFO:root:Component 570: size 1
# INFO:root:Component 570: submission took 0.00s
# INFO:root:Component 571: size 500
# INFO:root:Component 571: submission took 0.00s
# INFO:root:Component 572: size 500
# INFO:root:Component 572: submission took 0.00s
# INFO:root:Component 573: size 500
# INFO:root:Component 573: submission took 0.00s
# INFO:root:Component 574: size 500
# INFO:root:Component 574: submission took 0.00s
# INFO:root:Component 575: size 500
# INFO:root:Component 575: submission took 0.00s
# INFO:root:Component 576: size 500
# INFO:root:Component 576: submission took 0.00s
# INFO:root:Component 577: size 500
# INFO:root:Component 577: submission took 0.00s
# INFO:root:Component 578: size 500
# INFO:root:Component 578: submission took 0.00s
# INFO:root:Component 579: size 500
# INFO:root:Component 579: submission took 0.00s
# INFO:root:Component 580: size 500
# INFO:root:Component 580: submission took 0.00s
# INFO:root:Component 581: size 500
# INFO:root:Component 581: submission took 0.00s
# INFO:root:Component 582: size 500
# INFO:root:Component 582: submission took 0.00s
# INFO:root:Component 583: size 500
# INFO:root:Component 583: submission took 0.00s
# INFO:root:Component 584: size 500
# INFO:root:Component 584: submission took 0.00s
# INFO:root:Component 585: size 500
# INFO:root:Component 585: submission took 0.00s
# INFO:root:Component 586: size 500
# INFO:root:Component 586: submission took 0.00s
# INFO:root:Component 587: size 500
# INFO:root:Component 587: submission took 0.00s
# INFO:root:Component 588: size 500
# INFO:root:Component 588: submission took 0.00s
# INFO:root:Component 589: size 500
# INFO:root:Component 589: submission took 0.00s
# INFO:root:Component 590: size 499
# INFO:root:Component 590: submission took 0.00s
# INFO:root:Component 591: size 1
# INFO:root:Component 591: submission took 0.00s
# INFO:root:Component 592: size 500
# INFO:root:Component 592: submission took 0.00s
# INFO:root:Component 593: size 500
# INFO:root:Component 593: submission took 0.00s
# INFO:root:Component 594: size 500
# ...
# INFO:root:Component 1769: processing took 0.00s
# INFO:root:Component 1770: processing took 0.00s
# INFO:root:Component 1771: processing took 0.00s
# INFO:root:Component 1772: processing took 0.00s
# INFO:root:Component 1773: processing took 0.00s
# INFO:root:Component 1774: processing took 0.00s
# INFO:root:Component 1775: processing took 0.00s
# INFO:root:Component 1776: processing took 0.00s
# INFO:root:Component 1777: processing took 0.00s
# INFO:root:Component 1778: processing took 0.00s
# INFO:root:Component 1779: processing took 0.00s
# INFO:root:Component 1780: processing took 0.00s
# INFO:root:Component 1781: processing took 0.00s
# INFO:root:Component 1782: processing took 0.00s
# INFO:root:Component 1783: processing took 0.00s
# INFO:root:Component 1784: processing took 0.00s
# INFO:root:Component 1785: processing took 0.00s
# INFO:root:Component 1786: processing took 0.00s
# INFO:root:Component 1787: processing took 0.00s
# INFO:root:Component 1788: processing took 0.00s
# INFO:root:Component 1789: processing took 0.00s
# INFO:root:Component 1790: processing took 0.00s
# INFO:root:Component 1791: processing took 0.00s
# INFO:root:Component 1792: processing took 0.00s
# INFO:root:Component 1793: processing took 0.00s
# INFO:root:Component 1794: processing took 0.00s
# INFO:root:Component 1795: processing took 0.00s
# INFO:root:Component 1796: processing took 0.00s
# INFO:root:Component 1797: processing took 0.00s
# INFO:root:Component 1798: processing took 0.00s
# INFO:root:Component 1799: processing took 0.00s
# INFO:root:Component 1800: processing took 0.00s
# INFO:root:Component 1801: processing took 0.00s
# INFO:root:Component 1802: processing took 0.00s
# INFO:root:Component 1803: processing took 0.00s
# INFO:root:Component 1804: processing took 0.00s
# INFO:root:Component 1805: processing took 0.00s
# INFO:root:Component 1806: processing took 0.00s
# INFO:root:Component 1807: processing took 0.00s
# INFO:root:Component 1808: processing took 0.00s
# INFO:root:Component 1809: processing took 0.00s
# INFO:root:Component 1810: processing took 0.00s
# INFO:root:Component 1811: processing took 0.00s
# INFO:root:Component 1812: processing took 0.00s
# INFO:root:Component 1813: processing took 0.00s
# INFO:root:Component 1814: processing took 0.00s
# INFO:root:Component 1815: processing took 0.00s
# INFO:root:Component 1816: processing took 0.00s
# INFO:root:Component 1817: processing took 0.00s
# INFO:root:Component 1818: processing took 0.00s
# INFO:root:Component 1819: processing took 0.00s
# INFO:root:Component 1820: processing took 0.00s
# INFO:root:Component 1821: processing took 0.00s
# INFO:root:Component 1822: processing took 0.00s
# INFO:root:Component 1823: processing took 0.00s
# INFO:root:Component 1824: processing took 0.00s
# INFO:root:Component 1825: processing took 0.00s
# INFO:root:Component 1826: processing took 0.00s
# INFO:root:Component 1827: processing took 0.00s
# INFO:root:Component 1828: processing took 0.00s
# INFO:root:Component 1829: processing took 0.00s
# INFO:root:Component 1830: processing took 0.00s
# INFO:root:Component 1831: processing took 0.00s
# INFO:root:Component 1832: processing took 0.00s
# INFO:root:Component 1833: processing took 0.00s
# INFO:root:Component 1834: processing took 0.00s
# INFO:root:Component 1835: processing took 0.00s
# INFO:root:Component 1836: processing took 0.00s
# INFO:root:Component 1837: processing took 0.00s
# INFO:root:Component 1838: processing took 0.00s
# INFO:root:Component 1839: processing took 0.00s
# INFO:root:Component 1840: processing took 0.00s
# INFO:root:Component 1841: processing took 0.00s
# INFO:root:Component 1842: processing took 0.00s
# INFO:root:Component 1843: processing took 0.00s
# INFO:root:Component 1844: processing took 0.00s
# INFO:root:Component 1845: processing took 0.00s
# INFO:root:Component 1846: processing took 0.00s
# INFO:root:Component 1847: processing took 0.00s
# INFO:root:Component 1848: processing took 0.00s
# INFO:root:Component 1849: processing took 0.00s
# INFO:root:Component 1850: processing took 0.00s
# INFO:root:Component 1851: processing took 0.00s
# INFO:root:Component 1852: processing took 0.00s
# INFO:root:Component 1853: processing took 0.00s
# INFO:root:Component 1854: processing took 0.00s
# INFO:root:Component 1855: processing took 0.00s
# INFO:root:Component 1856: processing took 0.00s
# INFO:root:Component 1857: processing took 0.00s
# INFO:root:Component 1858: processing took 0.00s
# INFO:root:Component 1859: processing took 0.00s
# INFO:root:Component 1860: processing took 0.00s
# INFO:root:Component 1861: processing took 0.00s
# INFO:root:Component 1862: processing took 0.00s
# INFO:root:Component 1863: processing took 0.00s
# INFO:root:Component 1864: processing took 0.00s
# INFO:root:Component 1865: processing took 0.00s
# INFO:root:Component 1866: processing took 0.00s
# INFO:root:Component 1867: processing took 0.00s
# INFO:root:Component 1868: processing took 0.00s
# INFO:root:Component 1869: processing took 0.00s
# INFO:root:Component 1870: processing took 0.00s
# INFO:root:Component 1871: processing took 0.00s
# INFO:root:Component 1872: processing took 0.00s
# INFO:root:Component 1873: processing took 0.00s
# INFO:root:Component 1874: processing took 0.00s
# INFO:root:Component 1875: processing took 0.00s
# INFO:root:Component 1876: processing took 0.00s
# INFO:root:Component 1877: processing took 0.00s
# INFO:root:Component 1878: processing took 0.00s
# INFO:root:Component 1879: processing took 0.00s
# INFO:root:Component 1880: processing took 0.00s
# INFO:root:Component 1881: processing took 0.00s
# INFO:root:Component 1882: processing took 0.00s
# INFO:root:Component 1883: processing took 0.00s
# INFO:root:Component 1884: processing took 0.00s
# INFO:root:Component 1885: processing took 0.00s
# INFO:root:Component 1886: processing took 0.00s
# INFO:root:Component 1887: processing took 0.00s
# INFO:root:Component 1888: processing took 0.00s
# INFO:root:Component 1889: processing took 0.00s
# INFO:root:Component 1890: processing took 0.00s
# INFO:root:Component 1891: processing took 0.00s
# INFO:root:Component 1892: processing took 0.00s
# INFO:root:Component 1893: processing took 0.00s
# INFO:root:Component 1894: processing took 0.00s
# INFO:root:Component 1895: processing took 0.00s
# INFO:root:Component 1896: processing took 0.00s
# INFO:root:Component 1897: processing took 0.00s
# INFO:root:Component 1898: processing took 0.00s
# INFO:root:Component 1899: processing took 0.00s
# INFO:root:Component 1900: processing took 0.00s
# INFO:root:Component 1901: processing took 0.00s
# INFO:root:Component 1902: processing took 0.00s
# INFO:root:Component 1903: processing took 0.00s
# INFO:root:Component 1904: processing took 0.00s
# INFO:root:Component 1905: processing took 0.00s
# INFO:root:Component 1906: processing took 0.00s
# INFO:root:Component 1907: processing took 0.00s
# INFO:root:Component 1908: processing took 0.00s
# INFO:root:Component 1909: processing took 0.00s
# INFO:root:Component 1910: processing took 0.00s
# INFO:root:Component 1911: processing took 0.00s
# INFO:root:Component 1912: processing took 0.00s
# INFO:root:Component 1913: processing took 0.00s
# INFO:root:Component 1914: processing took 0.00s
# INFO:root:Component 1915: processing took 0.00s
# INFO:root:Component 1916: processing took 0.00s
# INFO:root:Component 1917: processing took 0.00s
# INFO:root:Component 1918: processing took 0.00s
# INFO:root:Component 1919: processing took 0.00s
# INFO:root:Component 1920: processing took 0.00s
# INFO:root:Component 1921: processing took 0.00s
# INFO:root:Component 1922: processing took 0.00s
# INFO:root:Component 1923: processing took 0.00s
# INFO:root:Component 1924: processing took 0.00s
# INFO:root:Component 1925: processing took 0.00s
# INFO:root:Component 1926: processing took 0.00s
# INFO:root:Component 1927: processing took 0.00s
# INFO:root:Component 1928: processing took 0.00s
# INFO:root:Component 1929: processing took 0.00s
# INFO:root:Component 1930: processing took 0.00s
# INFO:root:Component 1931: processing took 0.00s
# INFO:root:Component 1932: processing took 0.00s
# INFO:root:Component 1933: processing took 0.00s
# INFO:root:Component 1934: processing took 0.00s
# INFO:root:Component 1935: processing took 0.00s
# INFO:root:Component 1936: processing took 0.00s
# INFO:root:Component 1937: processing took 0.00s
# INFO:root:Component 1938: processing took 0.00s
# INFO:root:Component 1939: processing took 0.00s
# INFO:root:Component 1940: processing took 0.00s
# INFO:root:Component 1941: processing took 0.00s
# INFO:root:Component 1942: processing took 0.00s
# INFO:root:Component 1943: processing took 0.00s
# INFO:root:Component 1944: processing took 0.00s
# INFO:root:Component 1945: processing took 0.00s
# INFO:root:Component 1946: processing took 0.00s
# INFO:root:Component 1947: processing took 0.00s
# INFO:root:Component 1948: processing took 0.00s
# INFO:root:Component 1949: processing took 0.00s
# INFO:root:Component 1950: processing took 0.00s
# INFO:root:Component 1951: processing took 0.00s
# INFO:root:Component 1952: processing took 0.00s
# INFO:root:Component 1953: processing took 0.00s
# INFO:root:Component 1954: processing took 0.00s
# INFO:root:Component 1955: processing took 0.00s
# INFO:root:Component 1956: processing took 0.00s
# INFO:root:Component 1957: processing took 0.00s
# INFO:root:Component 1958: processing took 0.00s
# INFO:root:Component 1959: processing took 0.00s
# INFO:root:Component 1960: processing took 0.00s
# INFO:root:Component 1961: processing took 0.00s
# INFO:root:Component 1962: processing took 0.00s
# INFO:root:Component 1963: processing took 0.00s
# INFO:root:Component 1964: processing took 0.00s
# INFO:root:Component 1965: processing took 0.00s
# INFO:root:Component 1966: processing took 0.00s
# INFO:root:Component 1967: processing took 0.00s
# INFO:root:Component 1968: processing took 0.00s
# INFO:root:Component 1969: processing took 0.00s
# INFO:root:Component 1970: processing took 0.00s
# INFO:root:Component 1971: processing took 0.00s
# INFO:root:Component 1972: processing took 0.00s
# INFO:root:Component 1973: processing took 0.00s
# INFO:root:Component 1974: processing took 0.00s
# INFO:root:Component 1975: processing took 0.00s
# INFO:root:Component 1976: processing took 0.00s
# INFO:root:Component 1977: processing took 0.00s
# INFO:root:Component 1978: processing took 0.00s
# INFO:root:Component 1979: processing took 0.00s
# INFO:root:Component 1980: processing took 0.00s
# INFO:root:Component 1981: processing took 0.00s
# INFO:root:Component 1982: processing took 0.00s
# INFO:root:Component 1983: processing took 0.00s
# INFO:root:Component 1984: processing took 0.00s
# INFO:root:Component 1985: processing took 0.00s
# INFO:root:Component 1986: processing took 0.00s
# INFO:root:Component 1987: processing took 0.00s
# INFO:root:Component 1988: processing took 0.00s
# INFO:root:Component 1989: processing took 0.00s
# INFO:root:Component 1990: processing took 0.00s
# INFO:root:Component 1991: processing took 0.00s
# INFO:root:Component 1992: processing took 0.00s
# INFO:root:Component 1993: processing took 0.00s
# INFO:root:Component 1994: processing took 0.00s
# INFO:root:Component 1995: processing took 0.00s
# INFO:root:Component 1996: processing took 0.00s
# INFO:root:Component 1997: processing took 0.00s
# INFO:root:Component 1998: processing took 0.00s
# INFO:root:Component 1999: processing took 0.00s
# INFO:root:Component 2000: processing took 0.00s
# INFO:root:Component 2001: processing took 0.00s
# INFO:root:Component 2002: processing took 0.00s
# INFO:root:Component 2003: processing took 0.00s
# INFO:root:Component 2004: processing took 0.00s
# INFO:root:Component 2005: processing took 0.00s
# INFO:root:Component 2006: processing took 0.00s
# INFO:root:Component 2007: processing took 0.00s
# INFO:root:Component 2008: processing took 0.00s
# INFO:root:Component 2009: processing took 0.00s
# INFO:root:Component 2010: processing took 0.00s
# INFO:root:Component 2011: processing took 0.00s
# INFO:root:Component 2012: processing took 0.00s
# INFO:root:Component 2013: processing took 0.00s
# INFO:root:Component 2014: processing took 0.00s
# INFO:root:Component 2015: processing took 0.00s
# INFO:root:Component 2016: processing took 0.00s
# INFO:root:Component 2017: processing took 0.00s
# INFO:root:Component 2018: processing took 0.00s
# INFO:root:Component 2019: processing took 0.00s
# INFO:root:Component 2020: processing took 0.00s
# INFO:root:Component 2021: processing took 0.00s
# INFO:root:Component 2022: processing took 0.00s
# INFO:root:Component 2023: processing took 0.00s
# INFO:root:Component 2024: processing took 0.00s
# INFO:root:Component 2025: processing took 0.00s
# INFO:root:Component 2026: processing took 0.00s
# INFO:root:Component 2027: processing took 0.00s
# INFO:root:Component 2028: processing took 0.00s
# INFO:root:Component 2029: processing took 0.00s
# INFO:root:Component 2030: processing took 0.00s
# INFO:root:Component 2031: processing took 0.00s
# INFO:root:Component 2032: processing took 0.00s
# INFO:root:Component 2033: processing took 0.00s
# INFO:root:Component 2034: processing took 0.00s
# INFO:root:Component 2035: processing took 0.00s
# INFO:root:Component 2036: processing took 0.00s
# INFO:root:Component 2037: processing took 0.00s
# INFO:root:Component 2038: processing took 0.00s
# INFO:root:Component 2039: processing took 0.00s
# INFO:root:Component 2040: processing took 0.00s
# INFO:root:Component 2041: processing took 0.00s
# INFO:root:Component 2042: processing took 0.00s
# INFO:root:Component 2043: processing took 0.00s
# INFO:root:Component 2044: processing took 0.00s
# INFO:root:Component 2045: processing took 0.00s
# INFO:root:Component 2046: processing took 0.00s
# INFO:root:Component 2047: processing took 0.00s
# INFO:root:Component 2048: processing took 0.00s
# INFO:root:Component 2049: processing took 0.00s
# INFO:root:Component 2050: processing took 0.00s
# INFO:root:Component 2051: processing took 0.00s
# INFO:root:Component 2052: processing took 0.00s
# INFO:root:Component 2053: processing took 0.00s
# INFO:root:Component 2054: processing took 0.00s
# INFO:root:Component 2055: processing took 0.00s
# INFO:root:Component 2056: processing took 0.00s
# INFO:root:Component 2057: processing took 0.00s
# INFO:root:Component 2058: processing took 0.00s
# INFO:root:Component 2059: processing took 0.00s
# INFO:root:Component 2060: processing took 0.00s
# INFO:root:Component 2061: processing took 0.00s
# INFO:root:Component 2062: processing took 0.00s
# INFO:root:Component 2063: processing took 0.00s
# INFO:root:Component 2064: processing took 0.00s
# INFO:root:Component 2065: processing took 0.00s
# INFO:root:Component 2066: processing took 0.00s
# INFO:root:Component 2067: processing took 0.00s
# INFO:root:Component 2068: processing took 0.00s
# INFO:root:Component 2069: processing took 0.00s
# INFO:root:Component 2070: processing took 0.00s
# INFO:root:Component 2071: processing took 0.00s
# INFO:root:Component 2072: processing took 0.00s
# INFO:root:Component 2073: processing took 0.00s
# INFO:root:Component 2074: processing took 0.00s
# INFO:root:Component 2075: processing took 0.00s
# INFO:root:Component 2076: processing took 0.00s
# INFO:root:Component 2077: processing took 0.00s
# INFO:root:Component 2078: processing took 0.00s
# INFO:root:Component 2079: processing took 0.00s
# pyarrow.Table
# parent: int64
# child: int64
# probability: double
# ----
# parent: [[-1193661193,-1193661193,-1065816097,-1065816097,-2131390865,...,-1988605072,-384900360,-384900360,-1450541918,-1450541918],[-1998262778,-1998262778,-352384079,-352384079,-1971847649,...,-1780983856,-1515770754,-1515770754,-1282464668,-1282464668],...,[-549228011,-549228011,-785366439,-785366439,-1013741990,...,-1759852711,-1842716946,-1842716946,-1756929996,-1756929996],[-75333889,-75333889,-1183850366,-1183850366,-95546434,...,-1299895816,-284056808,-284056808,-1440724029,-1440724029]]
# child: [[197413,326505,116407,384163,114551,...,212599,19131,294811,193341,224447],[64284,340314,170279,378400,152470,...,246051,14448,296071,85173,322723],...,[72846,345192,90867,360477,2449,...,324026,51072,220303,113552,257515],[168741,288248,29190,339106,179769,...,204144,48177,357956,121674,378111]]
# probability: [[1,1,1,1,1,...,0.7,0.7,0.7,0.7,0.7],[1,1,1,1,1,...,0.7,0.7,0.7,0.7,0.7],...,[1,1,1,1,1,...,0.7,0.7,0.7,0.7,0.7],[1,1,1,1,1,...,0.7,0.7,0.7,0.7,0.7]]

# %%
h_out = to_hierarchical_clusters_pa(cc200)

h_out
# Out:
# INFO:root:Starting processing with table size: 100000400
# INFO:root:Found 206763 unique components
# INFO:root:Component 0: size 500
# INFO:root:Component 0: submission took 0.14s
# INFO:root:Component 1: size 501
# INFO:root:Component 1: submission took 0.16s
# INFO:root:Component 2: size 501
# INFO:root:Component 2: submission took 0.15s
# INFO:root:Component 3: size 501
# INFO:root:Component 3: submission took 0.15s
# INFO:root:Component 4: size 501
# INFO:root:Component 4: submission took 0.15s
# INFO:root:Component 5: size 501
# INFO:root:Component 5: submission took 0.17s
# INFO:root:Component 6: size 501
# INFO:root:Component 6: submission took 0.13s
# INFO:root:Component 7: size 501
# INFO:root:Component 7: submission took 0.12s
# INFO:root:Component 8: size 501
# INFO:root:Component 8: submission took 0.10s
# INFO:root:Component 9: size 501
# INFO:root:Component 9: submission took 0.11s
# INFO:root:Component 10: size 501
# INFO:root:Component 10: submission took 0.11s
# INFO:root:Component 11: size 501
# INFO:root:Component 11: submission took 0.12s
# INFO:root:Component 12: size 501
# INFO:root:Component 12: submission took 0.11s
# INFO:root:Component 13: size 501
# INFO:root:Component 13: submission took 0.10s
# INFO:root:Component 14: size 501
# INFO:root:Component 14: submission took 0.10s
# INFO:root:Component 15: size 501
# INFO:root:Component 15: submission took 0.10s
# INFO:root:Component 16: size 501
# INFO:root:Component 16: submission took 0.09s
# INFO:root:Component 17: size 501
# INFO:root:Component 17: submission took 0.10s
# INFO:root:Component 18: size 501
# INFO:root:Component 18: submission took 0.09s
# INFO:root:Component 19: size 501
# INFO:root:Component 19: submission took 0.09s
# INFO:root:Component 20: size 501
# INFO:root:Component 20: submission took 0.09s
# INFO:root:Component 21: size 501
# INFO:root:Component 21: submission took 0.09s
# INFO:root:Component 22: size 501
# INFO:root:Component 22: submission took 0.09s
# INFO:root:Component 23: size 501
# INFO:root:Component 23: submission took 0.09s
# INFO:root:Component 24: size 501
# INFO:root:Component 24: submission took 0.10s
# INFO:root:Component 25: size 501
# INFO:root:Component 25: submission took 0.10s
# INFO:root:Component 26: size 501
# INFO:root:Component 26: submission took 0.09s
# INFO:root:Component 27: size 501
# INFO:root:Component 27: submission took 0.10s
# INFO:root:Component 28: size 501
# INFO:root:Component 28: submission took 0.09s
# INFO:root:Component 29: size 501
# INFO:root:Component 29: submission took 0.09s
# INFO:root:Component 30: size 501
# INFO:root:Component 30: submission took 0.10s
# INFO:root:Component 31: size 501
# INFO:root:Component 31: submission took 0.10s
# INFO:root:Component 32: size 501
# INFO:root:Component 32: submission took 0.10s
# INFO:root:Component 33: size 501
# INFO:root:Component 33: submission took 0.09s
# INFO:root:Component 34: size 501
# INFO:root:Component 34: submission took 0.10s
# INFO:root:Component 35: size 501
# INFO:root:Component 35: submission took 0.09s
# INFO:root:Component 36: size 501
# INFO:root:Component 36: submission took 0.10s
# INFO:root:Component 37: size 501
# INFO:root:Component 37: submission took 0.10s
# INFO:root:Component 38: size 501
# INFO:root:Component 38: submission took 0.09s
# INFO:root:Component 39: size 501
# INFO:root:Component 39: submission took 0.09s
# INFO:root:Component 40: size 501
# INFO:root:Component 40: submission took 0.10s
# INFO:root:Component 41: size 501
# INFO:root:Component 41: submission took 0.09s
# INFO:root:Component 42: size 501
# INFO:root:Component 42: submission took 0.11s
# INFO:root:Component 43: size 501
# INFO:root:Component 43: submission took 0.11s
# INFO:root:Component 44: size 501
# INFO:root:Component 44: submission took 0.10s
# INFO:root:Component 45: size 501
# INFO:root:Component 45: submission took 0.10s
# INFO:root:Component 46: size 501
# INFO:root:Component 46: submission took 0.10s
# INFO:root:Component 47: size 501
# INFO:root:Component 47: submission took 0.10s
# INFO:root:Component 48: size 501
# INFO:root:Component 48: submission took 0.09s
# INFO:root:Component 49: size 501
# INFO:root:Component 49: submission took 0.10s
# INFO:root:Component 50: size 501
# INFO:root:Component 50: submission took 0.10s
# INFO:root:Component 51: size 501
# INFO:root:Component 51: submission took 0.09s
# INFO:root:Component 52: size 501
# INFO:root:Component 52: submission took 0.09s
# INFO:root:Component 53: size 501
# INFO:root:Component 53: submission took 0.10s
# INFO:root:Component 54: size 501
# INFO:root:Component 54: submission took 0.11s
# INFO:root:Component 55: size 501
# INFO:root:Component 55: submission took 0.10s
# INFO:root:Component 56: size 501
# INFO:root:Component 56: submission took 0.10s
# INFO:root:Component 57: size 501
# INFO:root:Component 57: submission took 0.10s
# INFO:root:Component 58: size 501
# INFO:root:Component 58: submission took 0.10s
# INFO:root:Component 59: size 501
# INFO:root:Component 59: submission took 0.10s
# INFO:root:Component 60: size 501
# INFO:root:Component 60: submission took 0.09s
# INFO:root:Component 61: size 501
# INFO:root:Component 61: submission took 0.10s
# INFO:root:Component 62: size 501
# INFO:root:Component 62: submission took 0.10s
# INFO:root:Component 63: size 501
# INFO:root:Component 63: submission took 0.10s
# INFO:root:Component 64: size 501
# INFO:root:Component 64: submission took 0.10s
# INFO:root:Component 65: size 501
# INFO:root:Component 65: submission took 0.09s
# INFO:root:Component 66: size 501
# INFO:root:Component 66: submission took 0.09s
# INFO:root:Component 67: size 501
# INFO:root:Component 67: submission took 0.09s
# INFO:root:Component 68: size 501
# INFO:root:Component 68: submission took 0.09s
# INFO:root:Component 69: size 501
# INFO:root:Component 69: submission took 0.10s
# INFO:root:Component 70: size 501
# INFO:root:Component 70: submission took 0.10s
# INFO:root:Component 71: size 501
# INFO:root:Component 71: submission took 0.09s
# INFO:root:Component 72: size 501
# INFO:root:Component 72: submission took 0.10s
# INFO:root:Component 73: size 501
# INFO:root:Component 73: submission took 0.09s
# INFO:root:Component 74: size 501
# INFO:root:Component 74: submission took 0.09s
# INFO:root:Component 75: size 501
# INFO:root:Component 75: submission took 0.09s
# INFO:root:Component 76: size 501
# INFO:root:Component 76: submission took 0.09s
# INFO:root:Component 77: size 501
# INFO:root:Component 77: submission took 0.09s
# INFO:root:Component 78: size 501
# INFO:root:Component 78: submission took 0.10s
# INFO:root:Component 79: size 501
# INFO:root:Component 79: submission took 0.09s
# INFO:root:Component 80: size 501
# INFO:root:Component 80: submission took 0.10s
# INFO:root:Component 81: size 501
# INFO:root:Component 81: submission took 0.09s
# INFO:root:Component 82: size 501
# INFO:root:Component 82: submission took 0.10s
# INFO:root:Component 83: size 501
# INFO:root:Component 83: submission took 0.09s
# INFO:root:Component 84: size 501
# INFO:root:Component 84: submission took 0.10s
# INFO:root:Component 85: size 501
# INFO:root:Component 85: submission took 0.10s
# INFO:root:Component 86: size 501
# INFO:root:Component 86: submission took 0.10s
# INFO:root:Component 87: size 501
# INFO:root:Component 87: submission took 0.09s
# INFO:root:Component 88: size 501
# INFO:root:Component 88: submission took 0.09s
# INFO:root:Component 89: size 501
# INFO:root:Component 89: submission took 0.10s
# INFO:root:Component 90: size 501
# INFO:root:Component 90: submission took 0.09s
# INFO:root:Component 91: size 501
# INFO:root:Component 91: submission took 0.09s
# INFO:root:Component 92: size 501
# INFO:root:Component 92: submission took 0.09s
# INFO:root:Component 93: size 501
# INFO:root:Component 93: submission took 0.10s
# INFO:root:Component 94: size 501
# INFO:root:Component 94: submission took 0.09s
# INFO:root:Component 95: size 501
# INFO:root:Component 95: submission took 0.10s
# INFO:root:Component 96: size 501
# INFO:root:Component 96: submission took 0.09s
# INFO:root:Component 97: size 501
# INFO:root:Component 97: submission took 0.09s
# INFO:root:Component 98: size 501
# INFO:root:Component 98: submission took 0.09s
# INFO:root:Component 99: size 501
# INFO:root:Component 99: submission took 0.09s
# INFO:root:Component 100: size 501
# INFO:root:Component 100: submission took 0.10s
# INFO:root:Component 101: size 501
# INFO:root:Component 101: submission took 0.09s
# INFO:root:Component 102: size 501
# INFO:root:Component 102: submission took 0.10s
# INFO:root:Component 103: size 501
# INFO:root:Component 103: submission took 0.09s
# INFO:root:Component 104: size 501
# INFO:root:Component 104: submission took 0.10s
# INFO:root:Component 105: size 501
# INFO:root:Component 105: submission took 0.09s
# INFO:root:Component 106: size 501
# INFO:root:Component 106: submission took 0.10s
# INFO:root:Component 107: size 501
# INFO:root:Component 107: submission took 0.12s
# INFO:root:Component 108: size 501
# INFO:root:Component 108: submission took 0.09s
# INFO:root:Component 109: size 501
# INFO:root:Component 109: submission took 0.09s
# INFO:root:Component 110: size 501
# INFO:root:Component 110: submission took 0.09s
# INFO:root:Component 111: size 501
# INFO:root:Component 111: submission took 0.10s
# INFO:root:Component 112: size 501
# INFO:root:Component 112: submission took 0.09s
# INFO:root:Component 113: size 501
# INFO:root:Component 113: submission took 0.10s
# INFO:root:Component 114: size 501
# INFO:root:Component 114: submission took 0.09s
# INFO:root:Component 115: size 501
# INFO:root:Component 115: submission took 0.10s
# INFO:root:Component 116: size 501
# INFO:root:Component 116: submission took 0.09s
# INFO:root:Component 117: size 501
# INFO:root:Component 117: submission took 0.09s
# INFO:root:Component 118: size 501
# INFO:root:Component 118: submission took 0.09s
# INFO:root:Component 119: size 501
# INFO:root:Component 119: submission took 0.10s
# INFO:root:Component 120: size 501
# INFO:root:Component 120: submission took 0.10s
# INFO:root:Component 121: size 501
# INFO:root:Component 121: submission took 0.10s
# INFO:root:Component 122: size 501
# INFO:root:Component 122: submission took 0.10s
# INFO:root:Component 123: size 501
# INFO:root:Component 123: submission took 0.10s
# INFO:root:Component 124: size 501
# INFO:root:Component 124: submission took 0.10s
# INFO:root:Component 125: size 501
# INFO:root:Component 125: submission took 0.09s
# INFO:root:Component 126: size 501
# INFO:root:Component 126: submission took 0.10s
# INFO:root:Component 127: size 501
# INFO:root:Component 127: submission took 0.09s
# INFO:root:Component 128: size 501
# INFO:root:Component 128: submission took 0.09s
# INFO:root:Component 129: size 501
# INFO:root:Component 129: submission took 0.09s
# INFO:root:Component 130: size 501
# INFO:root:Component 130: submission took 0.10s
# INFO:root:Component 131: size 501
# INFO:root:Component 131: submission took 0.10s
# INFO:root:Component 132: size 501
# INFO:root:Component 132: submission took 0.10s
# INFO:root:Component 133: size 501
# INFO:root:Component 133: submission took 0.10s
# INFO:root:Component 134: size 501
# INFO:root:Component 134: submission took 0.10s
# INFO:root:Component 135: size 501
# INFO:root:Component 135: submission took 0.09s
# INFO:root:Component 136: size 501
# INFO:root:Component 136: submission took 0.10s
# INFO:root:Component 137: size 501
# INFO:root:Component 137: submission took 0.10s
# INFO:root:Component 138: size 501
# INFO:root:Component 138: submission took 0.10s
# INFO:root:Component 139: size 501
# INFO:root:Component 139: submission took 0.10s
# INFO:root:Component 140: size 501
# INFO:root:Component 140: submission took 0.09s
# INFO:root:Component 141: size 501
# INFO:root:Component 141: submission took 0.09s
# INFO:root:Component 142: size 501
# INFO:root:Component 142: submission took 0.10s
# INFO:root:Component 143: size 501
# INFO:root:Component 143: submission took 0.10s
# INFO:root:Component 144: size 501
# INFO:root:Component 144: submission took 0.10s
# INFO:root:Component 145: size 501
# INFO:root:Component 145: submission took 0.10s
# INFO:root:Component 146: size 501
# INFO:root:Component 146: submission took 0.09s
# INFO:root:Component 147: size 501
# INFO:root:Component 147: submission took 0.10s
# INFO:root:Component 148: size 501
# INFO:root:Component 148: submission took 0.10s
# INFO:root:Component 149: size 501
# INFO:root:Component 149: submission took 0.09s
# INFO:root:Component 150: size 501
# INFO:root:Component 150: submission took 0.09s
# INFO:root:Component 151: size 501
# INFO:root:Component 151: submission took 0.09s
# INFO:root:Component 152: size 501
# INFO:root:Component 152: submission took 0.10s
# INFO:root:Component 153: size 501
# INFO:root:Component 153: submission took 0.10s
# INFO:root:Component 154: size 501
# INFO:root:Component 154: submission took 0.10s
# INFO:root:Component 155: size 501
# INFO:root:Component 155: submission took 0.10s
# INFO:root:Component 156: size 501
# INFO:root:Component 156: submission took 0.10s
# INFO:root:Component 157: size 501
# INFO:root:Component 157: submission took 0.09s
# INFO:root:Component 158: size 501
# INFO:root:Component 158: submission took 0.09s
# INFO:root:Component 159: size 501
# INFO:root:Component 159: submission took 0.09s
# INFO:root:Component 160: size 501
# INFO:root:Component 160: submission took 0.10s
# INFO:root:Component 161: size 501
# INFO:root:Component 161: submission took 0.09s
# INFO:root:Component 162: size 500
# INFO:root:Component 162: submission took 0.10s
# INFO:root:Component 163: size 1
# INFO:root:Component 163: submission took 0.09s
# INFO:root:Component 164: size 501
# INFO:root:Component 164: submission took 0.09s
# INFO:root:Component 165: size 501
# INFO:root:Component 165: submission took 0.12s
# INFO:root:Component 166: size 501
# INFO:root:Component 166: submission took 0.10s
# INFO:root:Component 167: size 501
# INFO:root:Component 167: submission took 0.09s
# INFO:root:Component 168: size 501
# INFO:root:Component 168: submission took 0.10s
# INFO:root:Component 169: size 501
# INFO:root:Component 169: submission took 0.09s
# INFO:root:Component 170: size 501
# INFO:root:Component 170: submission took 0.10s
# INFO:root:Component 171: size 501
# INFO:root:Component 171: submission took 0.09s
# INFO:root:Component 172: size 501
# INFO:root:Component 172: submission took 0.09s
# INFO:root:Component 173: size 501
# INFO:root:Component 173: submission took 0.09s
# INFO:root:Component 174: size 501
# INFO:root:Component 174: submission took 0.10s
# INFO:root:Component 175: size 501
# INFO:root:Component 175: submission took 0.09s
# INFO:root:Component 176: size 501
# INFO:root:Component 176: submission took 0.09s
# INFO:root:Component 177: size 501
# INFO:root:Component 177: submission took 0.09s
# INFO:root:Component 178: size 501
# INFO:root:Component 178: submission took 0.10s
# INFO:root:Component 179: size 501
# INFO:root:Component 179: submission took 0.09s
# INFO:root:Component 180: size 501
# INFO:root:Component 180: submission took 0.09s
# INFO:root:Component 181: size 501
# INFO:root:Component 181: submission took 0.10s
# INFO:root:Component 182: size 501
# INFO:root:Component 182: submission took 0.10s
# INFO:root:Component 183: size 501
# INFO:root:Component 183: submission took 0.09s
# INFO:root:Component 184: size 501
# INFO:root:Component 184: submission took 0.09s
# INFO:root:Component 185: size 501
# INFO:root:Component 185: submission took 0.09s
# INFO:root:Component 186: size 501
# INFO:root:Component 186: submission took 0.09s
# INFO:root:Component 187: size 501
# INFO:root:Component 187: submission took 0.09s
# INFO:root:Component 188: size 501
# INFO:root:Component 188: submission took 0.09s
# INFO:root:Component 189: size 501
# INFO:root:Component 189: submission took 0.09s
# INFO:root:Component 190: size 501
# INFO:root:Component 190: submission took 0.09s
# INFO:root:Component 191: size 501
# INFO:root:Component 191: submission took 0.09s
# INFO:root:Component 192: size 501
# INFO:root:Component 192: submission took 0.09s
# INFO:root:Component 193: size 501
# INFO:root:Component 193: submission took 0.09s
# INFO:root:Component 194: size 501
# INFO:root:Component 194: submission took 0.09s
# INFO:root:Component 195: size 501
# INFO:root:Component 195: submission took 0.10s
# INFO:root:Component 196: size 501
# INFO:root:Component 196: submission took 0.10s
# INFO:root:Component 197: size 501
# INFO:root:Component 197: submission took 0.10s
# INFO:root:Component 198: size 501
# INFO:root:Component 198: submission took 0.09s
# INFO:root:Component 199: size 501
# INFO:root:Component 199: submission took 0.10s
# INFO:root:Component 200: size 501
# INFO:root:Component 200: submission took 0.09s
# INFO:root:Component 201: size 501
# INFO:root:Component 201: submission took 0.10s
# INFO:root:Component 202: size 501
# INFO:root:Component 202: submission took 0.10s
# INFO:root:Component 203: size 501
# INFO:root:Component 203: submission took 0.09s
# INFO:root:Component 204: size 501
# INFO:root:Component 204: submission took 0.09s
# INFO:root:Component 205: size 501
# INFO:root:Component 205: submission took 0.09s
# INFO:root:Component 206: size 501
# INFO:root:Component 206: submission took 0.09s
# INFO:root:Component 207: size 500
# INFO:root:Component 207: submission took 0.09s
# INFO:root:Component 208: size 1
# INFO:root:Component 208: submission took 0.10s
# INFO:root:Component 209: size 501
# INFO:root:Component 209: submission took 0.09s
# INFO:root:Component 210: size 501
# INFO:root:Component 210: submission took 0.10s
# INFO:root:Component 211: size 501
# INFO:root:Component 211: submission took 0.10s
# INFO:root:Component 212: size 501
# INFO:root:Component 212: submission took 0.10s
# INFO:root:Component 213: size 501
# INFO:root:Component 213: submission took 0.11s
# INFO:root:Component 214: size 501
# INFO:root:Component 214: submission took 0.09s
# INFO:root:Component 215: size 501
# INFO:root:Component 215: submission took 0.10s
# INFO:root:Component 216: size 501
# INFO:root:Component 216: submission took 0.10s
# INFO:root:Component 217: size 501
# INFO:root:Component 217: submission took 0.10s
# INFO:root:Component 218: size 501
# INFO:root:Component 218: submission took 0.10s
# INFO:root:Component 219: size 501
# INFO:root:Component 219: submission took 0.09s
# INFO:root:Component 220: size 501
# INFO:root:Component 220: submission took 0.09s
# INFO:root:Component 221: size 501
# INFO:root:Component 221: submission took 0.09s
# INFO:root:Component 222: size 501
# INFO:root:Component 222: submission took 0.09s
# INFO:root:Component 223: size 501
# INFO:root:Component 223: submission took 0.10s
# INFO:root:Component 224: size 501
# INFO:root:Component 224: submission took 0.09s
# INFO:root:Component 225: size 501
# INFO:root:Component 225: submission took 0.10s
# INFO:root:Component 226: size 501
# INFO:root:Component 226: submission took 0.10s
# INFO:root:Component 227: size 501
# INFO:root:Component 227: submission took 0.10s
# INFO:root:Component 228: size 501
# INFO:root:Component 228: submission took 0.10s
# INFO:root:Component 229: size 501
# INFO:root:Component 229: submission took 0.09s
# INFO:root:Component 230: size 501
# INFO:root:Component 230: submission took 0.09s
# INFO:root:Component 231: size 501
# INFO:root:Component 231: submission took 0.09s
# INFO:root:Component 232: size 501
# INFO:root:Component 232: submission took 0.10s
# INFO:root:Component 233: size 501
# INFO:root:Component 233: submission took 0.10s
# INFO:root:Component 234: size 500
# INFO:root:Component 234: submission took 0.09s
# INFO:root:Component 235: size 1
# INFO:root:Component 235: submission took 0.09s
# INFO:root:Component 236: size 501
# INFO:root:Component 236: submission took 0.09s
# INFO:root:Component 237: size 501
# INFO:root:Component 237: submission took 0.10s
# INFO:root:Component 238: size 501
# INFO:root:Component 238: submission took 0.09s
# INFO:root:Component 239: size 501
# INFO:root:Component 239: submission took 0.09s
# INFO:root:Component 240: size 501
# INFO:root:Component 240: submission took 0.09s
# INFO:root:Component 241: size 501
# INFO:root:Component 241: submission took 0.10s
# INFO:root:Component 242: size 501
# INFO:root:Component 242: submission took 0.09s
# INFO:root:Component 243: size 501
# INFO:root:Component 243: submission took 0.10s
# INFO:root:Component 244: size 501
# INFO:root:Component 244: submission took 0.09s
# INFO:root:Component 245: size 501
# INFO:root:Component 245: submission took 0.10s
# INFO:root:Component 246: size 501
# INFO:root:Component 246: submission took 0.09s
# INFO:root:Component 247: size 501
# INFO:root:Component 247: submission took 0.09s
# INFO:root:Component 248: size 501
# INFO:root:Component 248: submission took 0.09s
# INFO:root:Component 249: size 501
# INFO:root:Component 249: submission took 0.10s
# INFO:root:Component 250: size 501
# INFO:root:Component 250: submission took 0.09s
# INFO:root:Component 251: size 501
# INFO:root:Component 251: submission took 0.10s
# INFO:root:Component 252: size 501
# INFO:root:Component 252: submission took 0.10s
# INFO:root:Component 253: size 501
# INFO:root:Component 253: submission took 0.10s
# INFO:root:Component 254: size 501
# INFO:root:Component 254: submission took 0.11s
# INFO:root:Component 255: size 501
# INFO:root:Component 255: submission took 0.10s
# INFO:root:Component 256: size 501
# INFO:root:Component 256: submission took 0.10s
# INFO:root:Component 257: size 501
# INFO:root:Component 257: submission took 0.10s
# INFO:root:Component 258: size 501
# INFO:root:Component 258: submission took 0.10s
# INFO:root:Component 259: size 501
# INFO:root:Component 259: submission took 0.10s
# INFO:root:Component 260: size 501
# INFO:root:Component 260: submission took 0.09s
# INFO:root:Component 261: size 501
# INFO:root:Component 261: submission took 0.10s
# INFO:root:Component 262: size 501
# INFO:root:Component 262: submission took 0.09s
# INFO:root:Component 263: size 501
# INFO:root:Component 263: submission took 0.09s
# INFO:root:Component 264: size 501
# INFO:root:Component 264: submission took 0.09s
# INFO:root:Component 265: size 501
# INFO:root:Component 265: submission took 0.09s
# INFO:root:Component 266: size 501
# INFO:root:Component 266: submission took 0.10s
# INFO:root:Component 267: size 501
# INFO:root:Component 267: submission took 0.10s
# INFO:root:Component 268: size 501
# INFO:root:Component 268: submission took 0.09s
# INFO:root:Component 269: size 501
# INFO:root:Component 269: submission took 0.10s
# INFO:root:Component 270: size 501
# INFO:root:Component 270: submission took 0.09s
# INFO:root:Component 271: size 501
# INFO:root:Component 271: submission took 0.10s
# INFO:root:Component 272: size 501
# INFO:root:Component 272: submission took 0.10s
# INFO:root:Component 273: size 501
# INFO:root:Component 273: submission took 0.09s
# INFO:root:Component 274: size 501
# INFO:root:Component 274: submission took 0.09s
# INFO:root:Component 275: size 501
# INFO:root:Component 275: submission took 0.09s
# INFO:root:Component 276: size 501
# INFO:root:Component 276: submission took 0.10s
# INFO:root:Component 277: size 501
# INFO:root:Component 277: submission took 0.09s
# INFO:root:Component 278: size 501
# INFO:root:Component 278: submission took 0.10s
# INFO:root:Component 279: size 501
# INFO:root:Component 279: submission took 0.09s
# INFO:root:Component 280: size 501
# INFO:root:Component 280: submission took 0.09s
# INFO:root:Component 281: size 501
# INFO:root:Component 281: submission took 0.09s
# INFO:root:Component 282: size 501
# INFO:root:Component 282: submission took 0.10s
# INFO:root:Component 283: size 501
# INFO:root:Component 283: submission took 0.09s
# INFO:root:Component 284: size 501
# INFO:root:Component 284: submission took 0.10s
# INFO:root:Component 285: size 501
# INFO:root:Component 285: submission took 0.10s
# INFO:root:Component 286: size 501
# INFO:root:Component 286: submission took 0.09s
# INFO:root:Component 287: size 501
# INFO:root:Component 287: submission took 0.10s
# INFO:root:Component 288: size 501
# INFO:root:Component 288: submission took 0.10s
# INFO:root:Component 289: size 501
# INFO:root:Component 289: submission took 0.09s
# INFO:root:Component 290: size 501
# INFO:root:Component 290: submission took 0.09s
# INFO:root:Component 291: size 501
# INFO:root:Component 291: submission took 0.10s
# INFO:root:Component 292: size 501
# INFO:root:Component 292: submission took 0.10s
# INFO:root:Component 293: size 501
# INFO:root:Component 293: submission took 0.09s
# INFO:root:Component 294: size 501
# INFO:root:Component 294: submission took 0.09s
# INFO:root:Component 295: size 501
# INFO:root:Component 295: submission took 0.10s
# INFO:root:Component 296: size 501
# INFO:root:Component 296: submission took 0.09s
# INFO:root:Component 297: size 501
# INFO:root:Component 297: submission took 0.09s
# INFO:root:Component 298: size 501
# INFO:root:Component 298: submission took 0.09s
# INFO:root:Component 299: size 501
# INFO:root:Component 299: submission took 0.09s
# INFO:root:Component 300: size 501
# INFO:root:Component 300: submission took 0.09s
# INFO:root:Component 301: size 501
# INFO:root:Component 301: submission took 0.09s
# INFO:root:Component 302: size 501
# INFO:root:Component 302: submission took 0.09s
# INFO:root:Component 303: size 501
# INFO:root:Component 303: submission took 0.09s
# INFO:root:Component 304: size 501
# INFO:root:Component 304: submission took 0.09s
# INFO:root:Component 305: size 501
# INFO:root:Component 305: submission took 0.10s
# INFO:root:Component 306: size 501
# INFO:root:Component 306: submission took 0.10s
# INFO:root:Component 307: size 501
# INFO:root:Component 307: submission took 0.09s
# INFO:root:Component 308: size 500
# INFO:root:Component 308: submission took 0.09s
# INFO:root:Component 309: size 1
# INFO:root:Component 309: submission took 0.09s
# INFO:root:Component 310: size 501
# INFO:root:Component 310: submission took 0.10s
# INFO:root:Component 311: size 501
# INFO:root:Component 311: submission took 0.09s
# INFO:root:Component 312: size 501
# INFO:root:Component 312: submission took 0.10s
# INFO:root:Component 313: size 501
# INFO:root:Component 313: submission took 0.09s
# INFO:root:Component 314: size 501
# INFO:root:Component 314: submission took 0.09s
# INFO:root:Component 315: size 501
# INFO:root:Component 315: submission took 0.09s
# INFO:root:Component 316: size 501
# INFO:root:Component 316: submission took 0.10s
# INFO:root:Component 317: size 501
# INFO:root:Component 317: submission took 0.09s
# INFO:root:Component 318: size 501
# INFO:root:Component 318: submission took 0.09s
# INFO:root:Component 319: size 501
# INFO:root:Component 319: submission took 0.10s
# INFO:root:Component 320: size 501
# INFO:root:Component 320: submission took 0.09s
# INFO:root:Component 321: size 501
# INFO:root:Component 321: submission took 0.09s
# INFO:root:Component 322: size 501
# INFO:root:Component 322: submission took 0.10s
# INFO:root:Component 323: size 501
# INFO:root:Component 323: submission took 0.09s
# INFO:root:Component 324: size 501
# INFO:root:Component 324: submission took 0.10s
# INFO:root:Component 325: size 501
# INFO:root:Component 325: submission took 0.10s
# INFO:root:Component 326: size 501
# INFO:root:Component 326: submission took 0.09s
# INFO:root:Component 327: size 501
# INFO:root:Component 327: submission took 0.09s
# INFO:root:Component 328: size 501
# INFO:root:Component 328: submission took 0.09s
# INFO:root:Component 329: size 501
# INFO:root:Component 329: submission took 0.10s
# INFO:root:Component 330: size 501
# INFO:root:Component 330: submission took 0.09s
# INFO:root:Component 331: size 501
# INFO:root:Component 331: submission took 0.09s
# INFO:root:Component 332: size 501
# INFO:root:Component 332: submission took 0.10s
# INFO:root:Component 333: size 501
# INFO:root:Component 333: submission took 0.09s
# INFO:root:Component 334: size 501
# INFO:root:Component 334: submission took 0.09s
# INFO:root:Component 335: size 501
# INFO:root:Component 335: submission took 0.10s
# INFO:root:Component 336: size 501
# INFO:root:Component 336: submission took 0.09s
# INFO:root:Component 337: size 501
# INFO:root:Component 337: submission took 0.10s
# INFO:root:Component 338: size 501
# INFO:root:Component 338: submission took 0.10s
# INFO:root:Component 339: size 501
# INFO:root:Component 339: submission took 0.09s
# INFO:root:Component 340: size 501
# INFO:root:Component 340: submission took 0.09s
# INFO:root:Component 341: size 501
# INFO:root:Component 341: submission took 0.09s
# INFO:root:Component 342: size 501
# INFO:root:Component 342: submission took 0.11s
# INFO:root:Component 343: size 501
# INFO:root:Component 343: submission took 0.09s
# INFO:root:Component 344: size 501
# INFO:root:Component 344: submission took 0.10s
# INFO:root:Component 345: size 501
# INFO:root:Component 345: submission took 0.10s
# INFO:root:Component 346: size 501
# INFO:root:Component 346: submission took 0.09s
# INFO:root:Component 347: size 501
# INFO:root:Component 347: submission took 0.10s
# INFO:root:Component 348: size 501
# INFO:root:Component 348: submission took 0.09s
# INFO:root:Component 349: size 501
# INFO:root:Component 349: submission took 0.10s
# INFO:root:Component 350: size 501
# INFO:root:Component 350: submission took 0.09s
# INFO:root:Component 351: size 501
# INFO:root:Component 351: submission took 0.10s
# INFO:root:Component 352: size 501
# INFO:root:Component 352: submission took 0.09s
# INFO:root:Component 353: size 501
# INFO:root:Component 353: submission took 0.10s
# INFO:root:Component 354: size 501
# INFO:root:Component 354: submission took 0.09s
# INFO:root:Component 355: size 501
# INFO:root:Component 355: submission took 0.27s
# INFO:root:Component 356: size 501
# INFO:root:Component 356: submission took 0.13s
# INFO:root:Component 357: size 501
# INFO:root:Component 357: submission took 0.13s
# INFO:root:Component 358: size 501
# INFO:root:Component 358: submission took 0.10s
# INFO:root:Component 359: size 501
# INFO:root:Component 359: submission took 0.10s
# INFO:root:Component 360: size 501
# INFO:root:Component 360: submission took 0.09s
# INFO:root:Component 361: size 501
# INFO:root:Component 361: submission took 0.09s
# INFO:root:Component 362: size 500
# INFO:root:Component 362: submission took 0.09s
# INFO:root:Component 363: size 1
# INFO:root:Component 363: submission took 0.09s
# INFO:root:Component 364: size 501
# INFO:root:Component 364: submission took 0.09s
# INFO:root:Component 365: size 500
# INFO:root:Component 365: submission took 0.09s
# INFO:root:Component 366: size 1
# INFO:root:Component 366: submission took 0.10s
# INFO:root:Component 367: size 501
# INFO:root:Component 367: submission took 0.09s
# INFO:root:Component 368: size 501
# INFO:root:Component 368: submission took 0.09s
# INFO:root:Component 369: size 501
# INFO:root:Component 369: submission took 0.09s
# INFO:root:Component 370: size 501
# INFO:root:Component 370: submission took 0.10s
# INFO:root:Component 371: size 501
# INFO:root:Component 371: submission took 0.09s
# INFO:root:Component 372: size 501
# INFO:root:Component 372: submission took 0.10s
# INFO:root:Component 373: size 501
# INFO:root:Component 373: submission took 0.09s
# INFO:root:Component 374: size 501
# INFO:root:Component 374: submission took 0.09s
# INFO:root:Component 375: size 501
# INFO:root:Component 375: submission took 0.09s
# INFO:root:Component 376: size 501
# INFO:root:Component 376: submission took 0.10s
# INFO:root:Component 377: size 501
# INFO:root:Component 377: submission took 0.09s
# INFO:root:Component 378: size 500
# INFO:root:Component 378: submission took 0.10s
# INFO:root:Component 379: size 1
# INFO:root:Component 379: submission took 0.09s
# INFO:root:Component 380: size 501
# INFO:root:Component 380: submission took 0.10s
# INFO:root:Component 381: size 501
# INFO:root:Component 381: submission took 0.09s
# INFO:root:Component 382: size 501
# INFO:root:Component 382: submission took 0.09s
# INFO:root:Component 383: size 501
# INFO:root:Component 383: submission took 0.10s
# INFO:root:Component 384: size 501
# INFO:root:Component 384: submission took 0.10s
# INFO:root:Component 385: size 501
# INFO:root:Component 385: submission took 0.10s
# INFO:root:Component 386: size 501
# INFO:root:Component 386: submission took 0.09s
# INFO:root:Component 387: size 501
# INFO:root:Component 387: submission took 0.10s
# INFO:root:Component 388: size 501
# INFO:root:Component 388: submission took 0.09s
# INFO:root:Component 389: size 501
# INFO:root:Component 389: submission took 0.09s
# INFO:root:Component 390: size 501
# INFO:root:Component 390: submission took 0.09s
# INFO:root:Component 391: size 501
# INFO:root:Component 391: submission took 0.09s
# INFO:root:Component 392: size 501
# INFO:root:Component 392: submission took 0.09s
# INFO:root:Component 393: size 501
# INFO:root:Component 393: submission took 0.09s
# INFO:root:Component 394: size 501
# INFO:root:Component 394: submission took 0.09s
# INFO:root:Component 395: size 501
# INFO:root:Component 395: submission took 0.10s
# INFO:root:Component 396: size 501
# INFO:root:Component 396: submission took 0.10s
# INFO:root:Component 397: size 501
# INFO:root:Component 397: submission took 0.09s
# INFO:root:Component 398: size 501
# INFO:root:Component 398: submission took 0.09s
# INFO:root:Component 399: size 501
# INFO:root:Component 399: submission took 0.10s
# INFO:root:Component 400: size 501
# INFO:root:Component 400: submission took 0.10s
# INFO:root:Component 401: size 501
# INFO:root:Component 401: submission took 0.10s
# INFO:root:Component 402: size 501
# INFO:root:Component 402: submission took 0.10s
# INFO:root:Component 403: size 501
# INFO:root:Component 403: submission took 0.09s
# INFO:root:Component 404: size 501
# INFO:root:Component 404: submission took 0.09s
# INFO:root:Component 405: size 501
# INFO:root:Component 405: submission took 0.10s
# INFO:root:Component 406: size 501
# INFO:root:Component 406: submission took 0.09s
# INFO:root:Component 407: size 501
# INFO:root:Component 407: submission took 0.10s
# INFO:root:Component 408: size 500
# INFO:root:Component 408: submission took 0.10s
# INFO:root:Component 409: size 500
# INFO:root:Component 409: submission took 0.10s
# INFO:root:Component 410: size 500
# INFO:root:Component 410: submission took 0.10s
# INFO:root:Component 411: size 500
# INFO:root:Component 411: submission took 0.09s
# INFO:root:Component 412: size 500
# INFO:root:Component 412: submission took 0.10s
# INFO:root:Component 413: size 500
# INFO:root:Component 413: submission took 0.09s
# INFO:root:Component 414: size 500
# INFO:root:Component 414: submission took 0.09s
# INFO:root:Component 415: size 500
# INFO:root:Component 415: submission took 0.09s
# INFO:root:Component 416: size 500
# INFO:root:Component 416: submission took 0.09s
# INFO:root:Component 417: size 500
# INFO:root:Component 417: submission took 0.09s
# INFO:root:Component 418: size 500
# INFO:root:Component 418: submission took 0.10s
# INFO:root:Component 419: size 500
# INFO:root:Component 419: submission took 0.10s
# INFO:root:Component 420: size 500
# INFO:root:Component 420: submission took 0.11s
# INFO:root:Component 421: size 500
# INFO:root:Component 421: submission took 0.11s
# INFO:root:Component 422: size 500
# INFO:root:Component 422: submission took 0.10s
# INFO:root:Component 423: size 499
# INFO:root:Component 423: submission took 0.10s
# INFO:root:Component 424: size 1
# INFO:root:Component 424: submission took 0.09s
# INFO:root:Component 425: size 500
# INFO:root:Component 425: submission took 0.09s
# INFO:root:Component 426: size 500
# INFO:root:Component 426: submission took 0.22s
# INFO:root:Component 427: size 500
# INFO:root:Component 427: submission took 0.11s
# INFO:root:Component 428: size 500
# INFO:root:Component 428: submission took 0.09s
# INFO:root:Component 429: size 500
# INFO:root:Component 429: submission took 0.10s
# INFO:root:Component 430: size 500
# INFO:root:Component 430: submission took 0.10s
# INFO:root:Component 431: size 500
# INFO:root:Component 431: submission took 0.10s
# INFO:root:Component 432: size 500
# INFO:root:Component 432: submission took 0.11s
# INFO:root:Component 433: size 500
# INFO:root:Component 433: submission took 0.10s
# INFO:root:Component 434: size 500
# INFO:root:Component 434: submission took 0.10s
# INFO:root:Component 435: size 500
# INFO:root:Component 435: submission took 0.09s
# INFO:root:Component 436: size 500
# INFO:root:Component 436: submission took 0.10s
# INFO:root:Component 437: size 500
# INFO:root:Component 437: submission took 0.17s
# INFO:root:Component 438: size 500
# INFO:root:Component 438: submission took 0.16s
# INFO:root:Component 439: size 500
# INFO:root:Component 439: submission took 0.10s
# INFO:root:Component 440: size 500
# INFO:root:Component 440: submission took 0.10s
# INFO:root:Component 441: size 500
# INFO:root:Component 441: submission took 0.11s
# INFO:root:Component 442: size 500
# INFO:root:Component 442: submission took 0.11s
# INFO:root:Component 443: size 500
# INFO:root:Component 443: submission took 0.09s
# INFO:root:Component 444: size 500
# INFO:root:Component 444: submission took 0.10s
# INFO:root:Component 445: size 500
# INFO:root:Component 445: submission took 0.10s
# INFO:root:Component 446: size 500
# INFO:root:Component 446: submission took 0.10s
# INFO:root:Component 447: size 500
# INFO:root:Component 447: submission took 0.10s
# INFO:root:Component 448: size 500
# INFO:root:Component 448: submission took 0.15s
# INFO:root:Component 449: size 500
# INFO:root:Component 449: submission took 0.14s
# INFO:root:Component 450: size 500
# INFO:root:Component 450: submission took 0.12s
# INFO:root:Component 451: size 500
# INFO:root:Component 451: submission took 0.10s
# INFO:root:Component 452: size 500
# INFO:root:Component 452: submission took 0.12s
# INFO:root:Component 453: size 500
# INFO:root:Component 453: submission took 0.11s
# INFO:root:Component 454: size 500
# INFO:root:Component 454: submission took 0.10s
# INFO:root:Component 455: size 499
# INFO:root:Component 455: submission took 0.09s
# INFO:root:Component 456: size 1
# INFO:root:Component 456: submission took 0.09s
# INFO:root:Component 457: size 500
# INFO:root:Component 457: submission took 0.09s
# INFO:root:Component 458: size 500
# INFO:root:Component 458: submission took 0.09s
# INFO:root:Component 459: size 500
# INFO:root:Component 459: submission took 0.11s
# INFO:root:Component 460: size 500
# INFO:root:Component 460: submission took 0.16s
# INFO:root:Component 461: size 500
# INFO:root:Component 461: submission took 0.10s
# INFO:root:Component 462: size 500
# INFO:root:Component 462: submission took 0.09s
# INFO:root:Component 463: size 500
# INFO:root:Component 463: submission took 0.09s
# INFO:root:Component 464: size 499
# INFO:root:Component 464: submission took 0.09s
# INFO:root:Component 465: size 1
# INFO:root:Component 465: submission took 0.09s
# INFO:root:Component 466: size 500
# INFO:root:Component 466: submission took 0.09s
# INFO:root:Component 467: size 500
# INFO:root:Component 467: submission took 0.10s
# INFO:root:Component 468: size 500
# INFO:root:Component 468: submission took 0.12s
# INFO:root:Component 469: size 500
# INFO:root:Component 469: submission took 0.12s
# INFO:root:Component 470: size 500
# INFO:root:Component 470: submission took 0.15s
# INFO:root:Component 471: size 500
# INFO:root:Component 471: submission took 0.14s
# INFO:root:Component 472: size 500
# INFO:root:Component 472: submission took 0.12s
# INFO:root:Component 473: size 500
# INFO:root:Component 473: submission took 0.10s
# INFO:root:Component 474: size 500
# INFO:root:Component 474: submission took 0.13s
# INFO:root:Component 475: size 500
# INFO:root:Component 475: submission took 0.10s
# INFO:root:Component 476: size 500
# INFO:root:Component 476: submission took 0.16s
# INFO:root:Component 477: size 500
# INFO:root:Component 477: submission took 0.10s
# INFO:root:Component 478: size 500
# INFO:root:Component 478: submission took 0.10s
# INFO:root:Component 479: size 500
# INFO:root:Component 479: submission took 0.09s
# INFO:root:Component 480: size 500
# INFO:root:Component 480: submission took 0.10s
# INFO:root:Component 481: size 500
# INFO:root:Component 481: submission took 0.09s
# INFO:root:Component 482: size 500
# INFO:root:Component 482: submission took 0.10s
# INFO:root:Component 483: size 500
# INFO:root:Component 483: submission took 0.09s
# INFO:root:Component 484: size 500
# INFO:root:Component 484: submission took 0.09s
# INFO:root:Component 485: size 500
# INFO:root:Component 485: submission took 0.10s
# INFO:root:Component 486: size 500
# INFO:root:Component 486: submission took 0.11s
# INFO:root:Component 487: size 500
# INFO:root:Component 487: submission took 0.13s
# INFO:root:Component 488: size 500
# INFO:root:Component 488: submission took 0.10s
# INFO:root:Component 489: size 500
# INFO:root:Component 489: submission took 0.19s
# INFO:root:Component 490: size 500
# INFO:root:Component 490: submission took 0.12s
# INFO:root:Component 491: size 500
# INFO:root:Component 491: submission took 0.17s
# INFO:root:Component 492: size 500
# INFO:root:Component 492: submission took 0.15s
# INFO:root:Component 493: size 500
# INFO:root:Component 493: submission took 0.14s
# INFO:root:Component 494: size 500
# INFO:root:Component 494: submission took 0.10s
# INFO:root:Component 495: size 500
# INFO:root:Component 495: submission took 0.18s
# INFO:root:Component 496: size 500
# INFO:root:Component 496: submission took 0.14s
# INFO:root:Component 497: size 500
# INFO:root:Component 497: submission took 0.10s
# INFO:root:Component 498: size 500
# INFO:root:Component 498: submission took 0.10s
# INFO:root:Component 499: size 500
# INFO:root:Component 499: submission took 0.13s
# INFO:root:Component 500: size 500
# INFO:root:Component 500: submission took 0.09s
# INFO:root:Component 501: size 500
# INFO:root:Component 501: submission took 0.09s
# INFO:root:Component 502: size 500
# INFO:root:Component 502: submission took 0.09s
# INFO:root:Component 503: size 500
# INFO:root:Component 503: submission took 0.10s
# INFO:root:Component 504: size 500
# INFO:root:Component 504: submission took 0.09s
# INFO:root:Component 505: size 500
# INFO:root:Component 505: submission took 0.09s
# INFO:root:Component 506: size 499
# INFO:root:Component 506: submission took 0.09s
# INFO:root:Component 507: size 1
# INFO:root:Component 507: submission took 0.09s
# INFO:root:Component 508: size 500
# INFO:root:Component 508: submission took 0.09s
# INFO:root:Component 509: size 500
# INFO:root:Component 509: submission took 0.09s
# INFO:root:Component 510: size 500
# INFO:root:Component 510: submission took 0.10s
# INFO:root:Component 511: size 500
# INFO:root:Component 511: submission took 0.09s
# INFO:root:Component 512: size 500
# INFO:root:Component 512: submission took 0.11s
# INFO:root:Component 513: size 500
# INFO:root:Component 513: submission took 0.11s
# INFO:root:Component 514: size 500
# INFO:root:Component 514: submission took 0.12s
# INFO:root:Component 515: size 500
# INFO:root:Component 515: submission took 0.15s
# INFO:root:Component 516: size 499
# INFO:root:Component 516: submission took 0.12s
# INFO:root:Component 517: size 1
# INFO:root:Component 517: submission took 0.10s
# INFO:root:Component 518: size 500
# INFO:root:Component 518: submission took 0.11s
# INFO:root:Component 519: size 500
# INFO:root:Component 519: submission took 0.18s
# INFO:root:Component 520: size 500
# INFO:root:Component 520: submission took 0.14s
# INFO:root:Component 521: size 500
# INFO:root:Component 521: submission took 0.13s
# INFO:root:Component 522: size 500
# INFO:root:Component 522: submission took 0.21s
# INFO:root:Component 523: size 500
# INFO:root:Component 523: submission took 0.19s
# INFO:root:Component 524: size 500
# INFO:root:Component 524: submission took 0.13s
# INFO:root:Component 525: size 500
# INFO:root:Component 525: submission took 0.12s
# INFO:root:Component 526: size 500
# INFO:root:Component 526: submission took 0.10s
# INFO:root:Component 527: size 500
# INFO:root:Component 527: submission took 0.10s
# INFO:root:Component 528: size 500
# INFO:root:Component 528: submission took 0.11s
# INFO:root:Component 529: size 500
# INFO:root:Component 529: submission took 0.09s
# INFO:root:Component 530: size 500
# INFO:root:Component 530: submission took 0.09s
# INFO:root:Component 531: size 500
# INFO:root:Component 531: submission took 0.10s
# INFO:root:Component 532: size 500
# INFO:root:Component 532: submission took 0.11s
# INFO:root:Component 533: size 500
# INFO:root:Component 533: submission took 0.10s
# INFO:root:Component 534: size 500
# INFO:root:Component 534: submission took 0.10s
# INFO:root:Component 535: size 500
# INFO:root:Component 535: submission took 0.12s
# INFO:root:Component 536: size 500
# INFO:root:Component 536: submission took 0.10s
# INFO:root:Component 537: size 500
# INFO:root:Component 537: submission took 0.09s
# INFO:root:Component 538: size 500
# INFO:root:Component 538: submission took 0.09s
# INFO:root:Component 539: size 500
# INFO:root:Component 539: submission took 0.09s
# INFO:root:Component 540: size 500
# INFO:root:Component 540: submission took 0.10s
# INFO:root:Component 541: size 500
# INFO:root:Component 541: submission took 0.09s
# INFO:root:Component 542: size 500
# INFO:root:Component 542: submission took 0.10s
# INFO:root:Component 543: size 500
# INFO:root:Component 543: submission took 0.11s
# INFO:root:Component 544: size 500
# INFO:root:Component 544: submission took 0.10s
# INFO:root:Component 545: size 500
# INFO:root:Component 545: submission took 0.10s
# INFO:root:Component 546: size 500
# INFO:root:Component 546: submission took 0.09s
# INFO:root:Component 547: size 500
# INFO:root:Component 547: submission took 0.09s
# INFO:root:Component 548: size 500
# INFO:root:Component 548: submission took 0.09s
# INFO:root:Component 549: size 500
# INFO:root:Component 549: submission took 0.09s
# INFO:root:Component 550: size 500
# INFO:root:Component 550: submission took 0.09s
# INFO:root:Component 551: size 500
# INFO:root:Component 551: submission took 0.10s
# INFO:root:Component 552: size 500
# INFO:root:Component 552: submission took 0.10s
# INFO:root:Component 553: size 500
# INFO:root:Component 553: submission took 0.10s
# INFO:root:Component 554: size 500
# INFO:root:Component 554: submission took 0.09s
# INFO:root:Component 555: size 500
# INFO:root:Component 555: submission took 0.09s
# INFO:root:Component 556: size 500
# INFO:root:Component 556: submission took 0.09s
# INFO:root:Component 557: size 500
# INFO:root:Component 557: submission took 0.10s
# INFO:root:Component 558: size 500
# INFO:root:Component 558: submission took 0.10s
# INFO:root:Component 559: size 500
# INFO:root:Component 559: submission took 0.09s
# INFO:root:Component 560: size 499
# INFO:root:Component 560: submission took 0.09s
# INFO:root:Component 561: size 1
# INFO:root:Component 561: submission took 0.09s
# INFO:root:Component 562: size 500
# INFO:root:Component 562: submission took 0.09s
# INFO:root:Component 563: size 500
# INFO:root:Component 563: submission took 0.10s
# INFO:root:Component 564: size 500
# INFO:root:Component 564: submission took 0.10s
# INFO:root:Component 565: size 500
# INFO:root:Component 565: submission took 0.11s
# INFO:root:Component 566: size 500
# INFO:root:Component 566: submission took 0.10s
# INFO:root:Component 567: size 500
# INFO:root:Component 567: submission took 0.10s
# INFO:root:Component 568: size 500
# INFO:root:Component 568: submission took 0.09s
# INFO:root:Component 569: size 500
# INFO:root:Component 569: submission took 0.09s
# INFO:root:Component 570: size 500
# INFO:root:Component 570: submission took 0.09s
# INFO:root:Component 571: size 500
# INFO:root:Component 571: submission took 0.10s
# INFO:root:Component 572: size 500
# INFO:root:Component 572: submission took 0.09s
# INFO:root:Component 573: size 500
# INFO:root:Component 573: submission took 0.10s
# INFO:root:Component 574: size 499
# INFO:root:Component 574: submission took 0.09s
# INFO:root:Component 575: size 1
# INFO:root:Component 575: submission took 0.10s
# INFO:root:Component 576: size 500
# INFO:root:Component 576: submission took 0.09s
# INFO:root:Component 577: size 499
# INFO:root:Component 577: submission took 0.10s
# INFO:root:Component 578: size 1
# INFO:root:Component 578: submission took 0.09s
# INFO:root:Component 579: size 500
# INFO:root:Component 579: submission took 0.09s
# INFO:root:Component 580: size 500
# INFO:root:Component 580: submission took 0.09s
# INFO:root:Component 581: size 499
# INFO:root:Component 581: submission took 0.09s
# INFO:root:Component 582: size 1
# INFO:root:Component 582: submission took 0.09s
# INFO:root:Component 583: size 500
# INFO:root:Component 583: submission took 0.09s
# INFO:root:Component 584: size 500
# INFO:root:Component 584: submission took 0.09s
# INFO:root:Component 585: size 500
# INFO:root:Component 585: submission took 0.10s
# INFO:root:Component 586: size 500
# INFO:root:Component 586: submission took 0.09s
# INFO:root:Component 587: size 499
# INFO:root:Component 587: submission took 0.09s
# INFO:root:Component 588: size 1
# INFO:root:Component 588: submission took 0.10s
# INFO:root:Component 589: size 500
# INFO:root:Component 589: submission took 0.09s
# INFO:root:Component 590: size 500
# INFO:root:Component 590: submission took 0.09s
# INFO:root:Component 591: size 500
# INFO:root:Component 591: submission took 0.10s
# INFO:root:Component 592: size 500
# INFO:root:Component 592: submission took 0.10s
# INFO:root:Component 593: size 500
# INFO:root:Component 593: submission took 0.11s
# INFO:root:Component 594: size 500
# ...
# INFO:root:Component 1005: size 500
# INFO:root:Component 1005: submission took 0.09s
# INFO:root:Component 1006: size 500
# INFO:root:Component 1006: submission took 0.09s
# INFO:root:Component 1007: size 500
# INFO:root:Component 1007: submission took 0.09s
# INFO:root:Component 1008: size 500
# INFO:root:Component 1008: submission took 0.09s
# INFO:root:Component 1009: size 500
# INFO:root:Component 1009: submission took 0.09s
# INFO:root:Component 1010: size 500
# INFO:root:Component 1010: submission took 0.09s
# INFO:root:Component 1011: size 500
# INFO:root:Component 1011: submission took 0.10s
# INFO:root:Component 1012: size 500
# INFO:root:Component 1012: submission took 0.10s
# INFO:root:Component 1013: size 500
# INFO:root:Component 1013: submission took 0.10s
# INFO:root:Component 1014: size 500
# INFO:root:Component 1014: submission took 0.10s
# INFO:root:Component 1015: size 500
# INFO:root:Component 1015: submission took 0.09s
# INFO:root:Component 1016: size 500
# INFO:root:Component 1016: submission took 0.10s
# INFO:root:Component 1017: size 500
# INFO:root:Component 1017: submission took 0.10s
# INFO:root:Component 1018: size 500
# INFO:root:Component 1018: submission took 0.11s
# INFO:root:Component 1019: size 500
# INFO:root:Component 1019: submission took 0.10s
# INFO:root:Component 1020: size 500
# INFO:root:Component 1020: submission took 0.10s
# INFO:root:Component 1021: size 500
# INFO:root:Component 1021: submission took 0.10s
# INFO:root:Component 1022: size 499
# INFO:root:Component 1022: submission took 0.09s
# INFO:root:Component 1023: size 1
# INFO:root:Component 1023: submission took 0.10s
# INFO:root:Component 1024: size 500
# INFO:root:Component 1024: submission took 0.10s
# INFO:root:Component 1025: size 500
# INFO:root:Component 1025: submission took 0.09s
# INFO:root:Component 1026: size 500
# INFO:root:Component 1026: submission took 0.09s
# INFO:root:Component 1027: size 500
# INFO:root:Component 1027: submission took 0.10s
# INFO:root:Component 1028: size 500
# INFO:root:Component 1028: submission took 0.09s
# INFO:root:Component 1029: size 500
# INFO:root:Component 1029: submission took 0.09s
# INFO:root:Component 1030: size 500
# INFO:root:Component 1030: submission took 0.10s
# INFO:root:Component 1031: size 500
# INFO:root:Component 1031: submission took 0.09s
# INFO:root:Component 1032: size 500
# INFO:root:Component 1032: submission took 0.09s
# INFO:root:Component 1033: size 500
# INFO:root:Component 1033: submission took 0.09s
# INFO:root:Component 1034: size 500
# INFO:root:Component 1034: submission took 0.10s
# INFO:root:Component 1035: size 500
# INFO:root:Component 1035: submission took 0.09s
# INFO:root:Component 1036: size 500
# INFO:root:Component 1036: submission took 0.09s
# INFO:root:Component 1037: size 500
# INFO:root:Component 1037: submission took 0.10s
# INFO:root:Component 1038: size 500
# INFO:root:Component 1038: submission took 0.10s
# INFO:root:Component 1039: size 500
# INFO:root:Component 1039: submission took 0.10s
# INFO:root:Component 1040: size 500
# INFO:root:Component 1040: submission took 0.09s
# INFO:root:Component 1041: size 500
# INFO:root:Component 1041: submission took 0.09s
# INFO:root:Component 1042: size 500
# INFO:root:Component 1042: submission took 0.09s
# INFO:root:Component 1043: size 500
# INFO:root:Component 1043: submission took 0.10s
# INFO:root:Component 1044: size 500
# INFO:root:Component 1044: submission took 0.09s
# INFO:root:Component 1045: size 500
# INFO:root:Component 1045: submission took 0.10s
# INFO:root:Component 1046: size 500
# INFO:root:Component 1046: submission took 0.09s
# INFO:root:Component 1047: size 500
# INFO:root:Component 1047: submission took 0.10s
# INFO:root:Component 1048: size 500
# INFO:root:Component 1048: submission took 0.09s
# INFO:root:Component 1049: size 500
# INFO:root:Component 1049: submission took 0.09s
# INFO:root:Component 1050: size 500
# INFO:root:Component 1050: submission took 0.09s
# INFO:root:Component 1051: size 500
# INFO:root:Component 1051: submission took 0.09s
# INFO:root:Component 1052: size 499
# INFO:root:Component 1052: submission took 0.10s
# INFO:root:Component 1053: size 1
# INFO:root:Component 1053: submission took 0.12s
# INFO:root:Component 1054: size 500
# INFO:root:Component 1054: submission took 0.14s
# INFO:root:Component 1055: size 500
# INFO:root:Component 1055: submission took 0.13s
# INFO:root:Component 1056: size 500
# INFO:root:Component 1056: submission took 0.10s
# INFO:root:Component 1057: size 500
# INFO:root:Component 1057: submission took 0.10s
# INFO:root:Component 1058: size 500
# INFO:root:Component 1058: submission took 0.10s
# INFO:root:Component 1059: size 500
# INFO:root:Component 1059: submission took 0.09s
# INFO:root:Component 1060: size 500
# INFO:root:Component 1060: submission took 0.11s
# INFO:root:Component 1061: size 500
# INFO:root:Component 1061: submission took 0.14s
# INFO:root:Component 1062: size 500
# INFO:root:Component 1062: submission took 0.10s
# INFO:root:Component 1063: size 500
# INFO:root:Component 1063: submission took 0.10s
# INFO:root:Component 1064: size 500
# INFO:root:Component 1064: submission took 0.10s
# INFO:root:Component 1065: size 500
# INFO:root:Component 1065: submission took 0.10s
# INFO:root:Component 1066: size 500
# INFO:root:Component 1066: submission took 0.10s
# INFO:root:Component 1067: size 500
# INFO:root:Component 1067: submission took 0.10s
# INFO:root:Component 1068: size 500
# INFO:root:Component 1068: submission took 0.10s
# INFO:root:Component 1069: size 500
# INFO:root:Component 1069: submission took 0.16s
# INFO:root:Component 1070: size 500
# INFO:root:Component 1070: submission took 0.18s
# INFO:root:Component 1071: size 500
# INFO:root:Component 1071: submission took 0.17s
# INFO:root:Component 1072: size 500
# INFO:root:Component 1072: submission took 0.20s
# INFO:root:Component 1073: size 500
# INFO:root:Component 1073: submission took 0.13s
# INFO:root:Component 1074: size 500
# INFO:root:Component 1074: submission took 0.28s
# INFO:root:Component 1075: size 500
# INFO:root:Component 1075: submission took 0.20s
# INFO:root:Component 1076: size 500
# INFO:root:Component 1076: submission took 0.12s
# INFO:root:Component 1077: size 500
# INFO:root:Component 1077: submission took 0.21s
# INFO:root:Component 1078: size 500
# INFO:root:Component 1078: submission took 0.11s
# INFO:root:Component 1079: size 500
# INFO:root:Component 1079: submission took 0.10s
# INFO:root:Component 1080: size 500
# INFO:root:Component 1080: submission took 0.10s
# INFO:root:Component 1081: size 500
# INFO:root:Component 1081: submission took 0.12s
# INFO:root:Component 1082: size 500
# INFO:root:Component 1082: submission took 0.10s
# INFO:root:Component 1083: size 500
# INFO:root:Component 1083: submission took 0.09s
# INFO:root:Component 1084: size 500
# INFO:root:Component 1084: submission took 0.09s
# INFO:root:Component 1085: size 500
# INFO:root:Component 1085: submission took 0.09s
# INFO:root:Component 1086: size 500
# INFO:root:Component 1086: submission took 0.10s
# INFO:root:Component 1087: size 500
# INFO:root:Component 1087: submission took 0.10s
# INFO:root:Component 1088: size 500
# INFO:root:Component 1088: submission took 0.10s
# INFO:root:Component 1089: size 500
# INFO:root:Component 1089: submission took 0.10s
# INFO:root:Component 1090: size 500
# INFO:root:Component 1090: submission took 0.09s
# INFO:root:Component 1091: size 500
# INFO:root:Component 1091: submission took 0.10s
# INFO:root:Component 1092: size 500
# INFO:root:Component 1092: submission took 0.10s
# INFO:root:Component 1093: size 500
# INFO:root:Component 1093: submission took 0.09s
# INFO:root:Component 1094: size 500
# INFO:root:Component 1094: submission took 0.09s
# INFO:root:Component 1095: size 499
# INFO:root:Component 1095: submission took 0.10s
# INFO:root:Component 1096: size 1
# INFO:root:Component 1096: submission took 0.09s
# INFO:root:Component 1097: size 500
# INFO:root:Component 1097: submission took 0.10s
# INFO:root:Component 1098: size 500
# INFO:root:Component 1098: submission took 0.09s
# INFO:root:Component 1099: size 500
# INFO:root:Component 1099: submission took 0.09s
# INFO:root:Component 1100: size 500
# INFO:root:Component 1100: submission took 0.10s
# INFO:root:Component 1101: size 500
# INFO:root:Component 1101: submission took 0.09s
# INFO:root:Component 1102: size 500
# INFO:root:Component 1102: submission took 0.10s
# INFO:root:Component 1103: size 500
# INFO:root:Component 1103: submission took 0.09s
# INFO:root:Component 1104: size 500
# INFO:root:Component 1104: submission took 0.10s
# INFO:root:Component 1105: size 500
# INFO:root:Component 1105: submission took 0.09s
# INFO:root:Component 1106: size 500
# INFO:root:Component 1106: submission took 0.09s
# INFO:root:Component 1107: size 500
# INFO:root:Component 1107: submission took 0.12s
# INFO:root:Component 1108: size 500
# INFO:root:Component 1108: submission took 0.09s
# INFO:root:Component 1109: size 500
# INFO:root:Component 1109: submission took 0.10s
# INFO:root:Component 1110: size 500
# INFO:root:Component 1110: submission took 0.09s
# INFO:root:Component 1111: size 500
# INFO:root:Component 1111: submission took 0.09s
# INFO:root:Component 1112: size 500
# INFO:root:Component 1112: submission took 0.10s
# INFO:root:Component 1113: size 500
# INFO:root:Component 1113: submission took 0.10s
# INFO:root:Component 1114: size 500
# INFO:root:Component 1114: submission took 0.10s
# INFO:root:Component 1115: size 500
# INFO:root:Component 1115: submission took 0.09s
# INFO:root:Component 1116: size 500
# INFO:root:Component 1116: submission took 0.09s
# INFO:root:Component 1117: size 500
# INFO:root:Component 1117: submission took 0.09s
# INFO:root:Component 1118: size 500
# INFO:root:Component 1118: submission took 0.10s
# INFO:root:Component 1119: size 500
# INFO:root:Component 1119: submission took 0.10s
# INFO:root:Component 1120: size 500
# INFO:root:Component 1120: submission took 0.10s
# INFO:root:Component 1121: size 500
# INFO:root:Component 1121: submission took 0.09s
# INFO:root:Component 1122: size 500
# INFO:root:Component 1122: submission took 0.10s
# INFO:root:Component 1123: size 500
# INFO:root:Component 1123: submission took 0.10s
# INFO:root:Component 1124: size 499
# INFO:root:Component 1124: submission took 0.09s
# INFO:root:Component 1125: size 1
# INFO:root:Component 1125: submission took 0.09s
# INFO:root:Component 1126: size 500
# INFO:root:Component 1126: submission took 0.09s
# INFO:root:Component 1127: size 500
# INFO:root:Component 1127: submission took 0.10s
# INFO:root:Component 1128: size 500
# INFO:root:Component 1128: submission took 0.10s
# INFO:root:Component 1129: size 500
# INFO:root:Component 1129: submission took 0.09s
# INFO:root:Component 1130: size 500
# INFO:root:Component 1130: submission took 0.09s
# INFO:root:Component 1131: size 500
# INFO:root:Component 1131: submission took 0.10s
# INFO:root:Component 1132: size 500
# INFO:root:Component 1132: submission took 0.09s
# INFO:root:Component 1133: size 500
# INFO:root:Component 1133: submission took 0.11s
# INFO:root:Component 1134: size 500
# INFO:root:Component 1134: submission took 0.17s
# INFO:root:Component 1135: size 500
# INFO:root:Component 1135: submission took 0.13s
# INFO:root:Component 1136: size 500
# INFO:root:Component 1136: submission took 0.10s
# INFO:root:Component 1137: size 500
# INFO:root:Component 1137: submission took 0.10s
# INFO:root:Component 1138: size 500
# INFO:root:Component 1138: submission took 0.11s
# INFO:root:Component 1139: size 500
# INFO:root:Component 1139: submission took 0.33s
# INFO:root:Component 1140: size 500
# INFO:root:Component 1140: submission took 0.31s
# INFO:root:Component 1141: size 500
# INFO:root:Component 1141: submission took 0.18s
# INFO:root:Component 1142: size 500
# INFO:root:Component 1142: submission took 0.17s
# INFO:root:Component 1143: size 500
# INFO:root:Component 1143: submission took 0.11s
# INFO:root:Component 1144: size 500
# INFO:root:Component 1144: submission took 0.10s
# INFO:root:Component 1145: size 500
# INFO:root:Component 1145: submission took 0.10s
# INFO:root:Component 1146: size 500
# INFO:root:Component 1146: submission took 0.10s
# INFO:root:Component 1147: size 500
# INFO:root:Component 1147: submission took 0.12s
# INFO:root:Component 1148: size 500
# INFO:root:Component 1148: submission took 0.26s
# INFO:root:Component 1149: size 500
# INFO:root:Component 1149: submission took 0.14s
# INFO:root:Component 1150: size 500
# INFO:root:Component 1150: submission took 0.10s
# INFO:root:Component 1151: size 500
# INFO:root:Component 1151: submission took 0.10s
# INFO:root:Component 1152: size 500
# INFO:root:Component 1152: submission took 0.10s
# INFO:root:Component 1153: size 500
# INFO:root:Component 1153: submission took 0.09s
# INFO:root:Component 1154: size 500
# INFO:root:Component 1154: submission took 0.10s
# INFO:root:Component 1155: size 500
# INFO:root:Component 1155: submission took 0.10s
# INFO:root:Component 1156: size 500
# INFO:root:Component 1156: submission took 0.11s
# INFO:root:Component 1157: size 500
# INFO:root:Component 1157: submission took 0.10s
# INFO:root:Component 1158: size 500
# INFO:root:Component 1158: submission took 0.10s
# INFO:root:Component 1159: size 500
# INFO:root:Component 1159: submission took 0.09s
# INFO:root:Component 1160: size 500
# INFO:root:Component 1160: submission took 0.09s
# INFO:root:Component 1161: size 500
# INFO:root:Component 1161: submission took 0.10s
# INFO:root:Component 1162: size 500
# INFO:root:Component 1162: submission took 0.10s
# INFO:root:Component 1163: size 500
# INFO:root:Component 1163: submission took 0.11s
# INFO:root:Component 1164: size 500
# INFO:root:Component 1164: submission took 0.11s
# INFO:root:Component 1165: size 500
# INFO:root:Component 1165: submission took 0.10s
# INFO:root:Component 1166: size 500
# INFO:root:Component 1166: submission took 0.11s
# INFO:root:Component 1167: size 500
# INFO:root:Component 1167: submission took 0.11s
# INFO:root:Component 1168: size 500
# INFO:root:Component 1168: submission took 0.10s
# INFO:root:Component 1169: size 500
# INFO:root:Component 1169: submission took 0.10s
# INFO:root:Component 1170: size 500
# INFO:root:Component 1170: submission took 0.10s
# INFO:root:Component 1171: size 500
# INFO:root:Component 1171: submission took 0.10s
# INFO:root:Component 1172: size 500
# INFO:root:Component 1172: submission took 0.10s
# INFO:root:Component 1173: size 500
# INFO:root:Component 1173: submission took 0.10s
# INFO:root:Component 1174: size 500
# INFO:root:Component 1174: submission took 0.10s
# INFO:root:Component 1175: size 500
# INFO:root:Component 1175: submission took 0.12s
# INFO:root:Component 1176: size 500
# INFO:root:Component 1176: submission took 0.11s
# INFO:root:Component 1177: size 500
# INFO:root:Component 1177: submission took 0.10s
# INFO:root:Component 1178: size 500
# INFO:root:Component 1178: submission took 0.09s
# INFO:root:Component 1179: size 500
# INFO:root:Component 1179: submission took 0.10s
# INFO:root:Component 1180: size 500
# INFO:root:Component 1180: submission took 0.10s
# INFO:root:Component 1181: size 500
# INFO:root:Component 1181: submission took 0.10s
# INFO:root:Component 1182: size 500
# INFO:root:Component 1182: submission took 0.10s
# INFO:root:Component 1183: size 500
# INFO:root:Component 1183: submission took 0.09s
# INFO:root:Component 1184: size 500
# INFO:root:Component 1184: submission took 0.10s
# INFO:root:Component 1185: size 500
# INFO:root:Component 1185: submission took 0.09s
# INFO:root:Component 1186: size 500
# INFO:root:Component 1186: submission took 0.10s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 h_out = to_hierarchical_clusters_pa(cc200)
#       3 h_out
#
# Cell In[10], line 23, in to_hierarchical_clusters_pa(table)
#      21 for i, comp in enumerate(components):
#      22     t_start = time.time()
# ---> 23     mask = pc.equal(table["component"], comp)
#      24     component_table = table.filter(mask)
#      25     logging.info(f"Component {i}: size {len(component_table)}")
#
# File ~/DS/matchbox/.venv/lib/python3.11/site-packages/pyarrow/compute.py:247, in _make_generic_wrapper.<locals>.wrapper(memory_pool, *args)
#     245 if args and isinstance(args[0], Expression):
#     246     return Expression._call(func_name, list(args))
# --> 247 return func.call(args, None, memory_pool)
#
# KeyboardInterrupt:
