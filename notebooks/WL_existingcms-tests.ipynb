# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import IFrame, display
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # ExistingCMSPlus linker
#
# A place to fix and test the existing CMS+ linker.

# %%
from src import locations as loc
from src.data import utils as du
from src.data.star import Star
from src.data.datasets import Dataset
from src.data.probabilities import Probabilities
from src.data.clusters import Clusters
from src.data.validation import Validation
from src.link.existingservice_linker import ExistingCMSPlusLinker
from src.features.clean_complex import duckdb_cleaning_factory
from src.features.clean_basic_original import (
    cms_original_clean_company_name_general,
    cms_original_clean_company_name_ch,
    cms_original_clean_postcode,
    cms_original_clean_email,
    cms_original_clean_ch_id,
    cms_original_clean_cdms_id
)

from dotenv import load_dotenv, find_dotenv
import os
import duckdb
from pathlib import Path
import pandas as pd

dotenv_path = find_dotenv()
load_dotenv(dotenv_path)
# Out:
# DEBUG:git.cmd:Popen(['git', 'version'], cwd=/home/jovyan/company-matching/notebooks, universal_newlines=False, shell=None, istream=None)
# DEBUG:git.cmd:Popen(['git', 'version'], cwd=/home/jovyan/company-matching/notebooks, universal_newlines=False, shell=None, istream=None)
# True

# %%
star = Star(
    schema = os.getenv("SCHEMA"),
    table = os.getenv("STAR_TABLE")
)
probabilities = Probabilities(
    schema = os.getenv("SCHEMA"),
    table = os.getenv("PROBABILITIES_TABLE"),
    star = star
)
clusters = Clusters(
    schema = os.getenv("SCHEMA"),
    table = os.getenv("CLUSTERS_TABLE"),
    star = star
)
validation = Validation(
    schema = os.getenv("SCHEMA"),
    table = os.getenv("VALIDATE_TABLE")
)

# %%
cl_x_exp = ExistingCMSPlusLinker(
    name="n1_cms_basic",
    dataset = Dataset(
        star_id=54717,
        star=star
    ), 
    probabilities=probabilities, 
    clusters=clusters, 
    n=1,
    overwrite=True
)

# %%
cl_x_exp.get_data(
    # sample=5,
    cluster_select={
        '"companieshouse"."companies"': [
            "company_name as company_name",
            "postcode as postcode"
        ]
    },
    dim_select=[
        "id",
        "company_name",
        "postcode"
    ],
)

# %%
clean_postcode = duckdb_cleaning_factory(cms_original_clean_postcode)
clean_ch_name = duckdb_cleaning_factory(cms_original_clean_company_name_ch)
clean_gen_name = duckdb_cleaning_factory(cms_original_clean_company_name_general)

cluster_pipeline={
    "clean_ch_comp_names": {
        "function": clean_ch_name,
        "arguments": {
            "column": "company_name"
        },
    },
    "clean_postcode": {
        "function": clean_postcode,
        "arguments": {
            "column": "postcode"
        },
    }
}
dim_pipeline={
    "clean__comp_names": {
        "function": clean_gen_name,
        "arguments": {
            "column": "company_name"
        },
    },
    "clean_postcode": {
        "function": clean_postcode,
        "arguments": {
            "column": "postcode"
        },
    }
}
link_settings={
    "company_name": {
        "cluster": "company_name",
        "dimension": "company_name",
        "weight": 2
    },
    "postcode": {
        "cluster": "postcode",
        "dimension": "postcode",
        "weight": 1
    }
}

# %% [markdown]
# ## Full evaluation

# %%
cl_x_exp.evaluate(
    link_experiment="cm_hmrc-trade-exporters",
    evaluation_description="""
        - Existing CMS for name/postcode
        - Cleaned name as per existing CMS rules
        - Name match double weighted
    """,
    prepare_kwargs={
        "cluster_pipeline": cluster_pipeline,
        "dim_pipeline": dim_pipeline,
        "link_settings": link_settings
    },
    link_kwargs={
        "threshold": 0.5
    },
    report_dir=Path(
        loc.PROJECT_DIR, 
        'scratch', 
        'reports', 
        'cm_hmrc-trade-exporters',
        'existing'
    ),
    log_mlflow=True,
    log_output=True,
)
# Out:
# INFO:src.link.linker:Running pipeline
# INFO:src.link.linker:Logging outputs to the Probabilities table
# INFO:src.link.linker:Logging as MLflow experiment
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): mlflow--data-science.data.trade.gov.uk:8004
# DEBUG:urllib3.connectionpool:http://mlflow--data-science.data.trade.gov.uk:8004 "GET /api/2.0/mlflow/experiments/get-by-name?experiment_name=cm_hmrc-trade-exporters HTTP/1.1" 200 245
# DEBUG:urllib3.connectionpool:Resetting dropped connection: mlflow--data-science.data.trade.gov.uk
# DEBUG:urllib3.connectionpool:http://mlflow--data-science.data.trade.gov.uk:8004 "GET /api/2.0/mlflow/experiments/get-by-name?experiment_name=cm_hmrc-trade-exporters HTTP/1.1" 200 245
# DEBUG:git.util:Failed checking if running in CYGWIN due to: FileNotFoundError(2, 'No such file or directory')
# DEBUG:urllib3.connectionpool:Resetting dropped connection: mlflow--data-science.data.trade.gov.uk
# DEBUG:urllib3.connectionpool:http://mlflow--data-science.data.trade.gov.uk:8004 "POST /api/2.0/mlflow/runs/create HTTP/1.1" 200 1075
# DEBUG:urllib3.connectionpool:Resetting dropped connection: mlflow--data-science.data.trade.gov.uk
# DEBUG:urllib3.connectionpool:http://mlflow--data-science.data.trade.gov.uk:8004 "POST /api/2.0/mlflow/runs/log-batch HTTP/1.1" 200 2
# INFO:src.link.linker:Running prepare() function
# INFO:src.link.linker:Running link() function
# DEBUG:urllib3.connectionpool:Resetting dropped connection: mlflow--data-science.data.trade.gov.uk
# DEBUG:urllib3.connectionpool:http://mlflow--data-science.data.trade.gov.uk:8004 "GET /api/2.0/mlflow/runs/get?run_uuid=ec3a460012274e5b9942192f5699e0b4&run_id=ec3a460012274e5b9942192f5699e0b4 HTTP/1.1" 200 1222
# DEBUG:urllib3.connectionpool:Resetting dropped connection: mlflow--data-science.data.trade.gov.uk
# DEBUG:urllib3.connectionpool:http://mlflow--data-science.data.trade.gov.uk:8004 "PUT /api/2.0/mlflow-artifacts/artifacts/4/ec3a460012274e5b9942192f5699e0b4/artifacts/error.txt HTTP/1.1" 200 2
# DEBUG:urllib3.connectionpool:Resetting dropped connection: mlflow--data-science.data.trade.gov.uk
# DEBUG:urllib3.connectionpool:http://mlflow--data-science.data.trade.gov.uk:8004 "POST /api/2.0/mlflow/runs/update HTTP/1.1" 200 421
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cl_x_exp.evaluate(
#       2     link_experiment="cm_hmrc-trade-exporters",
#       3     evaluation_description="""
#       4         - Deterministic name/postcode
#       5         - Cleaned name as per existing CMS rules
#       6     """,
#       7     prepare_kwargs={
#       8         "cluster_pipeline": cluster_pipeline,
#       9         "dim_pipeline": dim_pipeline,
#      10         "link_settings": link_settings
#      11     },
#      12     link_kwargs={
#      13         "threshold": 0.5
#      14     },
#      15     report_dir=Path(
#      16         loc.PROJECT_DIR,
#      17         'scratch',
#      18         'reports',
#      19         'cm_hmrc-trade-exporters',
#      20         'existing'
#      21     ),
#      22     log_mlflow=True,
#      23     log_output=True,
#      24 )
#
# File ~/company-matching/src/link/linker.py:346, in Linker.evaluate(self, link_experiment, evaluation_description, prepare_kwargs, link_kwargs, evaluation_name, report_dir, log_mlflow, log_output)
#     343 self.prepare(**prepare_kwargs)
#     345 logger.info("Running link() function")
# --> 346 self.link(log_output=log_output, **link_kwargs)
#     348 # TODO: Evaluation method based on validation table
#     349 # Table not yet implemented
#     351 for artefact in self.report_artefacts.keys():
#
# File ~/company-matching/src/link/existingservice_linker.py:162, in ExistingCMSPlusLinker.link(self, threshold, log_output, overwrite)
#     142 total_weight = sum(weights)
#     144 self.predictions = self.con.sql(f"""
#     145     select
#     146         cls.id as cluster,
#    (...)
#     159         probability > {threshold}
#     160 """)
# --> 162 out = self.predictions.df()
#     164 super()._add_log_item(
#     165     name="link_threshold", item=str(threshold), item_type="parameter"
#     166 )
#     168 super()._add_log_item(
#     169     name="match_pct",
#     170     item=out.id.nunique() / self.dim_processed.shape[0],
#     171     item_type="metric"
#     172 )
#
# Error: Invalid Error: KeyboardInterrupt: <EMPTY MESSAGE>

# %% [markdown]
# ## Prepare data

# %%
cl_x_exp.prepare(
    cluster_pipeline=cluster_pipeline,
    dim_pipeline=dim_pipeline,
    link_settings=link_settings
)

# %%
cl_x_exp.dim_processed.head(5)
cl_x_exp.cluster_processed.head(5)
# Out:
#         id  company_name postcode
# 0  2937257   194localvtg    e16sa
# 1  2124828          1953  ec1y8jl
# 2  2570378          1953   sw32er
# 3  1537512  195mphlmited    s92tj
# 4  3359348  195mphlmited  dn227wf
#                                      id            company_name postcode
# 0  09bc545d-236a-4d15-9073-49ddabdc4b50  109uptonroadmanagement   ca89lz
# 1  0d4d985a-c15b-43e2-8142-c8f868025e1a                1093edin   g403px
# 2  cb9118f3-556c-4b1d-b3b5-ceaaa29993b8                 1094874    s11wf
# 3  1016c07d-2330-4076-ab7d-21ab6900a431               109london   ss11eg
# 4  c0e587ab-4b94-4c70-bcd0-b57b8c64ca21               1010games   bl14qr

# %% [markdown]
# ## Link data

# %%
cl_x_exp.con.sql(f"""
    select
        matches.cluster,
        matches.id,
        {cl_x_exp.dataset.id} as source,
        sum(matches.probability) / 3 as probability
    from (
        select
            cls.id as cluster,
            dim.id::text as id,
            1 * 2 as probability
        from
            cls cls
        left join
            dim dim on
                cls.company_name = dim.company_name
        where
            dim.id is not null
        union all
        select
            cls.id as cluster,
            dim.id::text as id,
            1 * 1 as probability
        from
            cls cls
        left join
            dim dim on
                cls.postcode = dim.postcode
        where
            dim.id is not null
    ) matches
    group by
        matches.cluster,
        matches.id
    having
        sum(matches.probability) / 3 > 0
""")
# Out:
# ┌──────────────────────────────────────┬─────────┬────────┬────────────────────┐
# │               cluster                │   id    │ source │    probability     │
# │                 uuid                 │ varchar │ int32  │       double       │
# ├──────────────────────────────────────┼─────────┼────────┼────────────────────┤
# │ 8b91a15e-8c93-4088-afa1-ec09c07427f3 │ 3426632 │  54717 │ 0.3333333333333333 │
# │ aae65716-924d-4d36-93db-cdbece76e638 │ 2246722 │  54717 │ 0.3333333333333333 │
# │ bcc34b84-b001-469e-9769-f8ce8fd59e4a │ 3001632 │  54717 │ 0.3333333333333333 │
# │ 6519eaf2-3581-464c-8720-5c932800d032 │ 1622136 │  54717 │ 0.3333333333333333 │
# │ 46a62a51-e903-4eb0-a46a-5d0e66fbb1a6 │ 1622136 │  54717 │ 0.3333333333333333 │
# │ c61121d2-647b-43ec-b33c-6a39ea4ec75a │ 1622136 │  54717 │ 0.3333333333333333 │
# │ 2635d38c-98f7-4374-88b2-14ca94417ffc │ 2785802 │  54717 │ 0.3333333333333333 │
# │ 326db4ee-9554-490b-9a5c-a0ffdaeca286 │ 629441  │  54717 │ 0.3333333333333333 │
# │ c6eff6ef-4a3d-4bb4-9c33-0f4a2b913b2a │ 2861672 │  54717 │ 0.3333333333333333 │
# │ dc7b42c0-cb36-4b17-bc13-e75bab8f3b37 │ 2345024 │  54717 │ 0.3333333333333333 │
# │                  ·                   │    ·    │    ·   │          ·         │
# │                  ·                   │    ·    │    ·   │          ·         │
# │                  ·                   │    ·    │    ·   │          ·         │
# │ 1a5056a9-9264-478c-ab81-a76b8776771b │ 2840536 │  54717 │ 0.3333333333333333 │
# │ c61121d2-647b-43ec-b33c-6a39ea4ec75a │ 3367505 │  54717 │ 0.3333333333333333 │
# │ 7868255b-ba69-4118-9be4-e5b63da885be │ 1992280 │  54717 │ 0.3333333333333333 │
# │ d397282f-647d-4c83-adb2-80714b829981 │ 2800177 │  54717 │ 0.3333333333333333 │
# │ 280755cc-b46d-43b1-bc9e-3efdf7c03af3 │ 1068889 │  54717 │ 0.3333333333333333 │
# │ ea99d75e-dde2-48e5-954e-4a110167dec4 │ 2404143 │  54717 │ 0.3333333333333333 │
# │ b6140a24-bde3-4737-974f-e6c5ed79771b │ 3380201 │  54717 │ 0.3333333333333333 │
# │ 5a84e246-a571-4a11-a075-f67c873c30ba │ 2603096 │  54717 │ 0.3333333333333333 │
# │ 9eecc522-3e2a-402e-a50e-6655847cbbff │ 2248791 │  54717 │ 0.3333333333333333 │
# │ 6ec9f504-3682-4ab3-8553-b0c408be6b1a │ 1222853 │  54717 │ 0.3333333333333333 │
# ├──────────────────────────────────────┴─────────┴────────┴────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                      4 columns │
# └──────────────────────────────────────────────────────────────────────────────┘

# %%
cl_x_exp.link(
    log_output=True
)
# Out:
#                                      cluster       id  source  probability  \
# 0       35f7dbe2-2eb1-4df7-b50f-041cbc5d246e  1077171   54717     0.333333
# 1       f33a7ab9-85b2-482e-8c02-5ca791ba76fc  1077171   54717     0.333333
# 2       524e2a90-bc77-4b3d-992b-53ecd6dbc792  1077171   54717     0.333333
# 3       b2c53705-e74c-47ef-9b32-94cb941ba393  1077171   54717     0.333333
# 4       e9c1fd4e-b2ec-489a-8c94-5cdcc7a7ac1e  1077171   54717     0.333333
# ...                                      ...      ...     ...          ...
# 245554  0e90228b-bde8-4f8b-a1db-cdbf233475a7  2260542   54717     0.333333
# 245555  26383f41-63d7-400d-97c0-3703b14584c5  2480128   54717     0.333333
# 245556  8f6d6a90-a62e-4fc3-bcd1-cc6832c6f218  2480128   54717     0.333333
# 245557  261972d3-5c94-4e03-9ff9-e00d4f4099c6  3056055   54717     0.333333
# 245558  3a115a0c-c05b-4e2d-b105-d317ce4bda36     2722   54717     0.333333
#
#                                         uuid link_type         model
# 0       029e3732-4154-4cb2-98b4-8e64e1196c31      link  n1_cms_basic
# 1       a9ed34c6-6018-496f-9617-3c62ac0b36cd      link  n1_cms_basic
# 2       0b6f4cf7-aecc-4f90-93ed-0bd7e0e21922      link  n1_cms_basic
# 3       4910d8b9-ee29-4a9a-a873-a2135c27d3f0      link  n1_cms_basic
# 4       f930bf59-dea7-4bb3-afb3-f0fd72a244f8      link  n1_cms_basic
# ...                                      ...       ...           ...
# 245554  03a1ff06-dda2-4c8f-8696-bf62218fdf70      link  n1_cms_basic
# 245555  a6dbf884-a09b-46d1-9cc4-64f3b587c241      link  n1_cms_basic
# 245556  d6f48469-11d3-4765-9e0d-852323f82c6e      link  n1_cms_basic
# 245557  acd959d2-0f04-4084-adc9-93a363bb2d24      link  n1_cms_basic
# 245558  a36e5b34-e9cb-46d9-bf01-ce9935aff1f3      link  n1_cms_basic
#
# [245559 rows x 7 columns]
