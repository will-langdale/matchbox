# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import IFrame
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Companies House x HMRC exporters
#
# I want to build this in a way that one can improve a link pair in a notebook, then deploy those changes to the link easily. I'm going to play with this idea here.

# %%
from src.data import utils as du
from src.models import utils as mu
from src.config import tables, stopwords
from src.features.clean_complex import clean_comp_names
from src.link.make_link import LinkDatasets

from splink.duckdb.linker import DuckDBLinker
import splink.duckdb.comparison_library as cl
import splink.duckdb.comparison_template_library as ctl

# import os
import logging
import mlflow
from functools import partial
from dotenv import load_dotenv, find_dotenv

# %%
settings = {
    "link_type": "link_only",
    "unique_id_column_name": "id",
    "retain_matching_columns": False,
    "retain_intermediate_calculation_columns": False,
    "blocking_rules_to_generate_predictions": [
        """
            (l.name_unusual_tokens = r.name_unusual_tokens)
            and (
                l.name_unusual_tokens <> ''
                and r.name_unusual_tokens <> ''
            )
        """,
        """
            (l.postcode = r.postcode)
            and (
                l.postcode <> ''
                and r.postcode <> ''
            )
        """
    ],
    "comparisons": [
        cl.jaro_winkler_at_thresholds(
            "name_unusual_tokens", [0.9, 0.6], term_frequency_adjustments=True
        ),
        ctl.postcode_comparison("postcode")
    ],
}

# %%
pipeline = {
    "estimate_probability_two_random_records_match": {
        "deterministic_matching_rules": """
            l.name_unusual_tokens = r.name_unusual_tokens
        """,
        "recall": 0.7
    },
    "estimate_u_using_random_sampling": {
        "max_pairs": 1e6
    },
    "estimate_parameters_using_expectation_maximisation": {
        "blocking_rule": """
            l.name_unusual_tokens = r.name_unusual_tokens
        """
    }
}

# %%
ch_settings = {
    "name": '"companieshouse"."companies"',
    "select": [
        "id::text",
        "company_name",
        "postcode"
    ],
    "preproc": {
        clean_comp_names: {
            "primary_col": "company_name",
            "secondary_col": None,
            "stopwords": stopwords
        }
    }
}

# %%
exp_settings = {
    "name": '"hmrc"."trade__exporters"',
    "select": [
        "id::text",
        "company_name",
        "postcode"
    ],
    "preproc": {
        clean_comp_names: {
            "primary_col": "company_name",
            "secondary_col": None,
            "stopwords": stopwords
        }
    }
}

# %%
ch_x_exp = LinkDatasets(
    table_l = ch_settings,
    table_r = exp_settings,
    settings = settings,
    pipeline = pipeline
)

# %%
ch_x_exp.get_data()
# Out:
# /opt/conda/envs/company_matching/lib/python3.9/site-packages/pandas/io/sql.py:1410: RemovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   meta = MetaData(self.connectable, schema=schema)

# %%
ch_x_exp.preprocess_data()

# %%
ch_x_exp.create_linker()

# %%
ch_x_exp.train_linker()
# Out:
# Probability two random records match is estimated to be  2.33e-07.
# This means that amongst all possible pairwise record comparisons, one in 4,294,837.17 are expected to match.  With 1,368,138,787,675 total possible comparisons, we expect a total of around 318,554.29 matching pairs
# ----- Estimating u probabilities using random sampling -----
# u probability not trained for name_unusual_tokens - Exact match (comparison vector value: 3). This usually means the comparison level was never observed in the training data.
#
# Estimated u probabilities using random sampling
#
# Your model is not yet fully trained. Missing estimates for:
#     - name_unusual_tokens (some u values are not trained, no m values are trained).
#     - postcode (no m values are trained).
#
# ----- Starting EM training session -----
#
# Estimating the m probabilities of the model by blocking on:
#
#             l.name_unusual_tokens = r.name_unusual_tokens
#
#
# Parameter estimates will be made for the following comparison(s):
#     - postcode
#
# Parameter estimates cannot be made for the following comparison(s) since they are used in the blocking rules:
#     - name_unusual_tokens
#
# Iteration 1: Largest change in params was 0.399 in probability_two_random_records_match
# Iteration 2: Largest change in params was -0.0873 in the m_probability of postcode, level `Exact match postcode`
# Iteration 3: Largest change in params was -0.0659 in the m_probability of postcode, level `Exact match postcode`
# Iteration 4: Largest change in params was 0.121 in the m_probability of postcode, level `Exact match Postcode Area`
# Iteration 5: Largest change in params was 0.0548 in the m_probability of postcode, level `Exact match Postcode Area`
# Iteration 6: Largest change in params was 0.00374 in the m_probability of postcode, level `Exact match Postcode Area`
# Iteration 7: Largest change in params was 0.000185 in the m_probability of postcode, level `Exact match Postcode Area`
# Iteration 8: Largest change in params was 8.99e-06 in the m_probability of postcode, level `Exact match Postcode Area`
#
# EM converged after 8 iterations
#
# Your model is not yet fully trained. Missing estimates for:
#     - name_unusual_tokens (some u values are not trained, no m values are trained).

# %%
ch_x_exp.predict(threshold_match_probability=0.7)
# Out:
#  -- WARNING --
# You have called predict(), but there are some parameter estimates which have neither been estimated or specified in your settings dictionary.  To produce predictions the following untrained trained parameters will use default values.
# Comparison: 'name_unusual_tokens':
#     m values not fully trained
# Comparison: 'name_unusual_tokens':
#     u values not fully trained

# %%
ch_x_exp.generate_report(sample=10)
# Out:
# {'eval_matches': 175842,
#  'pred_matches': 152541,
#  'both_eval_and_pred': 104647,
#  'eval_only': 71195,
#  'pred_only': 47894,
#  'both_eval_and_pred_sample': [{'id_l': '02900615',
#    'id_r': '1448544',
#    'match_probability': 0.9999811108482505,
#    'score': 4,
#    'company_name_l_pred': 'RESCROFT LIMITED',
#    'postcode_l_pred': 'B98 0RE',
#    'company_name_r_pred': 'RESCROFT LIMITED',
#    'postcode_r_pred': 'B98 0RE',
#    'company_name_l_exist': 'RESCROFT LIMITED',
#    'postcode_l_exist': 'B98 0RE',
#    'company_name_r_exist': 'RESCROFT LIMITED',
#    'postcode_r_exist': 'B98 0RE'},
#   {'id_l': '03777854',
#    'id_r': '348072',
#    'match_probability': 0.9999716665399733,
#    'score': 5,
#    'company_name_l_pred': 'ARBOR VITAE LIMITED',
#    'postcode_l_pred': 'WF10 1BY',
#    'company_name_r_pred': 'ARBOR VITAE LTD',
#    'postcode_r_pred': 'WF10 1BY',
#    'company_name_l_exist': 'ARBOR VITAE LIMITED',
#    'postcode_l_exist': 'WF10 1BY',
#    'company_name_r_exist': 'ARBOR VITAE LTD',
#    'postcode_r_exist': 'WF10 1BY'},
#   {'id_l': '05427798',
#    'id_r': '3104487',
#    'match_probability': 0.995552717260106,
#    'score': 4,
#    'company_name_l_pred': 'NATURAL WONDERS LIMITED',
#    'postcode_l_pred': 'YO22 4NG',
#    'company_name_r_pred': 'NATURAL WONDERS LTD',
#    'postcode_r_pred': 'YO22 4BA',
#    'company_name_l_exist': 'NATURAL WONDERS LIMITED',
#    'postcode_l_exist': 'YO22 4NG',
#    'company_name_r_exist': 'NATURAL WONDERS LTD',
#    'postcode_r_exist': 'YO22 4BA'},
#   {'id_l': '00816672',
#    'id_r': '2446901',
#    'match_probability': 0.9999811108482505,
#    'score': 4,
#    'company_name_l_pred': 'NTN BEARINGS (UK) LIMITED',
#    'postcode_l_pred': 'WS13 8RZ',
#    'company_name_r_pred': 'NTN BEARINGS (UK) LIMITED',
#    'postcode_r_pred': 'WS13 8RZ',
#    'company_name_l_exist': 'NTN BEARINGS (UK) LIMITED',
#    'postcode_l_exist': 'WS13 8RZ',
#    'company_name_r_exist': 'NTN BEARINGS (UK) LIMITED',
#    'postcode_r_exist': 'WS13 8RZ'},
#   {'id_l': '07514101',
#    'id_r': '537028',
#    'match_probability': 0.9149827082212684,
#    'score': 4,
#    'company_name_l_pred': 'APPIAN TECHNOLOGIES LTD',
#    'postcode_l_pred': 'BS4 3EH',
#    'company_name_r_pred': 'APPIAN TECHNOLOGIES LTD',
#    'postcode_r_pred': 'BS41 9DY',
#    'company_name_l_exist': 'APPIAN TECHNOLOGIES LTD',
#    'postcode_l_exist': 'BS4 3EH',
#    'company_name_r_exist': 'APPIAN TECHNOLOGIES LTD',
#    'postcode_r_exist': 'BS41 9DY'},
#   {'id_l': '01803787',
#    'id_r': '625978',
#    'match_probability': 0.9999622224100877,
#    'score': 5,
#    'company_name_l_pred': 'ACAL BFI UK LIMITED',
#    'postcode_l_pred': 'RG41 2EY',
#    'company_name_r_pred': 'ACAL BFI UK LIMITED',
#    'postcode_r_pred': 'RG41 2EY',
#    'company_name_l_exist': 'ACAL BFI UK LIMITED',
#    'postcode_l_exist': 'RG41 2EY',
#    'company_name_r_exist': 'ACAL BFI UK LIMITED',
#    'postcode_r_exist': 'RG41 2EY'},
#   {'id_l': '09978155',
#    'id_r': '896950',
#    'match_probability': 0.9999716665399733,
#    'score': 4,
#    'company_name_l_pred': 'STERLING SENSORS UK LIMITED',
#    'postcode_l_pred': 'OL8 4PQ',
#    'company_name_r_pred': 'STERLING SENSORS UK LIMITED',
#    'postcode_r_pred': 'OL8 4PQ',
#    'company_name_l_exist': 'STERLING SENSORS UK LIMITED',
#    'postcode_l_exist': 'OL8 4PQ',
#    'company_name_r_exist': 'STERLING SENSORS UK LIMITED',
#    'postcode_r_exist': 'OL8 4PQ'},
#   {'id_l': '09241878',
#    'id_r': '2276294',
#    'match_probability': 0.9149827082212684,
#    'score': 4,
#    'company_name_l_pred': 'REFURB LAPTOPS AND ACCESSORIES LIMITED',
#    'postcode_l_pred': 'S13 9DQ',
#    'company_name_r_pred': 'REFURB LAPTOPS AND ACCESSORIES LIMITED',
#    'postcode_r_pred': 'S9 4WA',
#    'company_name_l_exist': 'REFURB LAPTOPS AND ACCESSORIES LIMITED',
#    'postcode_l_exist': 'S13 9DQ',
#    'company_name_r_exist': 'REFURB LAPTOPS AND ACCESSORIES LIMITED',
#    'postcode_r_exist': 'S9 4WA'},
#   {'id_l': '08021528',
#    'id_r': '690111',
#    'match_probability': 0.9999338910907299,
#    'score': 4,
#    'company_name_l_pred': 'SIGMA CORPORATION LTD',
#    'postcode_l_pred': 'TW4 7RP',
#    'company_name_r_pred': 'SIGMA CORPORATION LTD',
#    'postcode_r_pred': 'TW4 7RP',
#    'company_name_l_exist': 'SIGMA CORPORATION LTD',
#    'postcode_l_exist': 'TW4 7RP',
#    'company_name_r_exist': 'SIGMA CORPORATION LTD',
#    'postcode_r_exist': 'TW4 7RP'},
#   {'id_l': '04850312',
#    'id_r': '3081415',
#    'match_probability': 0.9999811108482505,
#    'score': 5,
#    'company_name_l_pred': 'POLLYANNA FINE BONE CHINA LIMITED',
#    'postcode_l_pred': 'ST6 4AW',
#    'company_name_r_pred': 'POLLYANNA FINE BONE CHINA LTD',
#    'postcode_r_pred': 'ST6 4AW',
#    'company_name_l_exist': 'POLLYANNA FINE BONE CHINA LIMITED',
#    'postcode_l_exist': 'ST6 4AW',
#    'company_name_r_exist': 'POLLYANNA FINE BONE CHINA LTD',
#    'postcode_r_exist': 'ST6 4AW'}],
#  'eval_only_sample': [{'id_l': '03462441',
#    'id_r': '619709',
#    'score': 4.0,
#    'company_name_l_exist': 'COOLCARE LIMITED',
#    'postcode_l_exist': 'LS25 2DY',
#    'company_name_r_exist': 'TURNER VIRR AND CO LIMITED',
#    'postcode_r_exist': 'LS25 2DY'},
#   {'id_l': '00654015',
#    'id_r': '3377484',
#    'score': 4.0,
#    'company_name_l_exist': 'W.A.WEST LIMITED',
#    'postcode_l_exist': 'PE21 7TT',
#    'company_name_r_exist': 'BENTLEY INNOMED GMBH',
#    'postcode_r_exist': 'PE21 7TT'},
#   {'id_l': '05838289',
#    'id_r': '33961',
#    'score': 4.0,
#    'company_name_l_exist': 'REALITEE HAIR LIMITED',
#    'postcode_l_exist': 'WS12 3HB',
#    'company_name_r_exist': 'ANDREW CHARLESWORTH WATSON',
#    'postcode_r_exist': 'WS12 3HB'},
#   {'id_l': '13155174',
#    'id_r': '2027833',
#    'score': 4.0,
#    'company_name_l_exist': 'FLIP MULTIMEDIA LIMITED',
#    'postcode_l_exist': 'NG10 5DD',
#    'company_name_r_exist': 'SELF NATHAN',
#    'postcode_r_exist': 'NG10 5DD'},
#   {'id_l': '10733043',
#    'id_r': '2885966',
#    'score': 4.0,
#    'company_name_l_exist': 'PRECISION ELEMENTS LTD',
#    'postcode_l_exist': 'FY3 8LZ',
#    'company_name_r_exist': 'PRECISION ELEMENTS LTD',
#    'postcode_r_exist': 'N1 7GU'},
#   {'id_l': '08598559',
#    'id_r': '2680376',
#    'score': 4.0,
#    'company_name_l_exist': 'STRING AND TINS LTD',
#    'postcode_l_exist': 'NW3 6LH',
#    'company_name_r_exist': 'STRING AND TINS LTD',
#    'postcode_r_exist': 'W1T 1QT'},
#   {'id_l': '08136606',
#    'id_r': '565447',
#    'score': 4.0,
#    'company_name_l_exist': 'SYNC COMMUNICATIONS LIMITED',
#    'postcode_l_exist': 'E17 9RD',
#    'company_name_r_exist': 'ABIGAIL HANNAH  BOOTH & MAX ALEXANDER BAINBRIDGE',
#    'postcode_r_exist': 'E17 9RD'},
#   {'id_l': '11332314',
#    'id_r': '840604',
#    'score': 4.0,
#    'company_name_l_exist': 'ITALMATCH CHEMICALS GB LIMITED',
#    'postcode_l_exist': 'M17 1SX',
#    'company_name_r_exist': 'ITALMATCH CHEMICALS GB LIMITED',
#    'postcode_r_exist': 'BS2 0ZX'},
#   {'id_l': '02054167',
#    'id_r': '1606767',
#    'score': 4.0,
#    'company_name_l_exist': 'NIKHAR LIMITED',
#    'postcode_l_exist': 'HA3 0BU',
#    'company_name_r_exist': 'NIKHAR LIMITED',
#    'postcode_r_exist': 'N21 2NN'},
#   {'id_l': '10406638',
#    'id_r': '519173',
#    'score': 4.0,
#    'company_name_l_exist': 'UNOVA LIMITED',
#    'postcode_l_exist': 'RG2 0QX',
#    'company_name_r_exist': 'UNOVA LTD',
#    'postcode_r_exist': 'SL3 8AR'}],
#  'pred_only_sample': [{'id_l': '13777755',
#    'id_r': '1168275',
#    'match_probability': 0.8554662696062849,
#    'company_name_l_pred': 'OLIVER SWEENEY GROUP LIMITED',
#    'postcode_l_pred': 'NW5 3ED',
#    'company_name_r_pred': 'OLIVER SWEENEY TRADING LIMITED',
#    'postcode_r_pred': 'NW5 3ED'},
#   {'id_l': '10588575',
#    'id_r': '3264150',
#    'match_probability': 0.9999244476743602,
#    'company_name_l_pred': 'AINSLY LIMITED',
#    'postcode_l_pred': 'GL52 2EX',
#    'company_name_r_pred': 'AINSLY LTD',
#    'postcode_r_pred': 'GL52 2EX'},
#   {'id_l': '04012342',
#    'id_r': '621955',
#    'match_probability': 0.7820133875353363,
#    'company_name_l_pred': 'LOGICALIS GROUP LIMITED',
#    'postcode_l_pred': 'SL6 3UD',
#    'company_name_r_pred': 'LOGICALIS UK LIMITED',
#    'postcode_r_pred': 'SL1 4PF'},
#   {'id_l': '02061787',
#    'id_r': '1349330',
#    'match_probability': 0.9999716665399733,
#    'company_name_l_pred': 'SETHI SILK STORES LIMITED',
#    'postcode_l_pred': 'UB2 4AB',
#    'company_name_r_pred': 'SETHI SILK STORES LIMITED',
#    'postcode_r_pred': 'UB2 4AB'},
#   {'id_l': '12156924',
#    'id_r': '2468186',
#    'match_probability': 0.8554662696062849,
#    'company_name_l_pred': 'PLANET GARDENING RETAIL LIMITED',
#    'postcode_l_pred': 'SG18 9BS',
#    'company_name_r_pred': 'PLANET GARDENING LTD',
#    'postcode_r_pred': 'SG18 9BS'},
#   {'id_l': '14825159',
#    'id_r': '3059429',
#    'match_probability': 0.8554662696062849,
#    'company_name_l_pred': 'JC CO ENTERPRISES LTD',
#    'postcode_l_pred': 'EC2A 4NE',
#    'company_name_r_pred': 'LOJ ENTERPRISE LIMITED',
#    'postcode_r_pred': 'EC2A 4NE'},
#   {'id_l': '03103451',
#    'id_r': '1883240',
#    'match_probability': 0.8554662696062849,
#    'company_name_l_pred': 'LONDON CLUBS MANCHESTER LIMITED',
#    'postcode_l_pred': 'W1U 8EW',
#    'company_name_r_pred': 'LONDON CLUBS MANAGEMENT LTD',
#    'postcode_r_pred': 'W1U 8EW'},
#   {'id_l': '01194705',
#    'id_r': '245857',
#    'match_probability': 0.9999716665399733,
#    'company_name_l_pred': 'INTERSPIRO LIMITED',
#    'postcode_l_pred': 'TF2 9TU',
#    'company_name_r_pred': 'INTERSPIRO LTD',
#    'postcode_r_pred': 'TF2 9TU'},
#   {'id_l': '10793388',
#    'id_r': '278300',
#    'match_probability': 0.8432885956326873,
#    'company_name_l_pred': 'OTC EUROPE GROUP LIMITED',
#    'postcode_l_pred': 'EC2A 1AF',
#    'company_name_r_pred': 'OTC EUROPE LLP',
#    'postcode_r_pred': 'EC2R 6AR'},
#   {'id_l': '14965677',
#    'id_r': '569701',
#    'match_probability': 0.8554662696062849,
#    'company_name_l_pred': 'TD ENGINEERING LTD',
#    'postcode_l_pred': 'WC2H 9JQ',
#    'company_name_r_pred': 'IRATEC ENGINEERING LIMITED',
#    'postcode_r_pred': 'WC2H 9JQ'}]}

# %%
(
    agree
    .sample(10)
    .to_dict(orient='records')
)
# Out:
# [{'id_l': '04191274',
#   'id_r': '2442232',
#   'match_probability': 0.9997962447240717,
#   'score': 4,
#   'company_name_l_pred': 'LINDSTROM LIMITED',
#   'postcode_l_pred': 'MK41 0TY',
#   'company_name_r_pred': 'LINDSTROM LIMITED',
#   'postcode_r_pred': 'MK41 0TY',
#   'company_name_l_exist': 'LINDSTROM LIMITED',
#   'postcode_l_exist': 'MK41 0TY',
#   'company_name_r_exist': 'LINDSTROM LIMITED',
#   'postcode_r_exist': 'MK41 0TY'},
#  {'id_l': '11172250',
#   'id_r': '2934795',
#   'match_probability': 0.9947507544206163,
#   'score': 4,
#   'company_name_l_pred': 'LEAF DESIGN UK LIMITED',
#   'postcode_l_pred': 'LN11 0WA',
#   'company_name_r_pred': 'LEAF DESIGN UK LTD',
#   'postcode_r_pred': 'LN11 0BA',
#   'company_name_l_exist': 'LEAF DESIGN UK LIMITED',
#   'postcode_l_exist': 'LN11 0WA',
#   'company_name_r_exist': 'LEAF DESIGN UK LTD',
#   'postcode_r_exist': 'LN11 0BA'},
#  {'id_l': 'SC167094',
#   'id_r': '2338513',
#   'match_probability': 0.9995925724636534,
#   'score': 4,
#   'company_name_l_pred': 'ORB INTERNATIONAL KMS LIMITED',
#   'postcode_l_pred': 'G51 2JR',
#   'company_name_r_pred': 'ORB INTERNATIONAL KMS LIMITED',
#   'postcode_r_pred': 'G51 2JR',
#   'company_name_l_exist': 'ORB INTERNATIONAL KMS LIMITED',
#   'postcode_l_exist': 'G51 2JR',
#   'company_name_r_exist': 'ORB INTERNATIONAL KMS LIMITED',
#   'postcode_r_exist': 'G51 2JR'},
#  {'id_l': '03898053',
#   'id_r': '70309',
#   'match_probability': 0.972775539396186,
#   'score': 4,
#   'company_name_l_pred': 'RUNTIME COLLECTIVE LIMITED',
#   'postcode_l_pred': 'BN1 1UJ',
#   'company_name_r_pred': 'RUNTIME COLLECTIVE LTD',
#   'postcode_r_pred': 'BN1 3XE',
#   'company_name_l_exist': 'RUNTIME COLLECTIVE LIMITED',
#   'postcode_l_exist': 'BN1 1UJ',
#   'company_name_r_exist': 'RUNTIME COLLECTIVE LTD',
#   'postcode_r_exist': 'BN1 3XE'},
#  {'id_l': '04618535',
#   'id_r': '1343712',
#   'match_probability': 0.9997962447240717,
#   'score': 4,
#   'company_name_l_pred': 'JSF STAINLESS LIMITED',
#   'postcode_l_pred': 'WS8 6JT',
#   'company_name_r_pred': 'JSF STAINLESS LTD',
#   'postcode_r_pred': 'WS8 6JT',
#   'company_name_l_exist': 'JSF STAINLESS LIMITED',
#   'postcode_l_exist': 'WS8 6JT',
#   'company_name_r_exist': 'JSF STAINLESS LTD',
#   'postcode_r_exist': 'WS8 6JT'},
#  {'id_l': '02527480',
#   'id_r': '2686818',
#   'match_probability': 0.9997962447240717,
#   'score': 4,
#   'company_name_l_pred': "LETCHWORTH'S (FREEMASONS' HALL, LONDON) LIMITED",
#   'postcode_l_pred': 'WC2B 5AZ',
#   'company_name_r_pred': "LETCHWORTH'S (FREEMASONS' HALL LONDON) LTD",
#   'postcode_r_pred': 'WC2B 5AZ',
#   'company_name_l_exist': "LETCHWORTH'S (FREEMASONS' HALL, LONDON) LIMITED",
#   'postcode_l_exist': 'WC2B 5AZ',
#   'company_name_r_exist': "LETCHWORTH'S (FREEMASONS' HALL LONDON) LTD",
#   'postcode_r_exist': 'WC2B 5AZ'},
#  {'id_l': '00880470',
#   'id_r': '1413501',
#   'match_probability': 0.972775539396186,
#   'score': 4,
#   'company_name_l_pred': 'M G ELECTRIC (COLCHESTER) LIMITED',
#   'postcode_l_pred': 'CO4 9HY',
#   'company_name_r_pred': 'M G ELECTRIC (COLCHESTER) LTD',
#   'postcode_r_pred': 'CO4 4HT',
#   'company_name_l_exist': 'M G ELECTRIC (COLCHESTER) LIMITED',
#   'postcode_l_exist': 'CO4 9HY',
#   'company_name_r_exist': 'M G ELECTRIC (COLCHESTER) LTD',
#   'postcode_r_exist': 'CO4 4HT'},
#  {'id_l': '02567148',
#   'id_r': '2848093',
#   'match_probability': 0.9997962447240717,
#   'score': 4,
#   'company_name_l_pred': 'GOLDEN EAGLE LUXURY TRAINS LIMITED',
#   'postcode_l_pred': 'WA14 4QF',
#   'company_name_r_pred': 'GOLDEN EAGLE LUXURY TRAINS LIMITED',
#   'postcode_r_pred': 'WA14 4QF',
#   'company_name_l_exist': 'GOLDEN EAGLE LUXURY TRAINS LIMITED',
#   'postcode_l_exist': 'WA14 4QF',
#   'company_name_r_exist': 'GOLDEN EAGLE LUXURY TRAINS LIMITED',
#   'postcode_r_exist': 'WA14 4QF'},
#  {'id_l': 'NI041058',
#   'id_r': '2673710',
#   'match_probability': 0.9166476070055724,
#   'score': 4,
#   'company_name_l_pred': 'GREGORY DONNELLY SAND & GRAVEL LIMITED',
#   'postcode_l_pred': 'BT47 3RH',
#   'company_name_r_pred': 'GREGORY DONNELLY SAND & GRAVEL LTD',
#   'postcode_r_pred': 'BT82 0LB',
#   'company_name_l_exist': 'GREGORY DONNELLY SAND & GRAVEL LIMITED',
#   'postcode_l_exist': 'BT47 3RH',
#   'company_name_r_exist': 'GREGORY DONNELLY SAND & GRAVEL LTD',
#   'postcode_r_exist': 'BT82 0LB'},
#  {'id_l': '10887470',
#   'id_r': '2394784',
#   'match_probability': 0.9997962447240717,
#   'score': 4,
#   'company_name_l_pred': 'ALICE JEWELS LIMITED',
#   'postcode_l_pred': 'NW1 4QG',
#   'company_name_r_pred': 'ALICE JEWELS LIMITED',
#   'postcode_r_pred': 'NW1 4QG',
#   'company_name_l_exist': 'ALICE JEWELS LIMITED',
#   'postcode_l_exist': 'NW1 4QG',
#   'company_name_r_exist': 'ALICE JEWELS LIMITED',
#   'postcode_r_exist': 'NW1 4QG'}]
